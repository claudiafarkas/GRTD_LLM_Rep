# %% [markdown]
# Note: Decided to run the replication code in the colab envirnment due to gpu restrictions on our peronal computers. Therefore, we also had to reduce some paremeters (as specified in step 1) during the replication in order to achive similar results to the paper.

# %%
import os, re, random
import pandas as pd
from sklearn.datasets import fetch_openml
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    Trainer,
    TrainingArguments,
)
import torch
import numpy as np

# %%
# ---------- GLOBAl CONFIGS ----------
os.environ.setdefault("TOKENIZERS_PARALLELISM", "false")
random.seed(42)

# Setting DEVICE to be dynamic (uses GPU if available, else CPU)
if torch.cuda.is_available():
    torch.set_default_device("cuda")
    DEVICE = torch.device("cuda")
    print("Using GPU")
else:
    torch.set_default_device("cpu")
    DEVICE = torch.device("cpu")
    print("Using CPU - GPU is currently unavilable")

# --- Values Taken from Paper Specifications ---
MODEL_NAME = "distilgpt2"   # stays no matter the dataset chosen
MAX_LEN = 256               # not explicitly specified but is assumed
BATCH_SIZE = 32             # (32 is specified in the paper - stays no matter the dataset chosen)
EPOCHS = 10                 # (50 is specified in the paper - stays no matter the dataset chosen)
N_SAMPLES = 2000            # (5000 specified in the paper for the adult dataset) # rows we want in our synthetic dataset

# --- Loading the Two Chosen Datasets ---
# -- Comment out the one not in use --
# - Adult Dataset -
DATASET_NAME = "adult"
LABEL_ORIG = "class"
LABEL_NEW = "income"
CSV_OUT = "data/synthetic_adult_predllm_mini.csv"

# - Bank Dataset -
# DATASET_NAME = "bank"
# LABEL_ORIG = "bank-marketing"
# LABEL_NEW = "y"
# CSV_OUT = "data/synthetic_bank_predllm_mini.csv"


print(f" --- Loading Dataset: {DATASET_NAME} --- ")
chosen_dataset = fetch_openml(DATASET_NAME, version=2, as_frame=True)
df = chosen_dataset.frame
df = df.rename(columns={LABEL_ORIG: LABEL_NEW})  # renamed in the df
LABEL = LABEL_NEW                                # setting it for the rest of the pipeline
df = df.dropna().reset_index(drop=True)

df = df.sample(n=min(2000, len(df)), random_state=42).reset_index(drop=True) # keeps a smaller subset (computationally easier on our laptops)

FEATURES = [c for c in df.columns if c != LABEL]    # creates a list of column names but excludes the target LABEL value, this is bc we are trying to predict that label
# Out:
# Using GPU
#  --- Loading Dataset: adult ---

# %%
#improvement section
# ---------- Improvement: Cheap Schema Constraints (Improves Realism) ----------
# from pred_llm_mini_no_finetune import sample_feature_value


REAL_UNIQUES = {}
REAL_NUM_STATS = {}

for c in FEATURES:
    if df[c].dtype == "object":
        REAL_UNIQUES[c] = set(df[c].astype(str).str.strip().str.lower().unique().tolist())      # normalizing the strings to lower case and stripping whitespace
    else:
        col_num = pd.to_numeric(df[c], errors="coerce")         # convert to numeric, coerce errors to NaN (this helps handle non-numeric entries)
        REAL_NUM_STATS[c] = {
            "min": float(col_num.min()),        # real min
            "max": float(col_num.max()),        # real max
        }

def enforce_schema(feats: dict) -> dict:
    """Helper function to sample a numeric feature value within real min/max range
    generated values to validate real schema (cheap & improves evaluation)."""
    out = dict(feats)       # make a copy to avoid modifying original

    for c in FEATURES:
        v = out.get(c, None)   # get the generated value for the column

        # categorical
        if c in REAL_UNIQUES:
            if v is None:
                out[c] = random.choice(df[c].astype(str).tolist())      # if no value generated, sample a real value
                continue
            vn = str(v).strip().lower()                                 # normalize the generated value
            if vn not in REAL_UNIQUES[c]:
                out[c] = random.choice(df[c].astype(str).tolist())  # sample a real value if generated value not in real uniques
            else:
                matches = df[c].astype(str)
                match_list = matches[matches.str.strip().str.lower() == vn].tolist()    # keeps case sensitivity
                out[c] = random.choice(match_list) if match_list else str(v).strip()

        # numeric
        else:
            stats = REAL_NUM_STATS[c]       # get the real stats for the column, this helps us clip the values so that they are realistic
            if v is None:
                out[c] = sample_feature_value(c)    # sample a real value if none generated
                continue
            try:
                x = float(str(v).strip())        # convert to float so that we can do min/max clipping
                x = max(stats["min"], min(stats["max"], x))  # clip - this helps keep the values realistic
                out[c] = x                     # assign the clipped value
            except Exception:
                out[c] = sample_feature_value(c)    # sample a real value if conversion fails

    return out     # output is expected to be categorial values as strings and numeric values as floats, now enforced to be realistic.

# %%
# STEP 1
# ---------- Serialization helpers: Fine-tune with Y last + Permute - learn p(Y｜X） ----------
def serialize_row(row: pd.Series, feature_order, label_col: str) -> str:
    ''' Used to help the model understand the data.
        The input data is currently a key value pair,
        but inorder for it to actually understand and process it, it converts it to string format.
    '''
    parts = []
    for col in feature_order:
        parts.append(f"{col} is {str(row[col]).strip()}")
    parts.append(f"{label_col} is {str(row[label_col]).strip()}")
    return ", ".join(parts)

def build_training_corpus(df: pd.DataFrame, features, label_col, permute_ratio=0.7):
    ''' Used to shuffle the order around of the passed in serialized string but
    makes sure that the LABEL value is always last. This helps with the training process.
    '''
    texts = []
    for _, r in df.iterrows():
        texts.append(serialize_row(r, features, label_col))  # original
        if random.random() < permute_ratio:
            fperm = features[:]
            random.shuffle(fperm)
            texts.append(serialize_row(r, fperm, label_col))  # shuffled
    return texts

print("Building training texts…")
train_texts = build_training_corpus(df, FEATURES, LABEL, permute_ratio=0.7)
print(train_texts)

# ---------- Tokenization + Training ----------
tok = AutoTokenizer.from_pretrained(MODEL_NAME)
if tok.pad_token is None:
    tok.pad_token = tok.eos_token

enc = tok(
    train_texts,
    padding = True,
    truncation = True,
    max_length = MAX_LEN,
    return_tensors = "pt",
)

class TxtDataset(torch.utils.data.Dataset):
    def __init__(self, encodings):
        self.enc = encodings
    def __len__(self):
        return self.enc["input_ids"].shape[0]
    def __getitem__(self, i):
        return {
            "input_ids": self.enc["input_ids"][i],
            "attention_mask": self.enc["attention_mask"][i],
            "labels": self.enc["input_ids"][i],
        }

ds = TxtDataset(enc)

# --- Model Specifications ---
model = AutoModelForCausalLM.from_pretrained(MODEL_NAME)
model.to(DEVICE)

# --- Training Specifications ---
# -- Described earlier in the code --
args = TrainingArguments(
    output_dir = "runs/predllm-mini",
    per_device_train_batch_size = BATCH_SIZE,
    gradient_accumulation_steps=8,
    num_train_epochs = EPOCHS,
    learning_rate = 5e-5,
    weight_decay = 0.01,
    fp16 = torch.cuda.is_available(),
    bf16 = False,
    logging_steps = 50,
    save_steps = 2000,
    save_total_limit = 1,
    report_to = [],
    no_cuda = not torch.cuda.is_available(),  # only disable CUDA if GPU isn't available
    dataloader_pin_memory = False,
    # use_mps_device=False,     # only needed if running on a mac
)

print("Initializing the trainer...")
trainer = Trainer(model=model, args=args, train_dataset=ds)
print(trainer)

print("Fine-tuning (CPU/GPU - depending on which one is selected to run on)")
trainer.train()   # startes training
model = trainer.model
model.to(DEVICE)
model.eval()

print("Model is on device - ", next(model.parameters()).device)

# --- Saves Finetuning Data to the 'runs' Folder ---
os.makedirs("runs/predllm-mini/model", exist_ok=True)
trainer.save_model("runs/predllm-mini/model")
tok.save_pretrained("runs/predllm-mini/model")
# Out:
# Building training texts…
# ['age is 19, workclass is Self-emp-not-inc, fnlwgt is 30800, education is 10th, education-num is 6, marital-status is Married-spouse-absent, occupation is Adm-clerical, relationship is Unmarried, race is Amer-Indian-Eskimo, sex is Female, capital-gain is 0, capital-loss is 0, hours-per-week is 40, native-country is United-States, income is <=50K', 'sex is Female, relationship is Unmarried, race is Amer-Indian-Eskimo, native-country is United-States, hours-per-week is 40, occupation is Adm-clerical, marital-status is Married-spouse-absent, workclass is Self-emp-not-inc, fnlwgt is 30800, capital-gain is 0, education is 10th, education-num is 6, capital-loss is 0, age is 19, income is <=50K', 'age is 45, workclass is Private, fnlwgt is 26781, education is HS-grad, education-num is 9, marital-status is Married-civ-spouse, occupation is Farming-fishing, relationship is Husband, race is Amer-Indian-Eskimo, sex is Male, capital-gain is 0, capital-loss is 0, hours-per-week is 40, native-country is United-States, income is <=50K', 'fnlwgt is 26781, native-country is United-States, capital-gain is 0, relationship is Husband, education-num is 9, occupation is Farming-fishing, marital-status is Married-civ-spouse, capital-loss is 0, age is 45, sex is Male, race is Amer-Indian-Eskimo, hours-per-week is 40, education is HS-grad, workclass is Private, income is <=50K', 'age is 47, workclass is Private, fnlwgt is 431515, education is Assoc-voc, education-num is 11, marital-status is Married-civ-spouse, occupation is Craft-repair, relationship is Husband, race is White, sex is Male, capital-gain is 0, capital-loss is 0, hours-per-week is 40, native-country is United-States, income is >50K', 'sex is Male, education is Assoc-voc, capital-gain is 0, race is White, native-country is United-States, relationship is Husband, workclass is Private, capital-loss is 0, education-num is 11, marital-status is Married-civ-spouse, occupation is Craft-repair, fnlwgt is 431515, age is 47, hours-per-week is 40, income is >50K', 'age is 23, workclass is Private, fnlwgt is 45713, education is Some-college, education-num is 10, marital-status is Never-married, occupation is Craft-repair, relationship is Other-relative, race is White, sex is Male, capital-gain is 0, capital-loss is 0, hours-per-week is 40, native-country is United-States, income is <=50K', 'native-country is United-States, hours-per-week is 40, occupation is Craft-repair, fnlwgt is 45713, capital-loss is 0, capital-gain is 0, education is Some-college, workclass is Private, race is White, relationship is Other-relative, age is 23, education-num is 10, sex is Male, marital-status is Never-married, income is <=50K', 'age is 53, workclass is Local-gov, fnlwgt is 175897, education is HS-grad, education-num is 9, marital-status is Married-civ-spouse, occupation is Craft-repair, relationship is Husband, race is White, sex is Male, capital-gain is 0, capital-loss is 0, hours-per-week is 40, native-country is United-States, income is <=50K', 'race is White, fnlwgt is 175897, marital-status is Married-civ-spouse, sex is Male, native-country is United-States, relationship is Husband, occupation is Craft-repair, hours-per-week is 40, education-num is 9, education is HS-grad, capital-gain is 0, age is 53, workclass is Local-gov, capital-loss is 0, income is <=50K', 'age is 52, workclass is Self-emp-not-inc, fnlwgt is 34973, education is HS-grad, education-num is 9, marital-status is Married-civ-spouse, occupation is Farming-fishing, relationship is Husband, race is White, sex is Male, capital-gain is 0, capital-loss is 1887, hours-per-week is 60, native-country is United-States, income is >50K', 'hours-per-week is 60, sex is Male, age is 52, occupation is Farming-fishing, relationship is Husband, capital-gain is 0, race is White, workclass is Self-emp-not-inc, education-num is 9, education is HS-grad, capital-loss is 1887, native-country is United-States, fnlwgt is 34973, marital-status is Married-civ-spouse,  ...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# Initializing the trainer...
# <transformers.trainer.Trainer object at 0x7f893d9ea000>
# Fine-tuning (CPU/GPU - depending on which one is selected to run on)
# `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
#     <div>
#
#       <progress value='140' max='140' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [140/140 03:57, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.437900</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.504900</td>
#     </tr>
#   </tbody>
# </table><p>
# Model is on device -  cuda:0
# ('runs/predllm-mini/model/tokenizer_config.json',
#  'runs/predllm-mini/model/special_tokens_map.json',
#  'runs/predllm-mini/model/vocab.json',
#  'runs/predllm-mini/model/merges.txt',
#  'runs/predllm-mini/model/added_tokens.json',
#  'runs/predllm-mini/model/tokenizer.json')

# %%
# STEP 2
# ---------- Feature conditional Sampling phase: generate X ONLY ----------
print("\nSampling synthetic features (X) …")

def sample_feature_value(col):
    '''Sampler from real data'''
    return random.choice(df[col].tolist())

def generate_features_only(start_feature, start_value, max_new_tokens=120):
    """
    Start with "feature is value" and let the model continue generating
    features. If we see the label field begin (`, income is`), we cut before it.
    Returns a partial dict of generated features.
    """
    start = f"{start_feature} is {start_value}"
    prompt = start
    print(f"\n[Prompt Start] {prompt}")
    inputs = tok(prompt, return_tensors = "pt").to(model.device)

    out = model.generate(
        **inputs,
        max_new_tokens = max_new_tokens,
        do_sample = True,
        temperature = 0.8,
        top_p = 0.95,
        pad_token_id = tok.eos_token_id,
        eos_token_id = tok.eos_token_id,
    )
    text = tok.decode(out[0], skip_special_tokens=True)
    print(f"[Raw Output] {text}")

    # Stop at the beginning of label if present
    stop_idx = text.find(f", {LABEL} is")
    if stop_idx != -1:
        text = text[:stop_idx]
        print(f"[Truncated at label] {text}")

    # Parse comma separated "name is value" clauses
    clauses = [c.strip() for c in text.split(",")]
    seen = {}
    for c in clauses:
        m = re.match(r"^([^,]+?)\s+is\s+(.+)$", c)
        if not m:
            continue
        name = m.group(1).strip()
        val = m.group(2).strip()
        if name in FEATURES and name not in seen:
            seen[name] = val
        if len(seen) == len(FEATURES):
            break
    print(f"[Parsed Features] {seen}")
    return seen

synthetic_X = []
for i in range(N_SAMPLES):
    f0 = random.choice(FEATURES)      # randomly selects a feature
    v0 = sample_feature_value(f0)     # randomly selects a value
    print(f"\n[Sample {i+1}] Starting from: {f0} is {v0}")
    feats = generate_features_only(f0, v0)
    # Fill missing
    for col in FEATURES:
        if col not in feats:
            feats[col] = sample_feature_value(col)
            print(f"[Filled Missing Feature] {col} with {feats[col]}")

# ---------- Improvement: Filling Missing Features + Enforcing Schema ----------
    feats = enforce_schema(feats)     # snap to valid schema, this helps improve realism by ensuring all values conform to expected types/ranges

    synthetic_X.append(feats)

print(f"Generated {len(synthetic_X)} synthetic feature rows.")
# Out:
# Streaming output truncated to the last 5000 lines.
# [Filled Missing Feature] race with White
# [Filled Missing Feature] hours-per-week with 44
#
# [Sample 1480] Starting from: workclass is Private
#
# [Prompt Start] workclass is Private
# [Raw Output] workclass is Private, capital-loss is 0, relationship is Own-child, education is Some-college, marital-status is Married-civ-spouse, fnlwgt is 131214, hours-per-week is 40, education-num is 10, race is White, sex is Female, capital-gain is 0, native-country is United-States, hours-per-week is 40, income is <=50K
# [Truncated at label] workclass is Private, capital-loss is 0, relationship is Own-child, education is Some-college, marital-status is Married-civ-spouse, fnlwgt is 131214, hours-per-week is 40, education-num is 10, race is White, sex is Female, capital-gain is 0, native-country is United-States, hours-per-week is 40
# [Parsed Features] {'workclass': 'Private', 'capital-loss': '0', 'relationship': 'Own-child', 'education': 'Some-college', 'marital-status': 'Married-civ-spouse', 'fnlwgt': '131214', 'hours-per-week': '40', 'education-num': '10', 'race': 'White', 'sex': 'Female', 'capital-gain': '0', 'native-country': 'United-States'}
# [Filled Missing Feature] age with 37
# [Filled Missing Feature] occupation with Prof-specialty
#
# [Sample 1481] Starting from: relationship is Unmarried
#
# [Prompt Start] relationship is Unmarried
# [Raw Output] relationship is Unmarried, occupation is Other-service, native-country is United-States, race is White, sex is Male, education is Some-college, capital-gain is 0, fnlwgt is 8984, capital-loss is 0, education-num is 10, age is 18, workclass is Private, fnlwgt is 143567, relationship is Not-in-family, marital-status is Married-civ-spouse, income is <=50K
# [Truncated at label] relationship is Unmarried, occupation is Other-service, native-country is United-States, race is White, sex is Male, education is Some-college, capital-gain is 0, fnlwgt is 8984, capital-loss is 0, education-num is 10, age is 18, workclass is Private, fnlwgt is 143567, relationship is Not-in-family, marital-status is Married-civ-spouse
# [Parsed Features] {'relationship': 'Unmarried', 'occupation': 'Other-service', 'native-country': 'United-States', 'race': 'White', 'sex': 'Male', 'education': 'Some-college', 'capital-gain': '0', 'fnlwgt': '8984', 'capital-loss': '0', 'education-num': '10', 'age': '18', 'workclass': 'Private', 'marital-status': 'Married-civ-spouse'}
# [Filled Missing Feature] hours-per-week with 30
#
# [Sample 1482] Starting from: native-country is United-States
#
# [Prompt Start] native-country is United-States
# [Raw Output] native-country is United-States, capital-loss is 0, hours-per-week is 40, race is White, education is Some-college, fnlwgt is 121324, education-num is 10, sex is Male, marital-status is Married-civ-spouse, fnlwgt is 150632, capital-gain is 0, marital-status is Married-civ-spouse, race is White, income is <=50K
# [Truncated at label] native-country is United-States, capital-loss is 0, hours-per-week is 40, race is White, education is Some-college, fnlwgt is 121324, education-num is 10, sex is Male, marital-status is Married-civ-spouse, fnlwgt is 150632, capital-gain is 0, marital-status is Married-civ-spouse, race is White
# [Parsed Features] {'native-country': 'United-States', 'capital-loss': '0', 'hours-per-week': '40', 'race': 'White', 'education': 'Some-college', 'fnlwgt': '121324', 'education-num': '10', 'sex': 'Male', 'marital-status': 'Married-civ-spouse', 'capital-gain': '0'}
# [Filled Missing Feature] age with 61
# [Filled Missing Feature] workclass with Private
# [Filled Missing Feature] occupation with Exec-managerial
# [Filled Missing Feature] relationship with Own-child
#
# [Sample 1483] Starting from: relationship is Wife
#
# [Prompt Start] relationship is Wife
# [Raw Output] relationship is Wife, race is White, capital-loss is 0, hours-per-week is 40, education-num is 13, education is HS-grad, marital-status is Never-married, fnlwgt is 204942, sex is Male, capital-gain is 0, hours-per-week is 40, native-country is United-States, marital-status is Never-married, relationship is Not-in-family, income is <=50K
# [Truncated at label] relationship is Wife, race is White, capital-loss is 0, hours-per-week is 40, education-num is 13, education is HS-grad, marital-status is Never-married, fnlwgt is 204942, sex is Male, capital-gain is 0, hours-per-week is 40, native-country is United-States, marital-status is Never-married, relationship is Not-in-family
# [Parsed Features] {'relationship': 'Wife', 'race': 'White', 'capital-loss': '0', 'hours-per-week': '40', 'education-num': '13', 'education': 'HS-grad', 'marital-status': 'Never-married', 'fnlwgt': '204942', 'sex': 'Male', 'capital-gain': '0', 'native-country': 'United-States'}
# [Filled Missing Feature] age with 28
# [Filled Missing Feature] workclass with Self-emp-not-inc
# [Filled Missing Feature] occupation with Transport-moving
#
# [Sample 1484] Starting from: marital-status is Divorced
#
# [Prompt Start] marital-status is Divorced
# [Raw Output] marital-status is Divorced, capital-loss is 0, race is White, hours-per-week is 40, education-num is 13, workclass is Private, education is Some-college, relationship is Not-in-family, age is 33, relationship is Not-in-family, hours-per-week is 40, age is 35, workclass is Private, income is <=50K
# [Truncated at label] marital-status is Divorced, capital-loss is 0, race is White, hours-per-week is 40, education-num is 13, workclass is Private, education is Some-college, relationship is Not-in-family, age is 33, relationship is Not-in-family, hours-per-week is 40, age is 35, workclass is Private
# [Parsed Features] {'marital-status': 'Divorced', 'capital-loss': '0', 'race': 'White', 'hours-per-week': '40', 'education-num': '13', 'workclass': 'Private', 'education': 'Some-college', 'relationship': 'Not-in-family', 'age': '33'}
# [Filled Missing Feature] fnlwgt with 304353
# [Filled Missing Feature] occupation with Exec-managerial
# [Filled Missing Feature] sex with Male
# [Filled Missing Feature] capital-gain with 0
# [Filled Missing Feature] native-country with United-States
#
# [Sample 1485] Starting from: education-num is 10
#
# [Prompt Start] education-num is 10
# [Raw Output] education-num is 10, age is 38, capital-gain is 0, native-country is United-States, marital-status is Never-married, workclass is Private, fnlwgt is 131534, occupation is Exec-managerial, education is Some-college, education-num is 10, sex is Female, race is White, capital-loss is 0, education-num is 10, income is <=50K
# [Truncated at label] education-num is 10, age is 38, capital-gain is 0, native-country is United-States, marital-status is Never-married, workclass is Private, fnlwgt is 131534, occupation is Exec-managerial, education is Some-college, education-num is 10, sex is Female, race is White, capital-loss is 0, education-num is 10
# [Parsed Features] {'education-num': '10', 'age': '38', 'capital-gain': '0', 'native-country': 'United-States', 'marital-status': 'Never-married', 'workclass': 'Private', 'fnlwgt': '131534', 'occupation': 'Exec-managerial', 'education': 'Some-college', 'sex': 'Female', 'race': 'White', 'capital-loss': '0'}
# [Filled Missing Feature] relationship with Unmarried
# [Filled Missing Feature] hours-per-week with 44
#
# [Sample 1486] Starting from: marital-status is Married-civ-spouse
#
# [Prompt Start] marital-status is Married-civ-spouse
# [Raw Output] marital-status is Married-civ-spouse, hours-per-week is 40, education is Bachelors, occupation is Craft-repair, fnlwgt is 16894, race is White, education-num is 9, native-country is United-States, capital-gain is 0, workclass is Private, marital-status is Married-civ-spouse, capital-loss is 0, sex is Male, income is <=50K
# [Truncated at label] marital-status is Married-civ-spouse, hours-per-week is 40, education is Bachelors, occupation is Craft-repair, fnlwgt is 16894, race is White, education-num is 9, native-country is United-States, capital-gain is 0, workclass is Private, marital-status is Married-civ-spouse, capital-loss is 0, sex is Male
# [Parsed Features] {'marital-status': 'Married-civ-spouse', 'hours-per-week': '40', 'education': 'Bachelors', 'occupation': 'Craft-repair', 'fnlwgt': '16894', 'race': 'White', 'education-num': '9', 'native-country': 'United-States', 'capital-gain': '0', 'workclass': 'Private', 'capital-loss': '0', 'sex': 'Male'}
# [Filled Missing Feature] age with 28
# [Filled Missing Feature] relationship with Unmarried
#
# [Sample 1487] Starting from: workclass is Private
#
# [Prompt Start] workclass is Private
# [Raw Output] workclass is Private, relationship is Not-in-family, age is 34, education-num is 13, capital-loss is 0, hours-per-week is 40, race is Black, marital-status is Never-married, workclass is Private, native-country is United-States, education is 7th-8th, fnlwgt is 157330, capital-gain is 0, workclass is Private, income is <=50K
# [Truncated at label] workclass is Private, relationship is Not-in-family, age is 34, education-num is 13, capital-loss is 0, hours-per-week is 40, race is Black, marital-status is Never-married, workclass is Private, native-country is United-States, education is 7th-8th, fnlwgt is 157330, capital-gain is 0, workclass is Private
# [Parsed Features] {'workclass': 'Private', 'relationship': 'Not-in-family', 'age': '34', 'education-num': '13', 'capital-loss': '0', 'hours-per-week': '40', 'race': 'Black', 'marital-status': 'Never-married', 'native-country': 'United-States', 'education': '7th-8th', 'fnlwgt': '157330', 'capital-gain': '0'}
# [Filled Missing Feature] occupation with Adm-clerical
# [Filled Missing Feature] sex with Female
#
# [Sample 1488] Starting from: race is White
#
# [Prompt Start] race is White
# [Raw Output] race is White, fnlwgt is 253534, education is HS-grad, workclass is Private, relationship is Not-in-family, race is Black, sex is Male, capital-gain is 0, capital-loss is 0, hours-per-week is 45, native-country is United-States, age is 37, relationship is Not-in-family, occupation is Craft-repair, income is <=50K
# [Truncated at label] race is White, fnlwgt is 253534, education is HS-grad, workclass is Private, relationship is Not-in-family, race is Black, sex is Male, capital-gain is 0, capital-loss is 0, hours-per-week is 45, native-country is United-States, age is 37, relationship is Not-in-family, occupation is Craft-repair
# [Parsed Features] {'race': 'White', 'fnlwgt': '253534', 'education': 'HS-grad', 'workclass': 'Private', 'relationship': 'Not-in-family', 'sex': 'Male', 'capital-gain': '0', 'capital-loss': '0', 'hours-per-week': '45', 'native-country': 'United-States', 'age': '37', 'occupation': 'Craft-repair'}
# [Filled Missing Feature] education-num with 9
# [Filled Missing Feature] marital-status with Married-civ-spouse
#
# [Sample 1489] Starting from: marital-status is Never-married
#
# [Prompt Start] marital-status is Never-married
# [Raw Output] marital-status is Never-married, capital-loss is 0, age is 54, sex is Male, education is Some-college, education-num is 10, hours-per-week is 40, fnlwgt is 97975, education-num is 10, workclass is Private, occupation is Exec-managerial, capital-gain is 0, relationship is Not-in-family, workclass is Private, income is <=50K
# [Truncated at label] marital-status is Never-married, capital-loss is 0, age is 54, sex is Male, education is Some-college, education-num is 10, hours-per-week is 40, fnlwgt is 97975, education-num is 10, workclass is Private, occupation is Exec-managerial, capital-gain is 0, relationship is Not-in-family, workclass is Private
# [Parsed Features] {'marital-status': 'Never-married', 'capital-loss': '0', 'age': '54', 'sex': 'Male', 'education': 'Some-college', 'education-num': '10', 'hours-per-week': '40', 'fnlwgt': '97975', 'workclass': 'Private', 'occupation': 'Exec-managerial', 'capital-gain': '0', 'relationship': 'Not-in-family'}
# [Filled Missing Feature] race with White
# [Filled Missing Feature] native-country with United-States
#
# [Sample 1490] Starting from: marital-status is Never-married
#
# [Prompt Start] marital-status is Never-married
# [Raw Output] marital-status is Never-married, relationship is Never-married, hours-per-week is 45, native-country is United-States, marital-status is Never-married, occupation is Adm-clerical, capital-gain is 0, education is 7th-8th, race is White, sex is Male, capital-loss is 0, capital-gain is 0, income is <=50K
# [Truncated at label] marital-status is Never-married, relationship is Never-married, hours-per-week is 45, native-country is United-States, marital-status is Never-married, occupation is Adm-clerical, capital-gain is 0, education is 7th-8th, race is White, sex is Male, capital-loss is 0, capital-gain is 0
# [Parsed Features] {'marital-status': 'Never-married', 'relationship': 'Never-married', 'hours-per-week': '45', 'native-country': 'United-States', 'occupation': 'Adm-clerical', 'capital-gain': '0', 'education': '7th-8th', 'race': 'White', 'sex': 'Male', 'capital-loss': '0'}
# [Filled Missing Feature] age with 57
# [Filled Missing Feature] workclass with Private
# [Filled Missing Feature] fnlwgt with 145166
# [Filled Missing Feature] education-num with 11
#
# [Sample 1491] Starting from: age is 37
#
# [Prompt Start] age is 37
# [Raw Output] age is 37, workclass is Private, fnlwgt is 103475, education is Bachelors, education-num is 13, marital-status is Married-civ-spouse, occupation is Craft-repair, relationship is Husband, race is White, sex is Female, capital-gain is 0, capital-loss is 0, hours-per-week is 45, native-country is United-States, income is <=50K
# [Truncated at label] age is 37, workclass is Private, fnlwgt is 103475, education is Bachelors, education-num is 13, marital-status is Married-civ-spouse, occupation is Craft-repair, relationship is Husband, race is White, sex is Female, capital-gain is 0, capital-loss is 0, hours-per-week is 45, native-country is United-States
# [Parsed Features] {'age': '37', 'workclass': 'Private', 'fnlwgt': '103475', 'education': 'Bachelors', 'education-num': '13', 'marital-status': 'Married-civ-spouse', 'occupation': 'Craft-repair', 'relationship': 'Husband', 'race': 'White', 'sex': 'Female', 'capital-gain': '0', 'capital-loss': '0', 'hours-per-week': '45', 'native-country': 'United-States'}
#
# [Sample 1492] Starting from: education-num is 13
#
# [Prompt Start] education-num is 13
# [Raw Output] education-num is 13, occupation is Transport-moving, fnlwgt is 63250, education is HS-grad, relationship is Husband, education-num is 9, capital-gain is 0, race is White, sex is Male, capital-loss is 0, education-num is 13, capital-loss is 0, marital-status is Never-married, income is <=50K
# [Truncated at label] education-num is 13, occupation is Transport-moving, fnlwgt is 63250, education is HS-grad, relationship is Husband, education-num is 9, capital-gain is 0, race is White, sex is Male, capital-loss is 0, education-num is 13, capital-loss is 0, marital-status is Never-married
# [Parsed Features] {'education-num': '13', 'occupation': 'Transport-moving', 'fnlwgt': '63250', 'education': 'HS-grad', 'relationship': 'Husband', 'capital-gain': '0', 'race': 'White', 'sex': 'Male', 'capital-loss': '0', 'marital-status': 'Never-married'}
# [Filled Missing Feature] age with 34
# [Filled Missing Feature] workclass with Private
# [Filled Missing Feature] hours-per-week with 40
# [Filled Missing Feature] native-country with United-States
#
# [Sample 1493] Starting from: education is Bachelors
#
# [Prompt Start] education is Bachelors
# [Raw Output] education is Bachelors, hours-per-week is 50, occupation is Machine-op-inspct, relationship is Not-in-family, race is White, sex is Female, capital-gain is 0, capital-loss is 0, native-country is United-States, marital-status is Never-married, education-num is 9, native-country is United-States, income is <=50K
# [Truncated at label] education is Bachelors, hours-per-week is 50, occupation is Machine-op-inspct, relationship is Not-in-family, race is White, sex is Female, capital-gain is 0, capital-loss is 0, native-country is United-States, marital-status is Never-married, education-num is 9, native-country is United-States
# [Parsed Features] {'education': 'Bachelors', 'hours-per-week': '50', 'occupation': 'Machine-op-inspct', 'relationship': 'Not-in-family', 'race': 'White', 'sex': 'Female', 'capital-gain': '0', 'capital-loss': '0', 'native-country': 'United-States', 'marital-status': 'Never-married', 'education-num': '9'}
# [Filled Missing Feature] age with 40
# [Filled Missing Feature] workclass with Local-gov
# [Filled Missing Feature] fnlwgt with 32212
#
# [Sample 1494] Starting from: age is 25
#
# [Prompt Start] age is 25
# [Raw Output] age is 25, workclass is Self-emp-not-inc, fnlwgt is 237626, education is Some-college, education-num is 10, marital-status is Married-civ-spouse, occupation is Craft-repair, relationship is Husband, race is White, sex is Male, capital-gain is 0, capital-loss is 0, hours-per-week is 30, native-country is United-States, income is <=50K
# [Truncated at label] age is 25, workclass is Self-emp-not-inc, fnlwgt is 237626, education is Some-college, education-num is 10, marital-status is Married-civ-spouse, occupation is Craft-repair, relationship is Husband, race is White, sex is Male, capital-gain is 0, capital-loss is 0, hours-per-week is 30, native-country is United-States
# [Parsed Features] {'age': '25', 'workclass': 'Self-emp-not-inc', 'fnlwgt': '237626', 'education': 'Some-college', 'education-num': '10', 'marital-status': 'Married-civ-spouse', 'occupation': 'Craft-repair', 'relationship': 'Husband', 'race': 'White', 'sex': 'Male', 'capital-gain': '0', 'capital-loss': '0', 'hours-per-week': '30', 'native-country': 'United-States'}
#
# [Sample 1495] Starting from: capital-gain is 0
#
# [Prompt Start] capital-gain is 0
# [Raw Output] capital-gain is 0, age is 42, capital-loss is 0, native-country is United-States, marital-status is Never-married, education is Some-college, workclass is Self-emp-not-inc, hours-per-week is 50, education-num is 10, fnlwgt is 267615, fnlwgt is 5984, race is White, relationship is Not-in-family, income is <=50K
# [Truncated at label] capital-gain is 0, age is 42, capital-loss is 0, native-country is United-States, marital-status is Never-married, education is Some-college, workclass is Self-emp-not-inc, hours-per-week is 50, education-num is 10, fnlwgt is 267615, fnlwgt is 5984, race is White, relationship is Not-in-family
# [Parsed Features] {'capital-gain': '0', 'age': '42', 'capital-loss': '0', 'native-country': 'United-States', 'marital-status': 'Never-married', 'education': 'Some-college', 'workclass': 'Self-emp-not-inc', 'hours-per-week': '50', 'education-num': '10', 'fnlwgt': '267615', 'race': 'White', 'relationship': 'Not-in-family'}
# [Filled Missing Feature] occupation with Machine-op-inspct
# [Filled Missing Feature] sex with Female
#
# [Sample 1496] Starting from: occupation is Other-service
#
# [Prompt Start] occupation is Other-service
# [Raw Output] occupation is Other-service, fnlwgt is 182430, relationship is Other-service, education-num is 9, race is White, marital-status is Married-civ-spouse, capital-loss is 0, education is Bachelors, sex is Female, capital-gain is 0, capital-loss is 0, hours-per-week is 40, native-country is United-States, income is <=50K
# [Truncated at label] occupation is Other-service, fnlwgt is 182430, relationship is Other-service, education-num is 9, race is White, marital-status is Married-civ-spouse, capital-loss is 0, education is Bachelors, sex is Female, capital-gain is 0, capital-loss is 0, hours-per-week is 40, native-country is United-States
# [Parsed Features] {'occupation': 'Other-service', 'fnlwgt': '182430', 'relationship': 'Other-service', 'education-num': '9', 'race': 'White', 'marital-status': 'Married-civ-spouse', 'capital-loss': '0', 'education': 'Bachelors', 'sex': 'Female', 'capital-gain': '0', 'hours-per-week': '40', 'native-country': 'United-States'}
# [Filled Missing Feature] age with 36
# [Filled Missing Feature] workclass with Private
#
# [Sample 1497] Starting from: capital-gain is 0
#
# [Prompt Start] capital-gain is 0
# [Raw Output] capital-gain is 0, capital-loss is 0, education is Bachelors, native-country is United-States, workclass is Private, occupation is Transport-moving, fnlwgt is 97765, hours-per-week is 60, workclass is Private, fnlwgt is 123372, marital-status is Never-married, capital-loss is 0, marital-status is Never-married, income is <=50K
# [Truncated at label] capital-gain is 0, capital-loss is 0, education is Bachelors, native-country is United-States, workclass is Private, occupation is Transport-moving, fnlwgt is 97765, hours-per-week is 60, workclass is Private, fnlwgt is 123372, marital-status is Never-married, capital-loss is 0, marital-status is Never-married
# [Parsed Features] {'capital-gain': '0', 'capital-loss': '0', 'education': 'Bachelors', 'native-country': 'United-States', 'workclass': 'Private', 'occupation': 'Transport-moving', 'fnlwgt': '97765', 'hours-per-week': '60', 'marital-status': 'Never-married'}
# [Filled Missing Feature] age with 19
# [Filled Missing Feature] education-num with 9
# [Filled Missing Feature] relationship with Husband
# [Filled Missing Feature] race with White
# [Filled Missing Feature] sex with Male
#
# [Sample 1498] Starting from: sex is Male
#
# [Prompt Start] sex is Male
# [Raw Output] sex is Male, fnlwgt is 07865, education is HS-grad, hours-per-week is 40, native-country is United-States, race is White, capital-gain is 0, education-num is 9, sex is Male, age is 24, workclass is Private, capital-loss is 0, native-country is United-States, education-num is 9, income is <=50K
# [Truncated at label] sex is Male, fnlwgt is 07865, education is HS-grad, hours-per-week is 40, native-country is United-States, race is White, capital-gain is 0, education-num is 9, sex is Male, age is 24, workclass is Private, capital-loss is 0, native-country is United-States, education-num is 9
# [Parsed Features] {'sex': 'Male', 'fnlwgt': '07865', 'education': 'HS-grad', 'hours-per-week': '40', 'native-country': 'United-States', 'race': 'White', 'capital-gain': '0', 'education-num': '9', 'age': '24', 'workclass': 'Private', 'capital-loss': '0'}
# [Filled Missing Feature] marital-status with Never-married
# [Filled Missing Feature] occupation with Other-service
# [Filled Missing Feature] relationship with Husband
#
# [Sample 1499] Starting from: occupation is Craft-repair
#
# [Prompt Start] occupation is Craft-repair
# [Raw Output] occupation is Craft-repair, race is White, sex is Female, education-num is 9, relationship is Husband, fnlwgt is 81585, capital-loss is 0, occupation is Craft-repair, native-country is United-States, age is 47, hours-per-week is 40, workclass is Private, capital-gain is 0, education is Bachelors, income is <=50K
# [Truncated at label] occupation is Craft-repair, race is White, sex is Female, education-num is 9, relationship is Husband, fnlwgt is 81585, capital-loss is 0, occupation is Craft-repair, native-country is United-States, age is 47, hours-per-week is 40, workclass is Private, capital-gain is 0, education is Bachelors
# [Parsed Features] {'occupation': 'Craft-repair', 'race': 'White', 'sex': 'Female', 'education-num': '9', 'relationship': 'Husband', 'fnlwgt': '81585', 'capital-loss': '0', 'native-country': 'United-States', 'age': '47', 'hours-per-week': '40', 'workclass': 'Private', 'capital-gain': '0', 'education': 'Bachelors'}
# [Filled Missing Feature] marital-status with Married-civ-spouse
#
# [Sample 1500] Starting from: race is White
#
# [Prompt Start] race is White
# [Raw Output] race is White, occupation is Prof-specialty, sex is Male, capital-loss is 0, education is Bachelors, native-country is United-States, marital-status is Married-civ-spouse, capital-gain is 0, workclass is Private, age is 33, relationship is Husband, education-num is 9, fnlwgt is 183563, income is <=50K
# [Truncated at label] race is White, occupation is Prof-specialty, sex is Male, capital-loss is 0, education is Bachelors, native-country is United-States, marital-status is Married-civ-spouse, capital-gain is 0, workclass is Private, age is 33, relationship is Husband, education-num is 9, fnlwgt is 183563
# [Parsed Features] {'race': 'White', 'occupation': 'Prof-specialty', 'sex': 'Male', 'capital-loss': '0', 'education': 'Bachelors', 'native-country': 'United-States', 'marital-status': 'Married-civ-spouse', 'capital-gain': '0', 'workclass': 'Private', 'age': '33', 'relationship': 'Husband', 'education-num': '9', 'fnlwgt': '183563'}
# [Filled Missing Feature] hours-per-week with 40
#
# [Sample 1501] Starting from: capital-loss is 0
#
# [Prompt Start] capital-loss is 0
# [Raw Output] capital-loss is 0, hours-per-week is 40, native-country is United-States, relationship is Husband, workclass is Private, age is 47, education-num is 11, marital-status is Married-civ-spouse, workclass is Private, education is HS-grad, capital-gain is 0, marital-status is Married-civ-spouse, income is >50K
# [Truncated at label] capital-loss is 0, hours-per-week is 40, native-country is United-States, relationship is Husband, workclass is Private, age is 47, education-num is 11, marital-status is Married-civ-spouse, workclass is Private, education is HS-grad, capital-gain is 0, marital-status is Married-civ-spouse
# [Parsed Features] {'capital-loss': '0', 'hours-per-week': '40', 'native-country': 'United-States', 'relationship': 'Husband', 'workclass': 'Private', 'age': '47', 'education-num': '11', 'marital-status': 'Married-civ-spouse', 'education': 'HS-grad', 'capital-gain': '0'}
# [Filled Missing Feature] fnlwgt with 126494
# [Filled Missing Feature] occupation with Machine-op-inspct
# [Filled Missing Feature] race with White
# [Filled Missing Feature] sex with Female
#
# [Sample 1502] Starting from: relationship is Not-in-family
#
# [Prompt Start] relationship is Not-in-family
# [Raw Output] relationship is Not-in-family, age is 29, relationship is Not-in-family, fnlwgt is 187915, capital-loss is 0, capital-gain is 0, education is Bachelors, native-country is United-States, fnlwgt is 150631, hours-per-week is 38, income is <=50K
# [Truncated at label] relationship is Not-in-family, age is 29, relationship is Not-in-family, fnlwgt is 187915, capital-loss is 0, capital-gain is 0, education is Bachelors, native-country is United-States, fnlwgt is 150631, hours-per-week is 38
# [Parsed Features] {'relationship': 'Not-in-family', 'age': '29', 'fnlwgt': '187915', 'capital-loss': '0', 'capital-gain': '0', 'education': 'Bachelors', 'native-country': 'United-States', 'hours-per-week': '38'}
# [Filled Missing Feature] workclass with Private
# [Filled Missing Feature] education-num with 10
# [Filled Missing Feature] marital-status with Married-civ-spouse
# [Filled Missing Feature] occupation with Transport-moving
# [Filled Missing Feature] race with White
# [Filled Missing Feature] sex with Female
#
# [Sample 1503] Starting from: sex is Male
#
# [Prompt Start] sex is Male
# [Raw Output] sex is Male, hours-per-week is 40, native-country is United-States, sex is Male, relationship is Husband, education-num is 13, native-country is United-States, capital-gain is 0, occupation is Craft-repair, education is HS-grad, fnlwgt is 171236, income is <=50K
# [Truncated at label] sex is Male, hours-per-week is 40, native-country is United-States, sex is Male, relationship is Husband, education-num is 13, native-country is United-States, capital-gain is 0, occupation is Craft-repair, education is HS-grad, fnlwgt is 171236
# [Parsed Features] {'sex': 'Male', 'hours-per-week': '40', 'native-country': 'United-States', 'relationship': 'Husband', 'education-num': '13', 'capital-gain': '0', 'occupation': 'Craft-repair', 'education': 'HS-grad', 'fnlwgt': '171236'}
# [Filled Missing Feature] age with 30
# [Filled Missing Feature] workclass with Private
# [Filled Missing Feature] marital-status with Never-married
# [Filled Missing Feature] race with White
# [Filled Missing Feature] capital-loss with 0
#
# [Sample 1504] Starting from: occupation is Other-service
#
# [Prompt Start] occupation is Other-service
# [Raw Output] occupation is Other-service, relationship is Not-in-family, race is White, marital-status is Married-civ-spouse, education-num is 9, workclass is Private, hours-per-week is 40, native-country is United-States, education is Some-college, native-country is United-States, capital-loss is 0, capital-gain is 0, occupation is Other-service, income is <=50K
# [Truncated at label] occupation is Other-service, relationship is Not-in-family, race is White, marital-status is Married-civ-spouse, education-num is 9, workclass is Private, hours-per-week is 40, native-country is United-States, education is Some-college, native-country is United-States, capital-loss is 0, capital-gain is 0, occupation is Other-service
# [Parsed Features] {'occupation': 'Other-service', 'relationship': 'Not-in-family', 'race': 'White', 'marital-status': 'Married-civ-spouse', 'education-num': '9', 'workclass': 'Private', 'hours-per-week': '40', 'native-country': 'United-States', 'education': 'Some-college', 'capital-loss': '0', 'capital-gain': '0'}
# [Filled Missing Feature] age with 22
# [Filled Missing Feature] fnlwgt with 331552
# [Filled Missing Feature] sex with Male
#
# [Sample 1505] Starting from: education-num is 13
#
# [Prompt Start] education-num is 13
# [Raw Output] education-num is 13, fnlwgt is 150626, marital-status is Married-civ-spouse, occupation is Prof-specialty, relationship is Husband, race is White, sex is Male, capital-gain is 0, capital-loss is 0, hours-per-week is 40, native-country is United-States, fnlwgt is 52130, income is <=50K
# [Truncated at label] education-num is 13, fnlwgt is 150626, marital-status is Married-civ-spouse, occupation is Prof-specialty, relationship is Husband, race is White, sex is Male, capital-gain is 0, capital-loss is 0, hours-per-week is 40, native-country is United-States, fnlwgt is 52130
# [Parsed Features] {'education-num': '13', 'fnlwgt': '150626', 'marital-status': 'Married-civ-spouse', 'occupation': 'Prof-specialty', 'relationship': 'Husband', 'race': 'White', 'sex': 'Male', 'capital-gain': '0', 'capital-loss': '0', 'hours-per-week': '40', 'native-country': 'United-States'}
# [Filled Missing Feature] age with 22
# [Filled Missing Feature] workclass with Private
# [Filled Missing Feature] education with Some-college
#
# [Sample 1506] Starting from: native-country is United-States
#
# [Prompt Start] native-country is United-States
# [Raw Output] native-country is United-States, sex is Male, age is 57, education-num is 9, marital-status is Married-civ-spouse, capital-loss is 0, fnlwgt is 46724, education is Bachelors, education-num is 10, marital-status is Divorced, workclass is Private, relationship is Husband, hours-per-week is 40, native-country is United-States, income is <=50K
# [Truncated at label] native-country is United-States, sex is Male, age is 57, education-num is 9, marital-status is Married-civ-spouse, capital-loss is 0, fnlwgt is 46724, education is Bachelors, education-num is 10, marital-status is Divorced, workclass is Private, relationship is Husband, hours-per-week is 40, native-country is United-States
# [Parsed Features] {'native-country': 'United-States', 'sex': 'Male', 'age': '57', 'education-num': '9', 'marital-status': 'Married-civ-spouse', 'capital-loss': '0', 'fnlwgt': '46724', 'education': 'Bachelors', 'workclass': 'Private', 'relationship': 'Husband', 'hours-per-week': '40'}
# [Filled Missing Feature] occupation with Tech-support
# [Filled Missing Feature] race with Black
# [Filled Missing Feature] capital-gain with 0
#
# [Sample 1507] Starting from: fnlwgt is 129775
#
# [Prompt Start] fnlwgt is 129775
# [Raw Output] fnlwgt is 129775, sex is Male, race is White, capital-gain is 0, education is Some-college, education-num is 10, age is 45, capital-loss is 0, marital-status is Never-married, capital-loss is 0, education-num is 10, relationship is Never-married, hours-per-week is 40, native-country is United-States, income is <=50K
# [Truncated at label] fnlwgt is 129775, sex is Male, race is White, capital-gain is 0, education is Some-college, education-num is 10, age is 45, capital-loss is 0, marital-status is Never-married, capital-loss is 0, education-num is 10, relationship is Never-married, hours-per-week is 40, native-country is United-States
# [Parsed Features] {'fnlwgt': '129775', 'sex': 'Male', 'race': 'White', 'capital-gain': '0', 'education': 'Some-college', 'education-num': '10', 'age': '45', 'capital-loss': '0', 'marital-status': 'Never-married', 'relationship': 'Never-married', 'hours-per-week': '40', 'native-country': 'United-States'}
# [Filled Missing Feature] workclass with Private
# [Filled Missing Feature] occupation with Tech-support
#
# [Sample 1508] Starting from: education-num is 14
#
# [Prompt Start] education-num is 14
# [Raw Output] education-num is 14, native-country is United-States, sex is Male, workclass is Private, age is 36, capital-loss is 0, workclass is Private, relationship is Not-in-family, education is HS-grad, hours-per-week is 40, relationship is Not-in-family, age is 54, education-num is 9, occupation is Exec-managerial, income is >50K
# [Truncated at label] education-num is 14, native-country is United-States, sex is Male, workclass is Private, age is 36, capital-loss is 0, workclass is Private, relationship is Not-in-family, education is HS-grad, hours-per-week is 40, relationship is Not-in-family, age is 54, education-num is 9, occupation is Exec-managerial
# [Parsed Features] {'education-num': '14', 'native-country': 'United-States', 'sex': 'Male', 'workclass': 'Private', 'age': '36', 'capital-loss': '0', 'relationship': 'Not-in-family', 'education': 'HS-grad', 'hours-per-week': '40', 'occupation': 'Exec-managerial'}
# [Filled Missing Feature] fnlwgt with 101119
# [Filled Missing Feature] marital-status with Married-spouse-absent
# [Filled Missing Feature] race with White
# [Filled Missing Feature] capital-gain with 0
#
# [Sample 1509] Starting from: fnlwgt is 64563
#
# [Prompt Start] fnlwgt is 64563
# [Raw Output] fnlwgt is 64563, education is Bachelors, marital-status is Married-civ-spouse, occupation is Craft-repair, relationship is Husband, race is White, sex is Male, capital-gain is 0, capital-loss is 0, hours-per-week is 40, native-country is United-States, native-country is United-States, income is <=50K
# [Truncated at label] fnlwgt is 64563, education is Bachelors, marital-status is Married-civ-spouse, occupation is Craft-repair, relationship is Husband, race is White, sex is Male, capital-gain is 0, capital-loss is 0, hours-per-week is 40, native-country is United-States, native-country is United-States
# [Parsed Features] {'fnlwgt': '64563', 'education': 'Bachelors', 'marital-status': 'Married-civ-spouse', 'occupation': 'Craft-repair', 'relationship': 'Husband', 'race': 'White', 'sex': 'Male', 'capital-gain': '0', 'capital-loss': '0', 'hours-per-week': '40', 'native-country': 'United-States'}
# [Filled Missing Feature] age with 29
# [Filled Missing Feature] workclass with Self-emp-not-inc
# [Filled Missing Feature] education-num with 9
#
# [Sample 1510] Starting from: relationship is Other-relative
#
# [Prompt Start] relationship is Other-relative
# [Raw Output] relationship is Other-relative, race is White, marital-status is Divorced, hours-per-week is 40, age is 48, marital-status is Divorced, workclass is Private, fnlwgt is 46110, capital-loss is 0, native-country is United-States, education-num is 9, fnlwgt is 125832, sex is Female, income is <=50K
# [Truncated at label] relationship is Other-relative, race is White, marital-status is Divorced, hours-per-week is 40, age is 48, marital-status is Divorced, workclass is Private, fnlwgt is 46110, capital-loss is 0, native-country is United-States, education-num is 9, fnlwgt is 125832, sex is Female
# [Parsed Features] {'relationship': 'Other-relative', 'race': 'White', 'marital-status': 'Divorced', 'hours-per-week': '40', 'age': '48', 'workclass': 'Private', 'fnlwgt': '46110', 'capital-loss': '0', 'native-country': 'United-States', 'education-num': '9', 'sex': 'Female'}
# [Filled Missing Feature] education with HS-grad
# [Filled Missing Feature] occupation with Transport-moving
# [Filled Missing Feature] capital-gain with 15024
#
# [Sample 1511] Starting from: race is White
#
# [Prompt Start] race is White
# [Raw Output] race is White, workclass is Private, capital-loss is 0, fnlwgt is 176422, native-country is United-States, hours-per-week is 40, capital-gain is 0, occupation is Craft-repair, sex is Male, hours-per-week is 40, race is White, age is 39, hours-per-week is 35, education is Some-college, income is >50K
# [Truncated at label] race is White, workclass is Private, capital-loss is 0, fnlwgt is 176422, native-country is United-States, hours-per-week is 40, capital-gain is 0, occupation is Craft-repair, sex is Male, hours-per-week is 40, race is White, age is 39, hours-per-week is 35, education is Some-college
# [Parsed Features] {'race': 'White', 'workclass': 'Private', 'capital-loss': '0', 'fnlwgt': '176422', 'native-country': 'United-States', 'hours-per-week': '40', 'capital-gain': '0', 'occupation': 'Craft-repair', 'sex': 'Male', 'age': '39', 'education': 'Some-college'}
# [Filled Missing Feature] education-num with 10
# [Filled Missing Feature] marital-status with Separated
# [Filled Missing Feature] relationship with Not-in-family
#
# [Sample 1512] Starting from: age is 30
#
# [Prompt Start] age is 30
# [Raw Output] age is 30, workclass is Private, fnlwgt is 162978, education is 10th, education-num is 7, marital-status is Never-married, occupation is Other-service, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0, capital-loss is 0, hours-per-week is 50, native-country is United-States, income is <=50K
# [Truncated at label] age is 30, workclass is Private, fnlwgt is 162978, education is 10th, education-num is 7, marital-status is Never-married, occupation is Other-service, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0, capital-loss is 0, hours-per-week is 50, native-country is United-States
# [Parsed Features] {'age': '30', 'workclass': 'Private', 'fnlwgt': '162978', 'education': '10th', 'education-num': '7', 'marital-status': 'Never-married', 'occupation': 'Other-service', 'relationship': 'Not-in-family', 'race': 'White', 'sex': 'Male', 'capital-gain': '0', 'capital-loss': '0', 'hours-per-week': '50', 'native-country': 'United-States'}
#
# [Sample 1513] Starting from: capital-loss is 0
#
# [Prompt Start] capital-loss is 0
# [Raw Output] capital-loss is 0, fnlwgt is 254987, occupation is Exec-managerial, hours-per-week is 30, relationship is Husband, race is White, capital-gain is 0, education-num is 9, sex is Female, native-country is United-States, age is 38, education is HS-grad, capital-loss is 0, native-country is United-States, income is <=50K
# [Truncated at label] capital-loss is 0, fnlwgt is 254987, occupation is Exec-managerial, hours-per-week is 30, relationship is Husband, race is White, capital-gain is 0, education-num is 9, sex is Female, native-country is United-States, age is 38, education is HS-grad, capital-loss is 0, native-country is United-States
# [Parsed Features] {'capital-loss': '0', 'fnlwgt': '254987', 'occupation': 'Exec-managerial', 'hours-per-week': '30', 'relationship': 'Husband', 'race': 'White', 'capital-gain': '0', 'education-num': '9', 'sex': 'Female', 'native-country': 'United-States', 'age': '38', 'education': 'HS-grad'}
# [Filled Missing Feature] workclass with Private
# [Filled Missing Feature] marital-status with Never-married
#
# [Sample 1514] Starting from: marital-status is Divorced
#
# [Prompt Start] marital-status is Divorced
# [Raw Output] marital-status is Divorced, age is 50, marital-status is Married-civ-spouse, fnlwgt is 183556, education is HS-grad, relationship is Husband, education-num is 9, hours-per-week is 45, race is White, sex is Male, capital-gain is 0, capital-loss is 0, hours-per-week is 40, native-country is United-States, income is <=50K
# [Truncated at label] marital-status is Divorced, age is 50, marital-status is Married-civ-spouse, fnlwgt is 183556, education is HS-grad, relationship is Husband, education-num is 9, hours-per-week is 45, race is White, sex is Male, capital-gain is 0, capital-loss is 0, hours-per-week is 40, native-country is United-States
# [Parsed Features] {'marital-status': 'Divorced', 'age': '50', 'fnlwgt': '183556', 'education': 'HS-grad', 'relationship': 'Husband', 'education-num': '9', 'hours-per-week': '45', 'race': 'White', 'sex': 'Male', 'capital-gain': '0', 'capital-loss': '0', 'native-country': 'United-States'}
# [Filled Missing Feature] workclass with Private
# [Filled Missing Feature] occupation with Sales
#
# [Sample 1515] Starting from: fnlwgt is 150930
#
# [Prompt Start] fnlwgt is 150930
# [Raw Output] fnlwgt is 150930, education is HS-grad, relationship is Not-in-family, race is White, sex is Female, occupation is Craft-repair, relationship is Not-in-family, capital-gain is 0, capital-loss is 0, hours-per-week is 30, native-country is United-States, native-country is United-States, occupation is Craft-repair, income is <=50K
# [Truncated at label] fnlwgt is 150930, education is HS-grad, relationship is Not-in-family, race is White, sex is Female, occupation is Craft-repair, relationship is Not-in-family, capital-gain is 0, capital-loss is 0, hours-per-week is 30, native-country is United-States, native-country is United-States, occupation is Craft-repair
# [Parsed Features] {'fnlwgt': '150930', 'education': 'HS-grad', 'relationship': 'Not-in-family', 'race': 'White', 'sex': 'Female', 'occupation': 'Craft-repair', 'capital-gain': '0', 'capital-loss': '0', 'hours-per-week': '30', 'native-country': 'United-States'}
# [Filled Missing Feature] age with 43
# [Filled Missing Feature] workclass with Private
# [Filled Missing Feature] education-num with 9
# [Filled Missing Feature] marital-status with Never-married
#
# [Sample 1516] Starting from: capital-gain is 7298
#
# [Prompt Start] capital-gain is 7298
# [Raw Output] capital-gain is 7298, capital-loss is 0, hours-per-week is 39, occupation is Prof-specialty, age is 35, sex is Male, race is White, relationship is Not-in-family, education-num is 9, relationship is Not-in-family, occupation is Prof-specialty, native-country is United-States, education is HS-grad, capital-gain is 0, marital-status is Never-married, income is <=50K
# [Truncated at label] capital-gain is 7298, capital-loss is 0, hours-per-week is 39, occupation is Prof-specialty, age is 35, sex is Male, race is White, relationship is Not-in-family, education-num is 9, relationship is Not-in-family, occupation is Prof-specialty, native-country is United-States, education is HS-grad, capital-gain is 0, marital-status is Never-married
# [Parsed Features] {'capital-gain': '7298', 'capital-loss': '0', 'hours-per-week': '39', 'occupation': 'Prof-specialty', 'age': '35', 'sex': 'Male', 'race': 'White', 'relationship': 'Not-in-family', 'education-num': '9', 'native-country': 'United-States', 'education': 'HS-grad', 'marital-status': 'Never-married'}
# [Filled Missing Feature] workclass with State-gov
# [Filled Missing Feature] fnlwgt with 160291
#
# [Sample 1517] Starting from: relationship is Not-in-family
#
# [Prompt Start] relationship is Not-in-family
# [Raw Output] relationship is Not-in-family, occupation is Sales, sex is Male, marital-status is Never-married, capital-loss is 0, education-num is 9, workclass is Private, native-country is United-States, hours-per-week is 40, relationship is Not-in-family, race is White, fnlwgt is 148723, education is Some-college, income is <=50K
# [Truncated at label] relationship is Not-in-family, occupation is Sales, sex is Male, marital-status is Never-married, capital-loss is 0, education-num is 9, workclass is Private, native-country is United-States, hours-per-week is 40, relationship is Not-in-family, race is White, fnlwgt is 148723, education is Some-college
# [Parsed Features] {'relationship': 'Not-in-family', 'occupation': 'Sales', 'sex': 'Male', 'marital-status': 'Never-married', 'capital-loss': '0', 'education-num': '9', 'workclass': 'Private', 'native-country': 'United-States', 'hours-per-week': '40', 'race': 'White', 'fnlwgt': '148723', 'education': 'Some-college'}
# [Filled Missing Feature] age with 35
# [Filled Missing Feature] capital-gain with 0
#
# [Sample 1518] Starting from: capital-loss is 0
#
# [Prompt Start] capital-loss is 0
# [Raw Output] capital-loss is 0, education is HS-grad, hours-per-week is 40, sex is Male, native-country is United-States, education-num is 9, workclass is Private, age is 42, capital-gain is 0, occupation is Craft-repair, fnlwgt is 79865, workclass is Private, hours-per-week is 50, race is White, income is <=50K
# [Truncated at label] capital-loss is 0, education is HS-grad, hours-per-week is 40, sex is Male, native-country is United-States, education-num is 9, workclass is Private, age is 42, capital-gain is 0, occupation is Craft-repair, fnlwgt is 79865, workclass is Private, hours-per-week is 50, race is White
# [Parsed Features] {'capital-loss': '0', 'education': 'HS-grad', 'hours-per-week': '40', 'sex': 'Male', 'native-country': 'United-States', 'education-num': '9', 'workclass': 'Private', 'age': '42', 'capital-gain': '0', 'occupation': 'Craft-repair', 'fnlwgt': '79865', 'race': 'White'}
# [Filled Missing Feature] marital-status with Married-civ-spouse
# [Filled Missing Feature] relationship with Own-child
#
# [Sample 1519] Starting from: marital-status is Married-civ-spouse
#
# [Prompt Start] marital-status is Married-civ-spouse
# [Raw Output] marital-status is Married-civ-spouse, relationship is Husband, race is White, sex is Male, capital-gain is 0, capital-loss is 0, education is Some-college, age is 48, capital-loss is 0, hours-per-week is 40, relationship is Husband, education-num is 10, native-country is United-States, workclass is Private, income is <=50K
# [Truncated at label] marital-status is Married-civ-spouse, relationship is Husband, race is White, sex is Male, capital-gain is 0, capital-loss is 0, education is Some-college, age is 48, capital-loss is 0, hours-per-week is 40, relationship is Husband, education-num is 10, native-country is United-States, workclass is Private
# [Parsed Features] {'marital-status': 'Married-civ-spouse', 'relationship': 'Husband', 'race': 'White', 'sex': 'Male', 'capital-gain': '0', 'capital-loss': '0', 'education': 'Some-college', 'age': '48', 'hours-per-week': '40', 'education-num': '10', 'native-country': 'United-States', 'workclass': 'Private'}
# [Filled Missing Feature] fnlwgt with 201603
# [Filled Missing Feature] occupation with Prof-specialty
#
# [Sample 1520] Starting from: occupation is Other-service
#
# [Prompt Start] occupation is Other-service
# [Raw Output] occupation is Other-service, fnlwgt is 132611, capital-loss is 0, age is 26, education-num is 9, relationship is Not-in-family, education is Bachelors, fnlwgt is 153924, workclass is Private, occupation is Sales, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0, income is <=50K
# [Truncated at label] occupation is Other-service, fnlwgt is 132611, capital-loss is 0, age is 26, education-num is 9, relationship is Not-in-family, education is Bachelors, fnlwgt is 153924, workclass is Private, occupation is Sales, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0
# [Parsed Features] {'occupation': 'Other-service', 'fnlwgt': '132611', 'capital-loss': '0', 'age': '26', 'education-num': '9', 'relationship': 'Not-in-family', 'education': 'Bachelors', 'workclass': 'Private', 'race': 'White', 'sex': 'Male', 'capital-gain': '0'}
# [Filled Missing Feature] marital-status with Never-married
# [Filled Missing Feature] hours-per-week with 45
# [Filled Missing Feature] native-country with Columbia
#
# [Sample 1521] Starting from: capital-loss is 0
#
# [Prompt Start] capital-loss is 0
# ...
# [Parsed Features] {'education-num': '13', 'workclass': 'Private', 'fnlwgt': '178834', 'education': 'Some-college', 'marital-status': 'Married-civ-spouse', 'occupation': 'Prof-specialty', 'relationship': 'Husband', 'race': 'White', 'sex': 'Male', 'capital-gain': '0', 'capital-loss': '0', 'hours-per-week': '40', 'native-country': 'United-States'}
# [Filled Missing Feature] age with 46
#
# [Sample 1988] Starting from: fnlwgt is 395170
#
# [Prompt Start] fnlwgt is 395170
# [Raw Output] fnlwgt is 395170, marital-status is Divorced, race is White, occupation is Prof-specialty, native-country is United-States, sex is Male, fnlwgt is 137726, hours-per-week is 40, relationship is Not-in-family, education-num is 9, capital-gain is 0, capital-loss is 0, native-country is United-States, income is <=50K
# [Truncated at label] fnlwgt is 395170, marital-status is Divorced, race is White, occupation is Prof-specialty, native-country is United-States, sex is Male, fnlwgt is 137726, hours-per-week is 40, relationship is Not-in-family, education-num is 9, capital-gain is 0, capital-loss is 0, native-country is United-States
# [Parsed Features] {'fnlwgt': '395170', 'marital-status': 'Divorced', 'race': 'White', 'occupation': 'Prof-specialty', 'native-country': 'United-States', 'sex': 'Male', 'hours-per-week': '40', 'relationship': 'Not-in-family', 'education-num': '9', 'capital-gain': '0', 'capital-loss': '0'}
# [Filled Missing Feature] age with 59
# [Filled Missing Feature] workclass with State-gov
# [Filled Missing Feature] education with HS-grad
#
# [Sample 1989] Starting from: relationship is Husband
#
# [Prompt Start] relationship is Husband
# [Raw Output] relationship is Husband, workclass is Private, race is White, fnlwgt is 230728, hours-per-week is 45, marital-status is Married-civ-spouse, sex is Male, education is Some-college, capital-loss is 0, education-num is 10, marital-status is Never-married, occupation is Craft-repair, relationship is Husband, capital-gain is 0, income is <=50K
# [Truncated at label] relationship is Husband, workclass is Private, race is White, fnlwgt is 230728, hours-per-week is 45, marital-status is Married-civ-spouse, sex is Male, education is Some-college, capital-loss is 0, education-num is 10, marital-status is Never-married, occupation is Craft-repair, relationship is Husband, capital-gain is 0
# [Parsed Features] {'relationship': 'Husband', 'workclass': 'Private', 'race': 'White', 'fnlwgt': '230728', 'hours-per-week': '45', 'marital-status': 'Married-civ-spouse', 'sex': 'Male', 'education': 'Some-college', 'capital-loss': '0', 'education-num': '10', 'occupation': 'Craft-repair', 'capital-gain': '0'}
# [Filled Missing Feature] age with 42
# [Filled Missing Feature] native-country with United-States
#
# [Sample 1990] Starting from: age is 33
#
# [Prompt Start] age is 33
# [Raw Output] age is 33, workclass is Private, fnlwgt is 261110, education is Some-college, education-num is 10, marital-status is Divorced, occupation is Prof-specialty, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0, capital-loss is 0, hours-per-week is 40, native-country is United-States, income is <=50K
# [Truncated at label] age is 33, workclass is Private, fnlwgt is 261110, education is Some-college, education-num is 10, marital-status is Divorced, occupation is Prof-specialty, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0, capital-loss is 0, hours-per-week is 40, native-country is United-States
# [Parsed Features] {'age': '33', 'workclass': 'Private', 'fnlwgt': '261110', 'education': 'Some-college', 'education-num': '10', 'marital-status': 'Divorced', 'occupation': 'Prof-specialty', 'relationship': 'Not-in-family', 'race': 'White', 'sex': 'Male', 'capital-gain': '0', 'capital-loss': '0', 'hours-per-week': '40', 'native-country': 'United-States'}
#
# [Sample 1991] Starting from: native-country is United-States
#
# [Prompt Start] native-country is United-States
# [Raw Output] native-country is United-States, capital-loss is 0, sex is Male, education is HS-grad, native-country is United-States, workclass is Private, occupation is Exec-managerial, native-country is United-States, workclass is Private, native-country is United-States, hours-per-week is 40, age is 53, income is <=50K
# [Truncated at label] native-country is United-States, capital-loss is 0, sex is Male, education is HS-grad, native-country is United-States, workclass is Private, occupation is Exec-managerial, native-country is United-States, workclass is Private, native-country is United-States, hours-per-week is 40, age is 53
# [Parsed Features] {'native-country': 'United-States', 'capital-loss': '0', 'sex': 'Male', 'education': 'HS-grad', 'workclass': 'Private', 'occupation': 'Exec-managerial', 'hours-per-week': '40', 'age': '53'}
# [Filled Missing Feature] fnlwgt with 164190
# [Filled Missing Feature] education-num with 8
# [Filled Missing Feature] marital-status with Never-married
# [Filled Missing Feature] relationship with Husband
# [Filled Missing Feature] race with White
# [Filled Missing Feature] capital-gain with 0
#
# [Sample 1992] Starting from: capital-gain is 0
#
# [Prompt Start] capital-gain is 0
# [Raw Output] capital-gain is 0, age is 49, workclass is Private, education is Bachelors, hours-per-week is 40, occupation is Sales, native-country is United-States, marital-status is Divorced, relationship is Not-in-family, race is White, capital-loss is 0, native-country is United-States, marital-status is Married-civ-spouse, education-num is 13, income is <=50K
# [Truncated at label] capital-gain is 0, age is 49, workclass is Private, education is Bachelors, hours-per-week is 40, occupation is Sales, native-country is United-States, marital-status is Divorced, relationship is Not-in-family, race is White, capital-loss is 0, native-country is United-States, marital-status is Married-civ-spouse, education-num is 13
# [Parsed Features] {'capital-gain': '0', 'age': '49', 'workclass': 'Private', 'education': 'Bachelors', 'hours-per-week': '40', 'occupation': 'Sales', 'native-country': 'United-States', 'marital-status': 'Divorced', 'relationship': 'Not-in-family', 'race': 'White', 'capital-loss': '0', 'education-num': '13'}
# [Filled Missing Feature] fnlwgt with 112650
# [Filled Missing Feature] sex with Male
#
# [Sample 1993] Starting from: capital-loss is 0
#
# [Prompt Start] capital-loss is 0
# [Raw Output] capital-loss is 0, age is 24, education is HS-grad, capital-gain is 0, race is White, relationship is Not-in-family, occupation is Exec-managerial, workclass is Private, occupation is Other-service, marital-status is Never-married, hours-per-week is 40, native-country is United-States, sex is Female, fnlwgt is 205555, marital-status is Never-married, income is <=50K
# [Truncated at label] capital-loss is 0, age is 24, education is HS-grad, capital-gain is 0, race is White, relationship is Not-in-family, occupation is Exec-managerial, workclass is Private, occupation is Other-service, marital-status is Never-married, hours-per-week is 40, native-country is United-States, sex is Female, fnlwgt is 205555, marital-status is Never-married
# [Parsed Features] {'capital-loss': '0', 'age': '24', 'education': 'HS-grad', 'capital-gain': '0', 'race': 'White', 'relationship': 'Not-in-family', 'occupation': 'Exec-managerial', 'workclass': 'Private', 'marital-status': 'Never-married', 'hours-per-week': '40', 'native-country': 'United-States', 'sex': 'Female', 'fnlwgt': '205555'}
# [Filled Missing Feature] education-num with 9
#
# [Sample 1994] Starting from: capital-loss is 0
#
# [Prompt Start] capital-loss is 0
# [Raw Output] capital-loss is 0, age is 45, workclass is Private, education is Some-college, capital-gain is 0, marital-status is Married-civ-spouse, education-num is 10, sex is Female, fnlwgt is 155890, native-country is United-States, workclass is Private, relationship is Husband, capital-loss is 0, race is White, hours-per-week is 40, income is <=50K
# [Truncated at label] capital-loss is 0, age is 45, workclass is Private, education is Some-college, capital-gain is 0, marital-status is Married-civ-spouse, education-num is 10, sex is Female, fnlwgt is 155890, native-country is United-States, workclass is Private, relationship is Husband, capital-loss is 0, race is White, hours-per-week is 40
# [Parsed Features] {'capital-loss': '0', 'age': '45', 'workclass': 'Private', 'education': 'Some-college', 'capital-gain': '0', 'marital-status': 'Married-civ-spouse', 'education-num': '10', 'sex': 'Female', 'fnlwgt': '155890', 'native-country': 'United-States', 'relationship': 'Husband', 'race': 'White', 'hours-per-week': '40'}
# [Filled Missing Feature] occupation with Exec-managerial
#
# [Sample 1995] Starting from: hours-per-week is 35
#
# [Prompt Start] hours-per-week is 35
# [Raw Output] hours-per-week is 35, occupation is Adm-clerical, age is 47, marital-status is Never-married, relationship is Not-in-family, race is White, capital-gain is 0, fnlwgt is 155550, sex is Male, capital-loss is 0, hours-per-week is 40, native-country is United-States, education is HS-grad, income is <=50K
# [Truncated at label] hours-per-week is 35, occupation is Adm-clerical, age is 47, marital-status is Never-married, relationship is Not-in-family, race is White, capital-gain is 0, fnlwgt is 155550, sex is Male, capital-loss is 0, hours-per-week is 40, native-country is United-States, education is HS-grad
# [Parsed Features] {'hours-per-week': '35', 'occupation': 'Adm-clerical', 'age': '47', 'marital-status': 'Never-married', 'relationship': 'Not-in-family', 'race': 'White', 'capital-gain': '0', 'fnlwgt': '155550', 'sex': 'Male', 'capital-loss': '0', 'native-country': 'United-States', 'education': 'HS-grad'}
# [Filled Missing Feature] workclass with Private
# [Filled Missing Feature] education-num with 9
#
# [Sample 1996] Starting from: fnlwgt is 275093
#
# [Prompt Start] fnlwgt is 275093
# [Raw Output] fnlwgt is 275093, education-num is 13, marital-status is Never-married, occupation is Craft-repair, relationship is Own-child, race is White, sex is Male, capital-gain is 0, capital-loss is 0, native-country is United-States, hours-per-week is 55, native-country is United-States, income is <=50K
# [Truncated at label] fnlwgt is 275093, education-num is 13, marital-status is Never-married, occupation is Craft-repair, relationship is Own-child, race is White, sex is Male, capital-gain is 0, capital-loss is 0, native-country is United-States, hours-per-week is 55, native-country is United-States
# [Parsed Features] {'fnlwgt': '275093', 'education-num': '13', 'marital-status': 'Never-married', 'occupation': 'Craft-repair', 'relationship': 'Own-child', 'race': 'White', 'sex': 'Male', 'capital-gain': '0', 'capital-loss': '0', 'native-country': 'United-States', 'hours-per-week': '55'}
# [Filled Missing Feature] age with 23
# [Filled Missing Feature] workclass with Private
# [Filled Missing Feature] education with Masters
#
# [Sample 1997] Starting from: education is HS-grad
#
# [Prompt Start] education is HS-grad
# [Raw Output] education is HS-grad, age is 35, marital-status is Married-civ-spouse, capital-gain is 0, workclass is Private, relationship is Husband, race is White, sex is Male, education-num is 9, native-country is United-States, relationship is Husband, workclass is Private, native-country is United-States, capital-loss is 0, occupation is Sales, income is <=50K
# [Truncated at label] education is HS-grad, age is 35, marital-status is Married-civ-spouse, capital-gain is 0, workclass is Private, relationship is Husband, race is White, sex is Male, education-num is 9, native-country is United-States, relationship is Husband, workclass is Private, native-country is United-States, capital-loss is 0, occupation is Sales
# [Parsed Features] {'education': 'HS-grad', 'age': '35', 'marital-status': 'Married-civ-spouse', 'capital-gain': '0', 'workclass': 'Private', 'relationship': 'Husband', 'race': 'White', 'sex': 'Male', 'education-num': '9', 'native-country': 'United-States', 'capital-loss': '0', 'occupation': 'Sales'}
# [Filled Missing Feature] fnlwgt with 122988
# [Filled Missing Feature] hours-per-week with 36
#
# [Sample 1998] Starting from: relationship is Own-child
#
# [Prompt Start] relationship is Own-child
# [Raw Output] relationship is Own-child, sex is Male, native-country is United-States, education-num is 13, occupation is Adm-clerical, education is Masters, capital-gain is 0, hours-per-week is 40, fnlwgt is 287315, relationship is Husband, marital-status is Married-civ-spouse, fnlwgt is 267312, income is <=50K
# [Truncated at label] relationship is Own-child, sex is Male, native-country is United-States, education-num is 13, occupation is Adm-clerical, education is Masters, capital-gain is 0, hours-per-week is 40, fnlwgt is 287315, relationship is Husband, marital-status is Married-civ-spouse, fnlwgt is 267312
# [Parsed Features] {'relationship': 'Own-child', 'sex': 'Male', 'native-country': 'United-States', 'education-num': '13', 'occupation': 'Adm-clerical', 'education': 'Masters', 'capital-gain': '0', 'hours-per-week': '40', 'fnlwgt': '287315', 'marital-status': 'Married-civ-spouse'}
# [Filled Missing Feature] age with 35
# [Filled Missing Feature] workclass with Self-emp-not-inc
# [Filled Missing Feature] race with White
# [Filled Missing Feature] capital-loss with 0
#
# [Sample 1999] Starting from: occupation is Prof-specialty
#
# [Prompt Start] occupation is Prof-specialty
# [Raw Output] occupation is Prof-specialty, capital-loss is 0, hours-per-week is 40, education-num is 13, marital-status is Never-married, occupation is Exec-managerial, native-country is United-States, native-country is United-States, education is Bachelors, marital-status is Never-married, race is White, sex is Male, capital-gain is 0, age is 30, income is <=50K
# [Truncated at label] occupation is Prof-specialty, capital-loss is 0, hours-per-week is 40, education-num is 13, marital-status is Never-married, occupation is Exec-managerial, native-country is United-States, native-country is United-States, education is Bachelors, marital-status is Never-married, race is White, sex is Male, capital-gain is 0, age is 30
# [Parsed Features] {'occupation': 'Prof-specialty', 'capital-loss': '0', 'hours-per-week': '40', 'education-num': '13', 'marital-status': 'Never-married', 'native-country': 'United-States', 'education': 'Bachelors', 'race': 'White', 'sex': 'Male', 'capital-gain': '0', 'age': '30'}
# [Filled Missing Feature] workclass with Private
# [Filled Missing Feature] fnlwgt with 282553
# [Filled Missing Feature] relationship with Husband
#
# [Sample 2000] Starting from: capital-loss is 0
#
# [Prompt Start] capital-loss is 0
# [Raw Output] capital-loss is 0, education is HS-grad, workclass is Private, sex is Male, occupation is Sales, capital-gain is 0, hours-per-week is 40, native-country is United-States, marital-status is Married-civ-spouse, age is 32, workclass is Private, age is 35, education-num is 9, education-num is 9, income is <=50K
# [Truncated at label] capital-loss is 0, education is HS-grad, workclass is Private, sex is Male, occupation is Sales, capital-gain is 0, hours-per-week is 40, native-country is United-States, marital-status is Married-civ-spouse, age is 32, workclass is Private, age is 35, education-num is 9, education-num is 9
# [Parsed Features] {'capital-loss': '0', 'education': 'HS-grad', 'workclass': 'Private', 'sex': 'Male', 'occupation': 'Sales', 'capital-gain': '0', 'hours-per-week': '40', 'native-country': 'United-States', 'marital-status': 'Married-civ-spouse', 'age': '32', 'education-num': '9'}
# [Filled Missing Feature] fnlwgt with 116986
# [Filled Missing Feature] relationship with Own-child
# [Filled Missing Feature] race with White
# Generated 2000 synthetic feature rows.

# %%
# STEP 3
# ---------- Label-query phase: get Y (Patch 1: tighter parsing) ----------
print("\nQuerying labels (Y) …")

VALID_LABELS = {"<=50K", ">50K"}

def label_query(feat_row: dict) -> str:
  '''Serializes features in the original order,
  then lets the model continue to produce "income is <value>
  '''

  # Builds the prompt: 'feature is value, feature is value, ...'
  parts = [f"{c} is {feat_row[c]}" for c in FEATURES]
  prompt = ", ".join(parts) + ", "
  print(f"\n Prompt to model {prompt}")

  inputs = tok(prompt, return_tensors="pt").to(model.device)

  # Runs the model
  out = model.generate(
  **inputs,
  max_new_tokens = 8,
  do_sample = False,
  temperature = 0.0,
  top_p = 1.0,
  pad_token_id = tok.eos_token_id,
  eos_token_id = tok.eos_token_id,
)

  text = tok.decode(out[0], skip_special_tokens=True)
  print(f"[Model Output] {text}")

  for v in VALID_LABELS:                # orders the known labels first
    if f"{LABEL} is {v}" in text:
      print(f"Label found {v}")
      return v

  m = re.search(rf"{LABEL}\s+is\s+([^\s,]+)", text)      # regex used to fix any formatting issues
  if m:
    cand = m.group(1).strip()
    cand = cand.replace(".", "")        # normalization in case of punctuation
    for v in VALID_LABELS:
      if cand.lower() == v.lower():
        print(f"Fallback label {v}")
        return v

  print("No label found - switching to random label")
  return None

# --- Runs the label quesries ont he rows ---
synthetic_rows = []

print(f"\n Labeling {len(synthetic_X)} synthetic rows...")
for i, fx in enumerate(synthetic_X):
  print(f"\n Row {i+1}")
  y = label_query(fx)

  if y is None:     # no labels detected
      y = random.choice(df[LABEL].tolist())
      print(f"Randomly selected label: {y}")

  synthetic_rows.append({**fx, LABEL: y})

  print(f" Completed labeling {i+1} / {len(synthetic_X)} rows...")

syn_df = pd.DataFrame(synthetic_rows)

# --- Improvement: Added Extra Validation to Support the Improvement Changes---
print("\n---LABEL DISTRIBUTION CHECK---")
print(f"Synthetic label column: '{LABEL}'")
print(f"Unique synthetic labels: {syn_df[LABEL].unique()}")
print(f"Synthetic label counts:\n{syn_df[LABEL].value_counts()}")
print(f"\nReal label column: '{LABEL}'")
print(f"Unique real labels: {df[LABEL].unique()}")
print(f"Real label counts:\n{df[LABEL].value_counts()}")
print("-------------------------------\n")

# Check if we have at least 2 classes, this is critical for XGBoost to work
if len(syn_df[LABEL].unique()) < 2:
    print("Warning: Synthetic data only has 1 class! This will cause XGBoost to fail.")
    print("This means label_query() is not generating diverse labels.")
    print("Checking a few label generation examples...")

    # Testing label generation, this helps us debug the label generation process
    for i in range(min(3, len(synthetic_X))):
        test_row = synthetic_X[i]
        test_label = label_query(test_row)
        print(f"  Sample {i+1} generated label: {test_label}")
    print("\nNo automatic fix applied, evaluation will fall back to DummyClassifier if needed.")

    # Manually balance labels by copying real distribution, this helps ensure at least 2 classes are present
    print("\nManually balancing synthetic labels...")
    real_label_dist = df[LABEL].value_counts(normalize=True)
    print(f"Real label distribution:\n{real_label_dist}")

    # Assign labels proportionally to match real distribution
    n_samples = len(syn_df)
    all_labels = df[LABEL].unique()

    # Calculate how many of each label we need, this is a simple way to rebalance the dataset
    label_assignments = []
    for label in all_labels:
        n_needed = int(n_samples * real_label_dist[label])
        label_assignments.extend([label] * n_needed)

    # Fill remaining with random labels to reach n_samples
    while len(label_assignments) < n_samples:
        label_assignments.append(np.random.choice(all_labels))

    # Shuffle and assign
    np.random.shuffle(label_assignments)
    syn_df[LABEL] = label_assignments[:n_samples]

    print(f"New synthetic label distribution:\n{syn_df[LABEL].value_counts()}")



#--- Saves Synthetic CSV ---


os.makedirs("data", exist_ok=True)
syn_df.to_csv(CSV_OUT, index=False)
print(f"\nSaved synthetic dataset to: {CSV_OUT}")

print("\nSample synthetic rows:")
print(syn_df.head(10).to_string(index=False))
# Out:
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Streaming output truncated to the last 5000 lines.
# [Model Output] age is 36.0, workclass is Private, fnlwgt is 589809.0, education is Some-college, education-num is 9.0, marital-status is Never-married, occupation is Adm-clerical, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 55.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1347 / 2000 rows...
#
#  Row 1348
#
#  Prompt to model age is 36.0, workclass is Private, fnlwgt is 46711.0, education is Bachelors, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Tech-support, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 36.0, workclass is Private, fnlwgt is 46711.0, education is Bachelors, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Tech-support, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1348 / 2000 rows...
#
#  Row 1349
#
#  Prompt to model age is 31.0, workclass is Local-gov, fnlwgt is 191814.0, education is Doctorate, education-num is 10.0, marital-status is Divorced, occupation is Adm-clerical, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 31.0, workclass is Local-gov, fnlwgt is 191814.0, education is Doctorate, education-num is 10.0, marital-status is Divorced, occupation is Adm-clerical, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, urn-country is United-States,
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1349 / 2000 rows...
#
#  Row 1350
#
#  Prompt to model age is 43.0, workclass is Private, fnlwgt is 177315.0, education is Some-college, education-num is 13.0, marital-status is Never-married, occupation is Adm-clerical, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 50.0, native-country is United-States,
# [Model Output] age is 43.0, workclass is Private, fnlwgt is 177315.0, education is Some-college, education-num is 13.0, marital-status is Never-married, occupation is Adm-clerical, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 50.0, native-country is United-States, urn-country is United-States,
# No label found - switching to random label
# Randomly selected label: >50K
#  Completed labeling 1350 / 2000 rows...
#
#  Row 1351
#
#  Prompt to model age is 26.0, workclass is Private, fnlwgt is 150834.0, education is HS-grad, education-num is 14.0, marital-status is Divorced, occupation is Sales, relationship is Husband, race is Other, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 26.0, workclass is Private, fnlwgt is 150834.0, education is HS-grad, education-num is 14.0, marital-status is Divorced, occupation is Sales, relationship is Husband, race is Other, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1351 / 2000 rows...
#
#  Row 1352
#
#  Prompt to model age is 24.0, workclass is Private, fnlwgt is 34339.0, education is HS-grad, education-num is 13.0, marital-status is Married-civ-spouse, occupation is Farming-fishing, relationship is Husband, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 25.0, native-country is United-States,
# [Model Output] age is 24.0, workclass is Private, fnlwgt is 34339.0, education is HS-grad, education-num is 13.0, marital-status is Married-civ-spouse, occupation is Farming-fishing, relationship is Husband, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 25.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1352 / 2000 rows...
#
#  Row 1353
#
#  Prompt to model age is 39.0, workclass is Private, fnlwgt is 124548.0, education is Assoc-voc, education-num is 9.0, marital-status is Divorced, occupation is Adm-clerical, relationship is Not-in-family, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 45.0, native-country is United-States,
# [Model Output] age is 39.0, workclass is Private, fnlwgt is 124548.0, education is Assoc-voc, education-num is 9.0, marital-status is Divorced, occupation is Adm-clerical, relationship is Not-in-family, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 45.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1353 / 2000 rows...
#
#  Row 1354
#
#  Prompt to model age is 24.0, workclass is Private, fnlwgt is 61139.0, education is Bachelors, education-num is 13.0, marital-status is Married-civ-spouse, occupation is Protective-serv, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 24.0, workclass is Private, fnlwgt is 61139.0, education is Bachelors, education-num is 13.0, marital-status is Married-civ-spouse, occupation is Protective-serv, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1354 / 2000 rows...
#
#  Row 1355
#
#  Prompt to model age is 21.0, workclass is Private, fnlwgt is 93887.0, education is Assoc-voc, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Adm-clerical, relationship is Wife, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 21.0, workclass is Private, fnlwgt is 93887.0, education is Assoc-voc, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Adm-clerical, relationship is Wife, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is >50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1355 / 2000 rows...
#
#  Row 1356
#
#  Prompt to model age is 33.0, workclass is Private, fnlwgt is 103407.0, education is HS-grad, education-num is 5.0, marital-status is Divorced, occupation is Handlers-cleaners, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 33.0, workclass is Private, fnlwgt is 103407.0, education is HS-grad, education-num is 5.0, marital-status is Divorced, occupation is Handlers-cleaners, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1356 / 2000 rows...
#
#  Row 1357
#
#  Prompt to model age is 40.0, workclass is Private, fnlwgt is 292863.0, education is Prof-school, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Exec-managerial, relationship is Not-in-family, race is Black, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 40.0, workclass is Private, fnlwgt is 292863.0, education is Prof-school, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Exec-managerial, relationship is Not-in-family, race is Black, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1357 / 2000 rows...
#
#  Row 1358
#
#  Prompt to model age is 55.0, workclass is Private, fnlwgt is 176816.0, education is HS-grad, education-num is 10.0, marital-status is Never-married, occupation is Protective-serv, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 55.0, workclass is Private, fnlwgt is 176816.0, education is HS-grad, education-num is 10.0, marital-status is Never-married, occupation is Protective-serv, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: >50K
#  Completed labeling 1358 / 2000 rows...
#
#  Row 1359
#
#  Prompt to model age is 42.0, workclass is Self-emp-not-inc, fnlwgt is 246472.0, education is HS-grad, education-num is 12.0, marital-status is Married-civ-spouse, occupation is Exec-managerial, relationship is Unmarried, race is Black, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 55.0, native-country is United-States,
# [Model Output] age is 42.0, workclass is Self-emp-not-inc, fnlwgt is 246472.0, education is HS-grad, education-num is 12.0, marital-status is Married-civ-spouse, occupation is Exec-managerial, relationship is Unmarried, race is Black, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 55.0, native-country is United-States, ipsknot, income is >50
# No label found - switching to random label
# Randomly selected label: >50K
#  Completed labeling 1359 / 2000 rows...
#
#  Row 1360
#
#  Prompt to model age is 26.0, workclass is Local-gov, fnlwgt is 238415.0, education is HS-grad, education-num is 10.0, marital-status is Married-civ-spouse, occupation is Craft-repair, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 30.0, native-country is United-States,
# [Model Output] age is 26.0, workclass is Local-gov, fnlwgt is 238415.0, education is HS-grad, education-num is 10.0, marital-status is Married-civ-spouse, occupation is Craft-repair, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 30.0, native-country is United-States, ipsknot, income is >50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1360 / 2000 rows...
#
#  Row 1361
#
#  Prompt to model age is 41.0, workclass is Private, fnlwgt is 252662.0, education is Bachelors, education-num is 7.0, marital-status is Married-civ-spouse, occupation is Craft-repair, relationship is Wife, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 41.0, workclass is Private, fnlwgt is 252662.0, education is Bachelors, education-num is 7.0, marital-status is Married-civ-spouse, occupation is Craft-repair, relationship is Wife, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: >50K
#  Completed labeling 1361 / 2000 rows...
#
#  Row 1362
#
#  Prompt to model age is 28.0, workclass is Private, fnlwgt is 132297.0, education is Assoc-acdm, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Craft-repair, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is Taiwan,
# [Model Output] age is 28.0, workclass is Private, fnlwgt is 132297.0, education is Assoc-acdm, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Craft-repair, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is Taiwan, icharid is United-States,
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1362 / 2000 rows...
#
#  Row 1363
#
#  Prompt to model age is 19.0, workclass is Private, fnlwgt is 59145.0, education is Masters, education-num is 10.0, marital-status is Married-civ-spouse, occupation is Other-service, relationship is Unmarried, race is Amer-Indian-Eskimo, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 19.0, workclass is Private, fnlwgt is 59145.0, education is Masters, education-num is 10.0, marital-status is Married-civ-spouse, occupation is Other-service, relationship is Unmarried, race is Amer-Indian-Eskimo, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: >50K
#  Completed labeling 1363 / 2000 rows...
#
#  Row 1364
#
#  Prompt to model age is 30.0, workclass is Self-emp-inc, fnlwgt is 220385.0, education is HS-grad, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Adm-clerical, relationship is Husband, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 20.0, native-country is United-States,
# [Model Output] age is 30.0, workclass is Self-emp-inc, fnlwgt is 220385.0, education is HS-grad, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Adm-clerical, relationship is Husband, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 20.0, native-country is United-States, ipsknot, income is >50
# No label found - switching to random label
# Randomly selected label: >50K
#  Completed labeling 1364 / 2000 rows...
#
#  Row 1365
#
#  Prompt to model age is 20.0, workclass is Private, fnlwgt is 160633.0, education is Some-college, education-num is 5.0, marital-status is Never-married, occupation is Transport-moving, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 45.0, native-country is United-States,
# [Model Output] age is 20.0, workclass is Private, fnlwgt is 160633.0, education is Some-college, education-num is 5.0, marital-status is Never-married, occupation is Transport-moving, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 45.0, native-country is United-States, urn-country is United-States,
# No label found - switching to random label
# Randomly selected label: >50K
#  Completed labeling 1365 / 2000 rows...
#
#  Row 1366
#
#  Prompt to model age is 22.0, workclass is Private, fnlwgt is 152326.0, education is Bachelors, education-num is 10.0, marital-status is Never-married, occupation is Other-service, relationship is Unmarried, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 25.0, native-country is United-States,
# [Model Output] age is 22.0, workclass is Private, fnlwgt is 152326.0, education is Bachelors, education-num is 10.0, marital-status is Never-married, occupation is Other-service, relationship is Unmarried, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 25.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1366 / 2000 rows...
#
#  Row 1367
#
#  Prompt to model age is 24.0, workclass is Private, fnlwgt is 185554.0, education is HS-grad, education-num is 10.0, marital-status is Married-civ-spouse, occupation is Prof-specialty, relationship is Own-child, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 24.0, workclass is Private, fnlwgt is 185554.0, education is HS-grad, education-num is 10.0, marital-status is Married-civ-spouse, occupation is Prof-specialty, relationship is Own-child, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is >50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1367 / 2000 rows...
#
#  Row 1368
#
#  Prompt to model age is 51.0, workclass is Self-emp-inc, fnlwgt is 141268.0, education is HS-grad, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Craft-repair, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 50.0, native-country is United-States,
# [Model Output] age is 51.0, workclass is Self-emp-inc, fnlwgt is 141268.0, education is HS-grad, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Craft-repair, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 50.0, native-country is United-States, ipsknot, income is >50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1368 / 2000 rows...
#
#  Row 1369
#
#  Prompt to model age is 37.0, workclass is Private, fnlwgt is 287539.0, education is HS-grad, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Adm-clerical, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 37.0, workclass is Private, fnlwgt is 287539.0, education is HS-grad, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Adm-clerical, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1369 / 2000 rows...
#
#  Row 1370
#
#  Prompt to model age is 32.0, workclass is Private, fnlwgt is 404585.0, education is Some-college, education-num is 13.0, marital-status is Never-married, occupation is Exec-managerial, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is Mexico,
# [Model Output] age is 32.0, workclass is Private, fnlwgt is 404585.0, education is Some-college, education-num is 13.0, marital-status is Never-married, occupation is Exec-managerial, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is Mexico, ipskimit, income is <=
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1370 / 2000 rows...
#
#  Row 1371
#
#  Prompt to model age is 54.0, workclass is Private, fnlwgt is 113638.0, education is HS-grad, education-num is 13.0, marital-status is Married-civ-spouse, occupation is Adm-clerical, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 54.0, workclass is Private, fnlwgt is 113638.0, education is HS-grad, education-num is 13.0, marital-status is Married-civ-spouse, occupation is Adm-clerical, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is >50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1371 / 2000 rows...
#
#  Row 1372
#
#  Prompt to model age is 40.0, workclass is Private, fnlwgt is 247885.0, education is Some-college, education-num is 14.0, marital-status is Divorced, occupation is Other-service, relationship is Unmarried, race is Black, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 45.0, native-country is United-States,
# [Model Output] age is 40.0, workclass is Private, fnlwgt is 247885.0, education is Some-college, education-num is 14.0, marital-status is Divorced, occupation is Other-service, relationship is Unmarried, race is Black, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 45.0, native-country is United-States, urn-country is United-States,
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1372 / 2000 rows...
#
#  Row 1373
#
#  Prompt to model age is 40.0, workclass is Private, fnlwgt is 91839.0, education is Some-college, education-num is 10.0, marital-status is Never-married, occupation is Handlers-cleaners, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 50.0, native-country is United-States,
# [Model Output] age is 40.0, workclass is Private, fnlwgt is 91839.0, education is Some-college, education-num is 10.0, marital-status is Never-married, occupation is Handlers-cleaners, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 50.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1373 / 2000 rows...
#
#  Row 1374
#
#  Prompt to model age is 26.0, workclass is Private, fnlwgt is 168724.0, education is HS-grad, education-num is 9.0, marital-status is Never-married, occupation is Sales, relationship is Husband, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 26.0, workclass is Private, fnlwgt is 168724.0, education is HS-grad, education-num is 9.0, marital-status is Never-married, occupation is Sales, relationship is Husband, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1374 / 2000 rows...
#
#  Row 1375
#
#  Prompt to model age is 40.0, workclass is Private, fnlwgt is 188303.0, education is 10th, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Other-service, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 40.0, workclass is Private, fnlwgt is 188303.0, education is 10th, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Other-service, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1375 / 2000 rows...
#
#  Row 1376
#
#  Prompt to model age is 24.0, workclass is Private, fnlwgt is 174487.0, education is Assoc-acdm, education-num is 13.0, marital-status is Divorced, occupation is Sales, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 60.0, native-country is United-States,
# [Model Output] age is 24.0, workclass is Private, fnlwgt is 174487.0, education is Assoc-acdm, education-num is 13.0, marital-status is Divorced, occupation is Sales, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 60.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1376 / 2000 rows...
#
#  Row 1377
#
#  Prompt to model age is 36.0, workclass is Self-emp-not-inc, fnlwgt is 232616.0, education is Some-college, education-num is 9.0, marital-status is Never-married, occupation is Craft-repair, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 36.0, workclass is Self-emp-not-inc, fnlwgt is 232616.0, education is Some-college, education-num is 9.0, marital-status is Never-married, occupation is Craft-repair, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1377 / 2000 rows...
#
#  Row 1378
#
#  Prompt to model age is 36.0, workclass is State-gov, fnlwgt is 150832.0, education is Masters, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Other-service, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 1902.0, hours-per-week is 50.0, native-country is United-States,
# [Model Output] age is 36.0, workclass is State-gov, fnlwgt is 150832.0, education is Masters, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Other-service, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 1902.0, hours-per-week is 50.0, native-country is United-States, urn-country is United-States,
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1378 / 2000 rows...
#
#  Row 1379
#
#  Prompt to model age is 26.0, workclass is Private, fnlwgt is 169269.0, education is HS-grad, education-num is 6.0, marital-status is Never-married, occupation is Exec-managerial, relationship is Not-in-family, race is Black, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 30.0, native-country is United-States,
# [Model Output] age is 26.0, workclass is Private, fnlwgt is 169269.0, education is HS-grad, education-num is 6.0, marital-status is Never-married, occupation is Exec-managerial, relationship is Not-in-family, race is Black, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 30.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1379 / 2000 rows...
#
#  Row 1380
#
#  Prompt to model age is 22.0, workclass is Private, fnlwgt is 48873.0, education is HS-grad, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Machine-op-inspct, relationship is Own-child, race is White, sex is Female, capital-gain is 0.0, capital-loss is 1977.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 22.0, workclass is Private, fnlwgt is 48873.0, education is HS-grad, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Machine-op-inspct, relationship is Own-child, race is White, sex is Female, capital-gain is 0.0, capital-loss is 1977.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: >50K
#  Completed labeling 1380 / 2000 rows...
#
#  Row 1381
#
#  Prompt to model age is 40.0, workclass is State-gov, fnlwgt is 167610.0, education is Some-college, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Adm-clerical, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 40.0, workclass is State-gov, fnlwgt is 167610.0, education is Some-college, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Adm-clerical, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1381 / 2000 rows...
#
#  Row 1382
#
#  Prompt to model age is 28.0, workclass is Private, fnlwgt is 168975.0, education is HS-grad, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Machine-op-inspct, relationship is Husband, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 28.0, workclass is Private, fnlwgt is 168975.0, education is HS-grad, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Machine-op-inspct, relationship is Husband, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is >50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1382 / 2000 rows...
#
#  Row 1383
#
#  Prompt to model age is 41.0, workclass is Private, fnlwgt is 277964.0, education is Assoc-voc, education-num is 10.0, marital-status is Married-civ-spouse, occupation is Craft-repair, relationship is Not-in-family, race is Asian-Pac-Islander, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 41.0, workclass is Private, fnlwgt is 277964.0, education is Assoc-voc, education-num is 10.0, marital-status is Married-civ-spouse, occupation is Craft-repair, relationship is Not-in-family, race is Asian-Pac-Islander, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1383 / 2000 rows...
#
#  Row 1384
#
#  Prompt to model age is 49.0, workclass is Private, fnlwgt is 188246.0, education is Bachelors, education-num is 13.0, marital-status is Never-married, occupation is Adm-clerical, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 49.0, workclass is Private, fnlwgt is 188246.0, education is Bachelors, education-num is 13.0, marital-status is Never-married, occupation is Adm-clerical, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, urn-country is United-States,
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1384 / 2000 rows...
#
#  Row 1385
#
#  Prompt to model age is 26.0, workclass is Private, fnlwgt is 289572.0, education is Prof-school, education-num is 10.0, marital-status is Married-civ-spouse, occupation is Adm-clerical, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 26.0, workclass is Private, fnlwgt is 289572.0, education is Prof-school, education-num is 10.0, marital-status is Married-civ-spouse, occupation is Adm-clerical, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1385 / 2000 rows...
#
#  Row 1386
#
#  Prompt to model age is 33.0, workclass is Private, fnlwgt is 161052.0, education is HS-grad, education-num is 11.0, marital-status is Never-married, occupation is Other-service, relationship is Other-relative, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 45.0, native-country is United-States,
# [Model Output] age is 33.0, workclass is Private, fnlwgt is 161052.0, education is HS-grad, education-num is 11.0, marital-status is Never-married, occupation is Other-service, relationship is Other-relative, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 45.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1386 / 2000 rows...
#
#  Row 1387
#
#  Prompt to model age is 24.0, workclass is Private, fnlwgt is 183374.0, education is Assoc-acdm, education-num is 9.0, marital-status is Never-married, occupation is Farming-fishing, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 36.0, native-country is United-States,
# [Model Output] age is 24.0, workclass is Private, fnlwgt is 183374.0, education is Assoc-acdm, education-num is 9.0, marital-status is Never-married, occupation is Farming-fishing, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 36.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1387 / 2000 rows...
#
#  Row 1388
#
#  Prompt to model age is 46.0, workclass is Local-gov, fnlwgt is 162422.0, education is Some-college, education-num is 10.0, marital-status is Married-civ-spouse, occupation is Sales, relationship is Own-child, race is Black, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 46.0, workclass is Local-gov, fnlwgt is 162422.0, education is Some-college, education-num is 10.0, marital-status is Married-civ-spouse, occupation is Sales, relationship is Own-child, race is Black, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: >50K
#  Completed labeling 1388 / 2000 rows...
#
#  Row 1389
#
#  Prompt to model age is 56.0, workclass is Private, fnlwgt is 277488.0, education is Bachelors, education-num is 11.0, marital-status is Separated, occupation is Exec-managerial, relationship is Unmarried, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 56.0, workclass is Private, fnlwgt is 277488.0, education is Bachelors, education-num is 11.0, marital-status is Separated, occupation is Exec-managerial, relationship is Unmarried, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: >50K
#  Completed labeling 1389 / 2000 rows...
#
#  Row 1390
#
#  Prompt to model age is 36.0, workclass is Private, fnlwgt is 152687.0, education is Some-college, education-num is 10.0, marital-status is Married-civ-spouse, occupation is Adm-clerical, relationship is Own-child, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 36.0, workclass is Private, fnlwgt is 152687.0, education is Some-college, education-num is 10.0, marital-status is Married-civ-spouse, occupation is Adm-clerical, relationship is Own-child, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: >50K
#  Completed labeling 1390 / 2000 rows...
#
#  Row 1391
#
#  Prompt to model age is 34.0, workclass is Private, fnlwgt is 147284.0, education is Some-college, education-num is 13.0, marital-status is Never-married, occupation is Prof-specialty, relationship is Other-relative, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 34.0, workclass is Private, fnlwgt is 147284.0, education is Some-college, education-num is 13.0, marital-status is Never-married, occupation is Prof-specialty, relationship is Other-relative, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1391 / 2000 rows...
#
#  Row 1392
#
#  Prompt to model age is 45.0, workclass is Private, fnlwgt is 287978.0, education is Some-college, education-num is 11.0, marital-status is Divorced, occupation is Other-service, relationship is Own-child, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 50.0, native-country is United-States,
# [Model Output] age is 45.0, workclass is Private, fnlwgt is 287978.0, education is Some-college, education-num is 11.0, marital-status is Divorced, occupation is Other-service, relationship is Own-child, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 50.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: >50K
#  Completed labeling 1392 / 2000 rows...
#
#  Row 1393
#
#  Prompt to model age is 27.0, workclass is Private, fnlwgt is 19513.0, education is Assoc-voc, education-num is 13.0, marital-status is Divorced, occupation is Prof-specialty, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is Mexico,
# [Model Output] age is 27.0, workclass is Private, fnlwgt is 19513.0, education is Assoc-voc, education-num is 13.0, marital-status is Divorced, occupation is Prof-specialty, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is Mexico, ipskimit, income is <=
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1393 / 2000 rows...
#
#  Row 1394
#
#  Prompt to model age is 26.0, workclass is Self-emp-not-inc, fnlwgt is 93535.0, education is Bachelors, education-num is 10.0, marital-status is Married-civ-spouse, occupation is Sales, relationship is Other-relative, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 26.0, workclass is Self-emp-not-inc, fnlwgt is 93535.0, education is Bachelors, education-num is 10.0, marital-status is Married-civ-spouse, occupation is Sales, relationship is Other-relative, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1394 / 2000 rows...
#
#  Row 1395
#
#  Prompt to model age is 38.0, workclass is Private, fnlwgt is 167969.0, education is HS-grad, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Farming-fishing, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 38.0, workclass is Private, fnlwgt is 167969.0, education is HS-grad, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Farming-fishing, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is >50
# No label found - switching to random label
# Randomly selected label: >50K
#  Completed labeling 1395 / 2000 rows...
#
#  Row 1396
#
#  Prompt to model age is 22.0, workclass is Local-gov, fnlwgt is 93925.0, education is HS-grad, education-num is 9.0, marital-status is Separated, occupation is Adm-clerical, relationship is Unmarried, race is Amer-Indian-Eskimo, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 22.0, workclass is Local-gov, fnlwgt is 93925.0, education is HS-grad, education-num is 9.0, marital-status is Separated, occupation is Adm-clerical, relationship is Unmarried, race is Amer-Indian-Eskimo, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1396 / 2000 rows...
#
#  Row 1397
#
#  Prompt to model age is 35.0, workclass is Private, fnlwgt is 134545.0, education is Some-college, education-num is 13.0, marital-status is Never-married, occupation is Handlers-cleaners, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 35.0, workclass is Private, fnlwgt is 134545.0, education is Some-college, education-num is 13.0, marital-status is Never-married, occupation is Handlers-cleaners, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, urn-country is United-States,
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1397 / 2000 rows...
#
#  Row 1398
#
#  Prompt to model age is 41.0, workclass is Private, fnlwgt is 131228.0, education is Assoc-voc, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Machine-op-inspct, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 14.0, native-country is United-States,
# [Model Output] age is 41.0, workclass is Private, fnlwgt is 131228.0, education is Assoc-voc, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Machine-op-inspct, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 14.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: >50K
#  Completed labeling 1398 / 2000 rows...
#
#  Row 1399
#
#  Prompt to model age is 38.0, workclass is Private, fnlwgt is 162624.0, education is HS-grad, education-num is 9.0, marital-status is Divorced, occupation is Prof-specialty, relationship is Wife, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 38.0, workclass is Private, fnlwgt is 162624.0, education is HS-grad, education-num is 9.0, marital-status is Divorced, occupation is Prof-specialty, relationship is Wife, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is >50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1399 / 2000 rows...
#
#  Row 1400
#
#  Prompt to model age is 51.0, workclass is Self-emp-not-inc, fnlwgt is 108837.0, education is HS-grad, education-num is 10.0, marital-status is Married-civ-spouse, occupation is Prof-specialty, relationship is Own-child, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 55.0, native-country is United-States,
# [Model Output] age is 51.0, workclass is Self-emp-not-inc, fnlwgt is 108837.0, education is HS-grad, education-num is 10.0, marital-status is Married-civ-spouse, occupation is Prof-specialty, relationship is Own-child, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 55.0, native-country is United-States, ipsknot, income is >50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1400 / 2000 rows...
#
#  Row 1401
#
#  Prompt to model age is 29.0, workclass is Private, fnlwgt is 71587.0, education is HS-grad, education-num is 14.0, marital-status is Married-civ-spouse, occupation is Other-service, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is China,
# [Model Output] age is 29.0, workclass is Private, fnlwgt is 71587.0, education is HS-grad, education-num is 14.0, marital-status is Married-civ-spouse, occupation is Other-service, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is China, urn-country is United-States,
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1401 / 2000 rows...
#
#  Row 1402
#
#  Prompt to model age is 39.0, workclass is Self-emp-not-inc, fnlwgt is 162035.0, education is HS-grad, education-num is 4.0, marital-status is Married-civ-spouse, occupation is Adm-clerical, relationship is Husband, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 39.0, workclass is Self-emp-not-inc, fnlwgt is 162035.0, education is HS-grad, education-num is 4.0, marital-status is Married-civ-spouse, occupation is Adm-clerical, relationship is Husband, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is >50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1402 / 2000 rows...
#
#  Row 1403
#
#  Prompt to model age is 56.0, workclass is Private, fnlwgt is 318915.0, education is Some-college, education-num is 12.0, marital-status is Never-married, occupation is Prof-specialty, relationship is Own-child, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 45.0, native-country is Columbia,
# [Model Output] age is 56.0, workclass is Private, fnlwgt is 318915.0, education is Some-college, education-num is 12.0, marital-status is Never-married, occupation is Prof-specialty, relationship is Own-child, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 45.0, native-country is Columbia, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1403 / 2000 rows...
#
#  Row 1404
#
#  Prompt to model age is 29.0, workclass is Private, fnlwgt is 241538.0, education is Bachelors, education-num is 9.0, marital-status is Never-married, occupation is Prof-specialty, relationship is Husband, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 30.0, native-country is United-States,
# [Model Output] age is 29.0, workclass is Private, fnlwgt is 241538.0, education is Bachelors, education-num is 9.0, marital-status is Never-married, occupation is Prof-specialty, relationship is Husband, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 30.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: >50K
#  Completed labeling 1404 / 2000 rows...
#
#  Row 1405
#
# ...
#
#  Row 1953
#
#  Prompt to model age is 22.0, workclass is Private, fnlwgt is 182987.0, education is HS-grad, education-num is 10.0, marital-status is Married-civ-spouse, occupation is Exec-managerial, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 22.0, workclass is Private, fnlwgt is 182987.0, education is HS-grad, education-num is 10.0, marital-status is Married-civ-spouse, occupation is Exec-managerial, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is >50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1953 / 2000 rows...
#
#  Row 1954
#
#  Prompt to model age is 27.0, workclass is Private, fnlwgt is 86492.0, education is Some-college, education-num is 14.0, marital-status is Divorced, occupation is Farming-fishing, relationship is Husband, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is Cuba,
# [Model Output] age is 27.0, workclass is Private, fnlwgt is 86492.0, education is Some-college, education-num is 14.0, marital-status is Divorced, occupation is Farming-fishing, relationship is Husband, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is Cuba, ipsknot is 0, income is
# No label found - switching to random label
# Randomly selected label: >50K
#  Completed labeling 1954 / 2000 rows...
#
#  Row 1955
#
#  Prompt to model age is 24.0, workclass is Local-gov, fnlwgt is 319631.0, education is HS-grad, education-num is 9.0, marital-status is Never-married, occupation is Other-service, relationship is Unmarried, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 24.0, workclass is Local-gov, fnlwgt is 319631.0, education is HS-grad, education-num is 9.0, marital-status is Never-married, occupation is Other-service, relationship is Unmarried, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1955 / 2000 rows...
#
#  Row 1956
#
#  Prompt to model age is 29.0, workclass is Private, fnlwgt is 152397.0, education is Some-college, education-num is 9.0, marital-status is Married-spouse-absent, occupation is Machine-op-inspct, relationship is Other-relative, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 29.0, workclass is Private, fnlwgt is 152397.0, education is Some-college, education-num is 9.0, marital-status is Married-spouse-absent, occupation is Machine-op-inspct, relationship is Other-relative, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1956 / 2000 rows...
#
#  Row 1957
#
#  Prompt to model age is 45.0, workclass is State-gov, fnlwgt is 169515.0, education is Some-college, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Transport-moving, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 45.0, workclass is State-gov, fnlwgt is 169515.0, education is Some-college, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Transport-moving, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1957 / 2000 rows...
#
#  Row 1958
#
#  Prompt to model age is 24.0, workclass is Self-emp-not-inc, fnlwgt is 143936.0, education is Some-college, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Adm-clerical, relationship is Own-child, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 30.0, native-country is United-States,
# [Model Output] age is 24.0, workclass is Self-emp-not-inc, fnlwgt is 143936.0, education is Some-college, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Adm-clerical, relationship is Own-child, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 30.0, native-country is United-States, ipsknot, income is >50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1958 / 2000 rows...
#
#  Row 1959
#
#  Prompt to model age is 34.0, workclass is Self-emp-not-inc, fnlwgt is 19513.0, education is Some-college, education-num is 13.0, marital-status is Never-married, occupation is Sales, relationship is Husband, race is Black, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 34.0, workclass is Self-emp-not-inc, fnlwgt is 19513.0, education is Some-college, education-num is 13.0, marital-status is Never-married, occupation is Sales, relationship is Husband, race is Black, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1959 / 2000 rows...
#
#  Row 1960
#
#  Prompt to model age is 41.0, workclass is Local-gov, fnlwgt is 167565.0, education is Bachelors, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Prof-specialty, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 41.0, workclass is Local-gov, fnlwgt is 167565.0, education is Bachelors, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Prof-specialty, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is >50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1960 / 2000 rows...
#
#  Row 1961
#
#  Prompt to model age is 49.0, workclass is Self-emp-not-inc, fnlwgt is 245821.0, education is HS-grad, education-num is 10.0, marital-status is Married-civ-spouse, occupation is Prof-specialty, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 49.0, workclass is Self-emp-not-inc, fnlwgt is 245821.0, education is HS-grad, education-num is 10.0, marital-status is Married-civ-spouse, occupation is Prof-specialty, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1961 / 2000 rows...
#
#  Row 1962
#
#  Prompt to model age is 30.0, workclass is Private, fnlwgt is 176453.0, education is 5th-6th, education-num is 10.0, marital-status is Divorced, occupation is Sales, relationship is Wife, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 30.0, workclass is Private, fnlwgt is 176453.0, education is 5th-6th, education-num is 10.0, marital-status is Divorced, occupation is Sales, relationship is Wife, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1962 / 2000 rows...
#
#  Row 1963
#
#  Prompt to model age is 49.0, workclass is Self-emp-inc, fnlwgt is 385053.0, education is HS-grad, education-num is 13.0, marital-status is Never-married, occupation is Craft-repair, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 35.0, native-country is Jamaica,
# [Model Output] age is 49.0, workclass is Self-emp-inc, fnlwgt is 385053.0, education is HS-grad, education-num is 13.0, marital-status is Never-married, occupation is Craft-repair, relationship is Husband, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 35.0, native-country is Jamaica, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1963 / 2000 rows...
#
#  Row 1964
#
#  Prompt to model age is 26.0, workclass is Private, fnlwgt is 30267.0, education is HS-grad, education-num is 10.0, marital-status is Never-married, occupation is Prof-specialty, relationship is Other-relative, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 26.0, workclass is Private, fnlwgt is 30267.0, education is HS-grad, education-num is 10.0, marital-status is Never-married, occupation is Prof-specialty, relationship is Other-relative, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: >50K
#  Completed labeling 1964 / 2000 rows...
#
#  Row 1965
#
#  Prompt to model age is 44.0, workclass is Local-gov, fnlwgt is 481164.0, education is Bachelors, education-num is 9.0, marital-status is Divorced, occupation is Craft-repair, relationship is Unmarried, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is Mexico,
# [Model Output] age is 44.0, workclass is Local-gov, fnlwgt is 481164.0, education is Bachelors, education-num is 9.0, marital-status is Divorced, occupation is Craft-repair, relationship is Unmarried, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is Mexico, ipskimit, income is <=
# No label found - switching to random label
# Randomly selected label: >50K
#  Completed labeling 1965 / 2000 rows...
#
#  Row 1966
#
#  Prompt to model age is 40.0, workclass is Self-emp-inc, fnlwgt is 218558.0, education is Some-college, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Other-service, relationship is Unmarried, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 40.0, workclass is Self-emp-inc, fnlwgt is 218558.0, education is Some-college, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Other-service, relationship is Unmarried, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1966 / 2000 rows...
#
#  Row 1967
#
#  Prompt to model age is 60.0, workclass is Private, fnlwgt is 61656.0, education is HS-grad, education-num is 10.0, marital-status is Married-civ-spouse, occupation is Prof-specialty, relationship is Wife, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 50.0, native-country is United-States,
# [Model Output] age is 60.0, workclass is Private, fnlwgt is 61656.0, education is HS-grad, education-num is 10.0, marital-status is Married-civ-spouse, occupation is Prof-specialty, relationship is Wife, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 50.0, native-country is United-States, ipsknot, income is >50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1967 / 2000 rows...
#
#  Row 1968
#
#  Prompt to model age is 35.0, workclass is Private, fnlwgt is 116722.0, education is 5th-6th, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Adm-clerical, relationship is Own-child, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 45.0, native-country is United-States,
# [Model Output] age is 35.0, workclass is Private, fnlwgt is 116722.0, education is 5th-6th, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Adm-clerical, relationship is Own-child, race is White, sex is Female, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 45.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1968 / 2000 rows...
#
#  Row 1969
#
#  Prompt to model age is 22.0, workclass is Local-gov, fnlwgt is 203948.0, education is Some-college, education-num is 10.0, marital-status is Never-married, occupation is Prof-specialty, relationship is Husband, race is Other, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 22.0, workclass is Local-gov, fnlwgt is 203948.0, education is Some-college, education-num is 10.0, marital-status is Never-married, occupation is Prof-specialty, relationship is Husband, race is Other, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1969 / 2000 rows...
#
#  Row 1970
#
#  Prompt to model age is 29.0, workclass is Private, fnlwgt is 226443.0, education is Some-college, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Sales, relationship is Own-child, race is Black, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 29.0, workclass is Private, fnlwgt is 226443.0, education is Some-college, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Sales, relationship is Own-child, race is Black, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1970 / 2000 rows...
#
#  Row 1971
#
#  Prompt to model age is 39.0, workclass is Private, fnlwgt is 19513.0, education is Bachelors, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Sales, relationship is Unmarried, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,
# [Model Output] age is 39.0, workclass is Private, fnlwgt is 19513.0, education is Bachelors, education-num is 9.0, marital-status is Married-civ-spouse, occupation is Sales, relationship is Unmarried, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States, ipsknot, income is <=50
# No label found - switching to random label
# Randomly selected label: <=50K
#  Completed labeling 1971 / 2000 rows...
#
#  Row 1972
#
#  Prompt to model age is 37.0, workclass is Private, fnlwgt is 84420.0, education is Bachelors, education-num is 13.0, marital-status is Never-married, occupation is Adm-clerical, relationship is Not-in-family, race is White, sex is Male, capital-gain is 0.0, capital-loss is 0.0, hours-per-week is 40.0, native-country is United-States,

# %%
import warnings
warnings.filterwarnings('ignore')

# STEP 4
# ----------  TSTR: Train on Synthetic, Test on Real ----------
print("\nRunning TSTR (Train on Synthetic Test on Real)…")
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.dummy import DummyClassifier

# Copies real and synthetic data for processing
real = df.copy()
real_y = real[LABEL]
real_X = real.drop(columns=[LABEL])

syn = syn_df.copy()
syn_y = syn[LABEL].fillna("<=50K")
syn_X = syn.drop(columns=[LABEL])

print("Real and synthetic datasets loaded and separated into features/labels.")

# Identifies categorical/numerical columns from REAL schema
cat_cols = [c for c in real_X.columns if real_X[c].dtype == 'object']
num_cols = [c for c in real_X.columns if c not in cat_cols]
print(f"Found {len(cat_cols)} categorical and {len(num_cols)} numerical columns.")

for col in num_cols:
    real_X[col] = pd.to_numeric(real_X[col], errors="coerce")
    syn_X[col]  = pd.to_numeric(syn_X[col],  errors="coerce")

print("\nFilling NaNs with real-data medians...")
real_medians = real_X[num_cols].median(numeric_only=True)
real_X[num_cols] = real_X[num_cols].fillna(real_medians)
syn_X[num_cols]  = syn_X[num_cols].fillna(real_medians)


for col in cat_cols:
    real_X[col] = real_X[col].astype(str)       # ensures all categorical columns are strings
    syn_X[col]  = syn_X[col].astype(str)


print("Finsihed data cleaning now building the preprocessing pipeline...")

pre = ColumnTransformer([
    ("cat", OneHotEncoder(handle_unknown="ignore"), cat_cols),
    ("num", "passthrough", num_cols),
])


# --- Improvement: Creating the Classifier Only After Checking Labels (this helps switch the model to DummyClassifier if needed) ---
print("\nNow encoding the synthetic labels.")
label_vals = sorted(df[LABEL].astype(str).unique().tolist())        # builds the label_map dynamically instead of hardcoding values
if len(label_vals) != 2:
    raise ValueError(f"Expected binary labels, got: {label_vals}")  # ensures the real dataset is binary; if not, raise so user can handle it.


label_map = {label_vals[0]: 0, label_vals[1]: 1}    # using map textual labels (0/1) based on sorted order
inv_label_map = {0: label_vals[0], 1: label_vals[1]}
print("label_map =", label_map)

syn_y_enc = syn_y.map(label_map)
if syn_y_enc.isna().any():                      # if any unexpected labels slipped into synthetic data, snap them to the majority class
    print("\nWarning: Some synthetic labels were invalid and could not be mapped. Snapping to majority class.")
    maj = syn_y_enc.value_counts().idxmax()
    syn_y_enc = syn_y_enc.fillna(maj).astype(int)
else:
    syn_y_enc = syn_y_enc.astype(int)
print("Synthetic labels encoded...")


if syn_y_enc.nunique() == 1:        # choosing classifier based on encoded synthetic-label cardinality.
    print("\nWarning: Synthetic data contains only one unique label. XGBoost cannot train on this.")
    print("Switching to DummyClassifier (always predicts majority class) for TSTR evaluation.")
    clf = DummyClassifier(strategy="most_frequent")
else:
    clf = XGBClassifier(
        n_estimators=200,
        max_depth=6,
        learning_rate=0.1,
        subsample=0.8,
        colsample_bytree=0.8,
        tree_method="hist",
        n_jobs=4
    )

pipe = Pipeline([("pre", pre), ("clf", clf)])
print("Preprocessing and model processing...")
print("\n")


# Real test split
_, X_test_real, _, y_test_real = train_test_split(
    real_X, real_y, test_size=0.2, stratify=real_y, random_state=42
)
y_test_real_enc = y_test_real.map(label_map).astype(int)

print("Training of synthetic data...")
pipe.fit(syn_X, syn_y_enc)

print("Predicting on real data now...")
pred_enc = pipe.predict(X_test_real).astype(int)
acc = accuracy_score(y_test_real_enc, pred_enc)
print(f"TSTR Accuracy ({clf.__class__.__name__} trained on synthetic, tested on real): {acc:.3f}")


# Predicted label distribution in natural labels (optional)
pred_labels = pd.Series(pred_enc).map(inv_label_map).value_counts(normalize=True).rename("pred_label_share")
print("\nPredicted label share on real test set:")
print(pred_labels.to_string())

print("Majority baseline accuracy:", (y_test_real_enc.value_counts().max() / len(y_test_real_enc)))
print("\n")
print("Successfully fine-tuned LM, synthetic CSV, and a TSTR score.")
# Out:
# Running TSTR (Train on Synthetic Test on Real)…
# Real and synthetic datasets loaded and separated into features/labels.
# Found 0 categorical and 14 numerical columns.
#
# Filling NaNs with real-data medians...
# Finsihed data cleaning now building the preprocessing pipeline...
#
# Now encoding the synthetic labels.
# label_map = {'<=50K': 0, '>50K': 1}
# Synthetic labels encoded...
# Preprocessing and model processing...
#
#
# Training of synthetic data...
# Predicting on real data now...
# TSTR Accuracy (XGBClassifier trained on synthetic, tested on real): 0.705
#
# Predicted label share on real test set:
# <=50K    0.94
# >50K     0.06
# Majority baseline accuracy: 0.745
#
#
# Successfully fine-tuned LM, synthetic CSV, and a TSTR score.

# %% [markdown]
# **Evaluations**

# %%
import numpy as np
import pandas as pd
from typing import Tuple, Optional


from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.linear_model import LogisticRegression
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Define real_df and synth_df
real_df = real_X
synth_df = syn_X

# Converts the existing DataFrames to aligned numeric matrices
X_real = real_df.select_dtypes(include=[np.number]).copy()
X_synth = synth_df.select_dtypes(include=[np.number]).copy()

# Ensures same columns and order
common_cols = [c for c in X_real.columns if c in X_synth.columns]
X_real = X_real[common_cols].to_numpy()
X_synth = X_synth[common_cols].to_numpy()

print("X_real and X_synth ready:", X_real.shape, X_synth.shape)
# Out:
# X_real and X_synth ready: (2000, 14) (2000, 14)

# %%
# -- Set Up --
try:
    from xgboost import XGBClassifier
    _HAS_XGB = True
except Exception:
    _HAS_XGB = False
from sklearn.linear_model import LogisticRegression

def _as_array(X) -> np.ndarray:
    if isinstance(X, pd.DataFrame):
        return X.values
    X = np.asarray(X)
    if X.ndim != 2:
        raise ValueError("Expected 2D array for features.")
    return X

def _ensure_numeric_2d(X_real, X_synth) -> Tuple[np.ndarray, np.ndarray]:
  '''Ensures that all data is clean and formatted properly '''
  Xr = _as_array(X_real)
  Xs = _as_array(X_synth)

  # basic shape checks
  if Xr.shape[1] != Xs.shape[1]:
      raise ValueError(f"Column mismatch: X_real has {Xr.shape[1]} cols, X_synth has {Xs.shape[1]}.")

  # impute NaN/inf
  Xr = np.where(np.isfinite(Xr), Xr, np.nan)
  Xs = np.where(np.isfinite(Xs), Xs, np.nan)

  imputer = SimpleImputer(strategy="most_frequent")
  Xr = imputer.fit_transform(Xr)
  Xs = imputer.transform(Xs)

  Xr = Xr.astype(float)
  Xs = Xs.astype(float)

  print("Preprocessing complete for numeric 2D arrays.")
  return Xr, Xs

def _safe_k(n: int, k: int) -> int:
  '''Ensure kNN uses k <= n-1 and k>=1.'''
  if n <= 1:
      raise ValueError("Not enough rows for kNN metrics.")
  return max(1, min(k, max(1, n-1)))

def _kth_nn_radius(X: np.ndarray, k: int = 5) -> np.ndarray:
  '''Computes the k-th nearest neighbor radius for each row'''
  k_adj = _safe_k(len(X), k)
  nn = NearestNeighbors(n_neighbors=k_adj+1).fit(X)
  dists, _ = nn.kneighbors(X)     # excludes self; picks the k-th nearest neighbor
  return dists[:, -1]

# --- Inverse-KL with numeric or categorical columns ---
def _safe_probs(counts: np.ndarray) -> np.ndarray:
  '''Normalizses the count arrays '''
  counts = np.asarray(counts, dtype=float)
  s = counts.sum()
  if s <= 0:
      return np.ones_like(counts) / len(counts)
  return counts / s

def _inv_kl_1d(real_col, synth_col, max_bins: int = 30) -> float:
    eps = 1e-8
    try:
        real_num = pd.to_numeric(pd.Series(real_col), errors="raise")
        synth_num = pd.to_numeric(pd.Series(synth_col), errors="raise")
        is_numeric = True
    except Exception:
        is_numeric = False

    if is_numeric:
        real = real_num.astype(float).values
        synth = pd.Series(synth_num).astype(float).values

        q25, q75 = np.nanpercentile(real, [25, 75])
        iqr = max(q75 - q25, eps)
        bin_width = 2 * iqr * (len(real) ** (-1/3))
        if not np.isfinite(bin_width) or bin_width <= 0:
            bins = min(max_bins, max(5, int(np.sqrt(max(len(real), 5)))))
        else:
            rng = np.nanmax(real) - np.nanmin(real)
            bins = int(np.clip(rng / max(bin_width, eps), 5, max_bins))

        hist_r, edges = np.histogram(real, bins=bins)
        hist_s, _ = np.histogram(synth, bins=edges)

        p = _safe_probs(hist_r + 1)  # Laplace smoothing
        q = _safe_probs(hist_s + 1)
    else:
        r_counts = pd.Series(real_col).astype("object").value_counts()
        s_counts = pd.Series(synth_col).astype("object").value_counts()
        cats = pd.Index(sorted(set(r_counts.index).union(set(s_counts.index))))
        r = (r_counts.reindex(cats).fillna(0).values + 1)
        s = (s_counts.reindex(cats).fillna(0).values + 1)
        p = r / r.sum()
        q = s / s.sum()

    kl = float(np.sum(p * np.log((p + eps) / (q + eps))))
    inv_kl = 1.0 / (1.0 + max(kl, 0.0))  # higher is better
    return inv_kl

def inverse_kl_dataframe(real_df: pd.DataFrame, synth_df: pd.DataFrame):
  '''Inverse-KL on an entire dataframe'''
  if list(real_df.columns) != list(synth_df.columns):
      raise ValueError("Inverse-KL: dataframes must have the same columns in the same order.")
  print("Computing inverse-KL for each column...")
  vals = []
  for c in real_df.columns:
      vals.append(_inv_kl_1d(real_df[c].values, synth_df[c].values))
  return float(np.mean(vals)), pd.Series(vals, index=real_df.columns).sort_values(ascending=True)

print("Expecting variables X_real and X_synth to be defined (numeric, 2D).")
# Out:
# Expecting variables X_real and X_synth to be defined (numeric, 2D).

# %%
# --- DISCRIMINATOR SCORE (real vs synthetic) ---
print("\n--- DISCRIMINATOR SCORE (Real vs Synthetic Classifier) ---")
Xr, Xs = _ensure_numeric_2d(X_real, X_synth)
X_disc = np.vstack([Xr, Xs])
y_disc = np.concatenate([np.ones(len(Xr), dtype=int), np.zeros(len(Xs), dtype=int)])
test_size = 0.3 if len(X_disc) >= 20 else 0.5
print(f" Splitting data into train/test with test_size={test_size:.2f}")
X_tr, X_te, y_tr, y_te = train_test_split(X_disc, y_disc, test_size=test_size, stratify=y_disc, random_state=42)
print(f" Train size: {X_tr.shape[0]} | Test size: {X_te.shape[0]}")

if _HAS_XGB:
    clf = XGBClassifier(
        n_estimators=300, max_depth=6, subsample=0.8, colsample_bytree=0.8,
        learning_rate=0.05, reg_lambda=1.0, n_jobs=-1, random_state=42
    )
else:
    clf = LogisticRegression(max_iter=2000, n_jobs=-1, solver="lbfgs")

clf.fit(X_tr, y_tr)
print("\nModel training complete.")

print("Predicting labels on test set...")
y_pred = clf.predict(X_te)

try:
    if hasattr(clf, "predict_proba"):
        y_prob = clf.predict_proba(X_te)[:, 1]
    elif hasattr(clf, "decision_function"):
        from sklearn.metrics import roc_curve
        scores = clf.decision_function(X_te)
        ranks = pd.Series(scores).rank(method="average").values
        y_prob = (ranks - ranks.min()) / (ranks.max() - ranks.min() + 1e-8)
    else:
      print("No probability scores available from this classifier.")
      y_prob = None
except Exception as e:
  print(f"Error computing probabilities: {e}")
  y_prob = None

acc = accuracy_score(y_te, y_pred)
if y_prob is not None:
    auc = roc_auc_score(y_te, y_prob)
    print(f"\nDiscriminator score — Accuracy: {acc:.3f}   AUC: {auc:.3f}   (~0.50 acc is better)")
else:
    print(f"\nDiscriminator score — Accuracy: {acc:.3f}   (~0.50 is better; AUC not available)")
# Out:
# --- DISCRIMINATOR SCORE (Real vs Synthetic Classifier) ---
# Preprocessing complete for numeric 2D arrays.
#  Splitting data into train/test with test_size=0.30
#  Train size: 2800 | Test size: 1200
#
# Model training complete.
# Predicting labels on test set...
#
# Discriminator score — Accuracy: 0.662   AUC: 0.720   (~0.50 acc is better)

# %%
# DENSITY (kNN; higher is better if synth lies in real neighborhoods)
print("\n--- DENSITY (kNN ) ---")
Xr, Xs = _ensure_numeric_2d(X_real, X_synth)

# Choose k value and adjust for data size
k = 5
k_real = _safe_k(len(Xr), k)

scaler = StandardScaler().fit(Xr)  # scale by real distribution
R = scaler.transform(Xr)
S = scaler.transform(Xs)

r_real = _kth_nn_radius(R, k=k_real)

nn_real = NearestNeighbors(n_neighbors=1).fit(R)
d_sr, idx_sr = nn_real.kneighbors(S, return_distance=True)
d_sr = d_sr.ravel()
idx_sr = idx_sr.ravel()

hits = (d_sr <= r_real[idx_sr]).astype(float)
density_score = float(hits.mean())
print(f"Density (k={k_real}) = {density_score:.3f}   # higher = synthetic near real localities")
# Out:
# --- DENSITY (kNN ) ---
# Preprocessing complete for numeric 2D arrays.
# Density (k=5) = 0.930   # higher = synthetic near real localities

# %%
# COVERAGE (kNN; higher is better if synthetic spans real space)
print("\n--- CONVERGE (kNN ) ---")
Xr, Xs = _ensure_numeric_2d(X_real, X_synth)

k = 5
k_synth = _safe_k(len(Xs), k)

scaler = StandardScaler().fit(Xr)  # measure in real-scaled space
R = scaler.transform(Xr)
S = scaler.transform(Xs)

r_synth = _kth_nn_radius(S, k=k_synth)

nn_synth = NearestNeighbors(n_neighbors=1).fit(S)
d_rs, idx_rs = nn_synth.kneighbors(R, return_distance=True)
d_rs = d_rs.ravel()
idx_rs = idx_rs.ravel()

covered = (d_rs <= r_synth[idx_rs]).astype(float)
coverage_score = float(covered.mean())
print(f"Coverage (k={k_synth}) = {coverage_score:.3f}   # higher = synthetic covers real modes")
# Out:
# --- CONVERGE (kNN ) ---
# Preprocessing complete for numeric 2D arrays.
# Coverage (k=5) = 0.818   # higher = synthetic covers real modes

# %%
# INVERSE KL DIVERGENCE (per-feature, averaged)

print("\n--- INVERSE KL DIVERGENCE ---")
def _to_aligned_dataframes(X_real, X_synth) -> Tuple[pd.DataFrame, pd.DataFrame]:
  ''' Ensures X_real and X_synth are in the same format and aligned column-wise.
    If already DataFrames, checks column order.
    If arrays, creates default column names.'''

  if isinstance(X_real, pd.DataFrame) and isinstance(X_synth, pd.DataFrame):
      if list(X_real.columns) != list(X_synth.columns):
          raise ValueError("Inverse-KL: DataFrames must share identical columns in order.")
      return X_real.reset_index(drop=True), X_synth.reset_index(drop=True)

  print("Converting arrays to DataFrames...")
  Xr, Xs = _ensure_numeric_2d(X_real, X_synth)
  cols = [f"f{i}" for i in range(Xr.shape[1])]
  return pd.DataFrame(Xr, columns=cols), pd.DataFrame(Xs, columns=cols)

print("Aligning columns across real and synthetic data...")
real_df, synth_df = _to_aligned_dataframes(X_real, X_synth)

print("Calculating per-feature inverse KL divergence scores...")
inv_kl_mean, inv_kl_per_col = inverse_kl_dataframe(real_df, synth_df)

print(f"\nInverse KL (mean across features) = {inv_kl_mean:.3f}   # higher = closer per-feature distributions")
# Out:
# --- INVERSE KL DIVERGENCE ---
# Aligning columns across real and synthetic data...
# Converting arrays to DataFrames...
# Preprocessing complete for numeric 2D arrays.
# Calculating per-feature inverse KL divergence scores...
# Computing inverse-KL for each column...
#
# Inverse KL (mean across features) = 0.942   # higher = closer per-feature distributions

# %%
# --- Collects metric values from previous cells ---
results = {
    'Discriminator score': acc if 'acc' in locals() else None,
    'Inverse KL': inv_kl_mean if 'inv_kl_mean' in locals() else None,
    'Density': density_score if 'density_score' in locals() else None,
    'Coverage': coverage_score if 'coverage_score' in locals() else None
}

for metric, value in results.items():
    df = pd.DataFrame({'Pred-LLM': [value]})
    print(f"\n{metric}")
    display(df)
# Out:
# Discriminator score
#    Pred-LLM
# 0    0.6625
# Inverse KL
#    Pred-LLM
# 0  0.941549
# Density
#    Pred-LLM
# 0    0.9305
# Coverage
#    Pred-LLM
# 0    0.8175

# %%
# - Prepares the data for plotting ---
df_results = pd.DataFrame(list(results.items()), columns=["Metric", "Pred-LLM"])

plt.figure(figsize=(7, 4))
sns.barplot(data=df_results, x="Metric", y="Pred-LLM", color="blue")
plt.title("Pred-LLM Evaluation Metrics")
plt.ylim(0, 1)
plt.ylabel("Score")
plt.xlabel("")
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()
