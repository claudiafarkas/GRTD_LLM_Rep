# %% [markdown]
# <a href="https://colab.research.google.com/github/claudiafarkas/GRTD_LLM_Rep/blob/main/pred_llm_mini_bank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Note: Decided to run the replication code in the colab envirnment due to gpu restrictions on our peronal computers. Therefore, we also had to reduce some paremeters (as specified in step 1) during the replication in order to achive similar results to the paper.

# %%
import os, re, random
import pandas as pd
from sklearn.datasets import fetch_openml
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    Trainer,
    TrainingArguments,
)
import torch

# %%
# ---------- GLOBAl CONFIGS -----------
os.environ.setdefault("TOKENIZERS_PARALLELISM", "false")
random.seed(42)

# Setting DEVICE to be dynamic (uses GPU if available, else CPU)
if torch.cuda.is_available():
    torch.set_default_device("cuda")
    DEVICE = torch.device("cuda")
    print("Using GPU")
else:
    torch.set_default_device("cpu")
    DEVICE = torch.device("cpu")
    print("Using CPU - GPU is currently unavilable")

# --- Values Taken from Paper Specifications ---
MODEL_NAME = "distilgpt2"   # stays no matter the dataset chosen
MAX_LEN = 256               # not explicitly specified but is assumed
BATCH_SIZE = 32             # (32 is specified in the paper - stays no matter the dataset chosen)
EPOCHS = 10                 # (50 is specified in the paper - stays no matter the dataset chosen)
N_SAMPLES = 2000            # (5000 specified in the paper for the adult dataset) # rows we want in our synthetic dataset

# --- Loading the Two Chosen Datasets ---
# -- Comment out the one not in use --
# - Adult Dataset -
# DATASET_NAME = "adult"
# LABEL_ORIG = "class"
# LABEL_NEW = "income"
# CSV_OUT = "data/synthetic_adult_predllm_mini.csv"

# - Bank Dataset -
DATASET_NAME = "Bank"
CSV_OUT = "data/synthetic_bank_predllm_mini.csv"

print(f" --- Loading Dataset: {DATASET_NAME} --- ")
chosen_dataset = fetch_openml(name="bank-marketing", as_frame=True)
df = chosen_dataset.frame
LABEL = "Class"  # Use the actual label column name from your printout
df = df.dropna().reset_index(drop=True)

df = df.sample(n=min(2000, len(df)), random_state=42).reset_index(drop=True) # keeps a smaller subset (computationally easier on our laptops)

FEATURES = [c for c in df.columns if c != LABEL]    # creates a list of column names but excludes the target LABEL value, this is bc we are trying to predict that label

print(df.columns)
# Out:
# Using GPU
#  --- Loading Dataset: Bank ---
# /usr/local/lib/python3.12/dist-packages/sklearn/datasets/_openml.py:323: UserWarning: Multiple active versions of the dataset matching the name bank-marketing exist. Versions may be fundamentally different, returning version 1. Available versions:
# - version 1, status: active
#   url: https://www.openml.org/search?type=data&id=1461
# - version 2, status: active
#   url: https://www.openml.org/search?type=data&id=1558
#
#   warn(warning_msg)
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'Class'],
#       dtype='object')

# %%
# STEP 1
# ---------- Serialization helpers: Fine-tune with Y last + Permute - learn p(Y｜X） ----------
def serialize_row(row: pd.Series, feature_order, label_col: str) -> str:
    ''' Used to help the model understand the data.
        The input data is currently a key value pair,
        but inorder for it to actually understand and process it, it converts it to string format.
    '''
    parts = []
    for col in feature_order:
        parts.append(f"{col} is {str(row[col]).strip()}")
    parts.append(f"{label_col} is {str(row[label_col]).strip()}")
    return ", ".join(parts)

def build_training_corpus(df: pd.DataFrame, features, label_col, permute_ratio=0.7):
    ''' Used to shuffle the order around of the passed in serialized string but
    makes sure that the LABEL value is always last.
        This helps with the training process
    '''
    texts = []
    for _, r in df.iterrows():
        texts.append(serialize_row(r, features, label_col))
        if random.random() < permute_ratio:
            fperm = features[:]
            random.shuffle(fperm)
            texts.append(serialize_row(r, fperm, label_col))
    return texts

print("Building training texts…")
train_texts = build_training_corpus(df, FEATURES, LABEL, permute_ratio=0.7)
print(train_texts)

# ---------- Tokenization + Training ----------
tok = AutoTokenizer.from_pretrained(MODEL_NAME)
if tok.pad_token is None:
    tok.pad_token = tok.eos_token

enc = tok(
    train_texts,
    padding=True,
    truncation=True,
    max_length=MAX_LEN,
    return_tensors="pt",
)

class TxtDataset(torch.utils.data.Dataset):
    def __init__(self, encodings):
        self.enc = encodings
    def __len__(self):
        return self.enc["input_ids"].shape[0]
    def __getitem__(self, i):
        return {
            "input_ids": self.enc["input_ids"][i],
            "attention_mask": self.enc["attention_mask"][i],
            "labels": self.enc["input_ids"][i],
        }

ds = TxtDataset(enc)

# --- Model Specifications ---
model = AutoModelForCausalLM.from_pretrained(MODEL_NAME)
model.to(DEVICE)

# --- Training Specifications ---
# -- Described earlier in the code --
args = TrainingArguments(
    output_dir="runs/predllm-mini",
    per_device_train_batch_size=BATCH_SIZE,
    gradient_accumulation_steps=8,
    num_train_epochs=EPOCHS,
    learning_rate=5e-5,
    weight_decay=0.01,
    fp16=torch.cuda.is_available(),
    bf16=False,
    logging_steps=50,
    save_steps=5000,
    save_total_limit=1,
    report_to=[],
    no_cuda=not torch.cuda.is_available(),  # only disable CUDA if GPU isn't available
    dataloader_pin_memory=False,
    # use_mps_device=False,     # only needed if running on a mac
)

print("Initializing the trainer...")
trainer = Trainer(model=model, args=args, train_dataset=ds)   # initializes the trainer
print(trainer)

print("Fine-tuning (CPU/GPU - depending on which one is selected to run on)")
trainer.train()   # startes training
model = trainer.model
model.to(DEVICE)
model.eval()

print("Model is on device - ", next(model.parameters()).device)

# --- Saves Finetuning Data to the 'runs' Folder ---
os.makedirs("runs/predllm-mini/model", exist_ok=True)
trainer.save_model("runs/predllm-mini/model")
tok.save_pretrained("runs/predllm-mini/model")
# Out:
# Building training texts…
# ['V1 is 40, V2 is blue-collar, V3 is married, V4 is secondary, V5 is no, V6 is 580, V7 is yes, V8 is no, V9 is unknown, V10 is 16, V11 is may, V12 is 192, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, Class is 1', 'V8 is no, V11 is may, V6 is 580, V7 is yes, V16 is unknown, V15 is 0, V14 is -1, V10 is 16, V9 is unknown, V2 is blue-collar, V3 is married, V13 is 1, V4 is secondary, V5 is no, V12 is 192, V1 is 40, Class is 1', 'V1 is 47, V2 is services, V3 is single, V4 is secondary, V5 is no, V6 is 3644, V7 is no, V8 is no, V9 is unknown, V10 is 9, V11 is jun, V12 is 83, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, Class is 1', 'V10 is 9, V13 is 2, V6 is 3644, V2 is services, V16 is unknown, V3 is single, V5 is no, V8 is no, V14 is -1, V7 is no, V15 is 0, V11 is jun, V12 is 83, V4 is secondary, V9 is unknown, V1 is 47, Class is 1', 'V1 is 25, V2 is student, V3 is single, V4 is tertiary, V5 is no, V6 is 538, V7 is yes, V8 is no, V9 is cellular, V10 is 20, V11 is apr, V12 is 226, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, Class is 1', 'V15 is 0, V9 is cellular, V1 is 25, V8 is no, V16 is unknown, V3 is single, V10 is 20, V14 is -1, V11 is apr, V7 is yes, V12 is 226, V2 is student, V6 is 538, V13 is 1, V4 is tertiary, V5 is no, Class is 1', 'V1 is 42, V2 is management, V3 is married, V4 is tertiary, V5 is no, V6 is 1773, V7 is no, V8 is no, V9 is cellular, V10 is 9, V11 is apr, V12 is 311, V13 is 1, V14 is 336, V15 is 1, V16 is failure, Class is 1', 'V16 is failure, V14 is 336, V7 is no, V3 is married, V8 is no, V12 is 311, V1 is 42, V15 is 1, V4 is tertiary, V6 is 1773, V10 is 9, V11 is apr, V5 is no, V9 is cellular, V2 is management, V13 is 1, Class is 1', 'V1 is 56, V2 is management, V3 is married, V4 is tertiary, V5 is no, V6 is 217, V7 is no, V8 is yes, V9 is cellular, V10 is 21, V11 is jul, V12 is 121, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, Class is 1', 'V1 is 28, V2 is blue-collar, V3 is married, V4 is secondary, V5 is no, V6 is 1134, V7 is no, V8 is no, V9 is cellular, V10 is 9, V11 is feb, V12 is 130, V13 is 3, V14 is -1, V15 is 0, V16 is unknown, Class is 1', 'V9 is cellular, V8 is no, V12 is 130, V2 is blue-collar, V1 is 28, V7 is no, V10 is 9, V5 is no, V4 is secondary, V16 is unknown, V13 is 3, V3 is married, V6 is 1134, V14 is -1, V11 is feb, V15 is 0, Class is 1', 'V1 is 24, V2 is management, V3 is single, V4 is tertiary, V5 is no, V6 is 1085, V7 is no, V8 is yes, V9 is cellular, V10 is 7, V11 is may, V12 is 95, V13 is 6, V14 is -1, V15 is 0, V16 is unknown, Class is 1', 'V15 is 0, V10 is 7, V2 is management, V8 is yes, V3 is single, V16 is unknown, V7 is no, V14 is -1, V1 is 24, V6 is 1085, V4 is tertiary, V9 is cellular, V12 is 95, V11 is may, V5 is no, V13 is 6, Class is 1', 'V1 is 37, V2 is admin., V3 is single, V4 is secondary, V5 is no, V6 is 127, V7 is no, V8 is no, V9 is cellular, V10 is 23, V11 is mar, V12 is 83, V13 is 4, V14 is -1, V15 is 0, V16 is unknown, Class is 1', 'V1 is 37, V6 is 127, V15 is 0, V9 is cellular, V10 is 23, V12 is 83, V2 is admin., V5 is no, V3 is single, V13 is 4, V14 is -1, V7 is no, V8 is no, V16 is unknown, V4 is secondary, V11 is mar, Class is 1', 'V1 is 30, V2 is blue-collar, V3 is single, V4 is secondary, V5 is no, V6 is 3, V7 is yes, V8 is no, V9 is cellular, V10 is 25, V11 is jul, V12 is 51, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, Class is 1', 'V1 is 38, V2 is technician, V3 is single, V4 is secondary, V5 is no, V6 is 258, V7 is no, V8 is yes, V9 is unknown, V10 is 20, V11 is jun, V12 is 587, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, Class is 1', 'V5 is no, V13 is 2, V10 is 20, V11 is jun, V4 is secondary, V6 is 258, V7 is no, V14 is -1, V15 is 0, V12 is 587, V1 is 38, V2 is technician, V16 is unknown, V9 is unknown, V3 is single, V8 is yes, Class is 1', 'V1 is 33, V2 is blue-collar, V3 is single, V4 is secondary, V5 is no, V6 is 498, V7 is no, V8 is no, V9 is cellular, V10 is 30, V11 is apr, V12 is 301, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# Initializing the trainer...
# <transformers.trainer.Trainer object at 0x7d29fdf42d20>
# Fine-tuning (CPU/GPU - depending on which one is selected to run on)
# `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
#     <div>
#
#       <progress value='140' max='140' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [140/140 03:24, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.184000</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.641400</td>
#     </tr>
#   </tbody>
# </table><p>
# Model is on device -  cuda:0
# ('runs/predllm-mini/model/tokenizer_config.json',
#  'runs/predllm-mini/model/special_tokens_map.json',
#  'runs/predllm-mini/model/vocab.json',
#  'runs/predllm-mini/model/merges.txt',
#  'runs/predllm-mini/model/added_tokens.json',
#  'runs/predllm-mini/model/tokenizer.json')

# %%
# STEP 2
# ---------- Feature conditional Sampling phase: generate X ONLY ----------
print("\nSampling synthetic features (X) …")

def sample_feature_value(col):
    # simple marginal sampler from real data
    return random.choice(df[col].tolist())

def generate_features_only(start_feature, start_value, max_new_tokens=120):
    """
    Start with "feature is value" and let the model continue generating
    features. If we see the label field begin (`, income is`), we cut before it.
    Returns a partial dict of generated features.
    """
    start = f"{start_feature} is {start_value}"
    prompt = start
    inputs = tok(prompt, return_tensors="pt").to(model.device)

    out = model.generate(
        **inputs,
        max_new_tokens=max_new_tokens,
        do_sample=True,
        temperature=0.8,
        top_p=0.95,
        pad_token_id=tok.eos_token_id,
        eos_token_id=tok.eos_token_id,
    )
    text = tok.decode(out[0], skip_special_tokens=True)
    print(f"[Raw Output] {text}")

    # Stop at the beginning of label if present
    stop_idx = text.find(f", {LABEL} is")
    if stop_idx != -1:
        text = text[:stop_idx]
        print(f"[Truncated at label] {text}")

    # Parse comma separated "name is value" clauses
    clauses = [c.strip() for c in text.split(",")]
    seen = {}
    for c in clauses:
        m = re.match(r"^([^,]+?)\s+is\s+(.+)$", c)
        if not m:
            continue
        name = m.group(1).strip()
        val = m.group(2).strip()
        if name in FEATURES and name not in seen:
            seen[name] = val
        if len(seen) == len(FEATURES):
            break
    print(f"[Parsed Features] {seen}")
    return seen

synthetic_X = []
for _ in range(N_SAMPLES):
    f0 = random.choice(FEATURES)        # randomly selects a feature
    v0 = sample_feature_value(f0)       # randomly selects a value
    feats = generate_features_only(f0, v0)
    # Fill any missing features from real marginals to keep schema complete
    for col in FEATURES:
        if col not in feats:
            feats[col] = sample_feature_value(col)
            print(f"[Filled Missing Feature] {col} with {feats[col]}")
    synthetic_X.append(feats)

print(f"Generated {len(synthetic_X)} synthetic feature rows.")
# Out:
# Streaming output truncated to the last 5000 lines.
# [Filled Missing Feature] V1 with 49
# [Filled Missing Feature] V8 with no
# [Filled Missing Feature] V9 with unknown
# [Filled Missing Feature] V15 with 0
# [Raw Output] V13 is 2, V9 is cellular, V7 is no, V1 is 44, V11 is jul, V12 is 178, V10 is 12, V4 is tertiary, V1 is 32, V16 is unknown, V7 is yes, V10 is 7, V13 is 2, V1 is 36, V6 is 916, V11 is jun, Class is 1
# [Truncated at label] V13 is 2, V9 is cellular, V7 is no, V1 is 44, V11 is jul, V12 is 178, V10 is 12, V4 is tertiary, V1 is 32, V16 is unknown, V7 is yes, V10 is 7, V13 is 2, V1 is 36, V6 is 916, V11 is jun
# [Parsed Features] {'V13': '2', 'V9': 'cellular', 'V7': 'no', 'V1': '44', 'V11': 'jul', 'V12': '178', 'V10': '12', 'V4': 'tertiary', 'V16': 'unknown', 'V6': '916'}
# [Filled Missing Feature] V2 with admin.
# [Filled Missing Feature] V3 with single
# [Filled Missing Feature] V5 with no
# [Filled Missing Feature] V8 with no
# [Filled Missing Feature] V14 with -1
# [Filled Missing Feature] V15 with 2
# [Raw Output] V6 is 165, V3 is married, V7 is no, V10 is 2, V14 is -1, V3 is married, V8 is no, V5 is no, V11 is may, V3 is divorced, V16 is unknown, V1 is 39, V9 is unknown, V14 is -1, V15 is 0, V7 is no, Class is 1
# [Truncated at label] V6 is 165, V3 is married, V7 is no, V10 is 2, V14 is -1, V3 is married, V8 is no, V5 is no, V11 is may, V3 is divorced, V16 is unknown, V1 is 39, V9 is unknown, V14 is -1, V15 is 0, V7 is no
# [Parsed Features] {'V6': '165', 'V3': 'married', 'V7': 'no', 'V10': '2', 'V14': '-1', 'V8': 'no', 'V5': 'no', 'V11': 'may', 'V16': 'unknown', 'V1': '39', 'V9': 'unknown', 'V15': '0'}
# [Filled Missing Feature] V2 with blue-collar
# [Filled Missing Feature] V4 with primary
# [Filled Missing Feature] V12 with 288
# [Filled Missing Feature] V13 with 1
# [Raw Output] V13 is 2, V1 is 39, V14 is -1, V8 is no, V11 is jul, V12 is 0, V7 is yes, V9 is cellular, V14 is -1, V10 is 30, V12 is 181, V10 is 19, V16 is failure, V4 is secondary, V10 is 12, Class is 1
# [Truncated at label] V13 is 2, V1 is 39, V14 is -1, V8 is no, V11 is jul, V12 is 0, V7 is yes, V9 is cellular, V14 is -1, V10 is 30, V12 is 181, V10 is 19, V16 is failure, V4 is secondary, V10 is 12
# [Parsed Features] {'V13': '2', 'V1': '39', 'V14': '-1', 'V8': 'no', 'V11': 'jul', 'V12': '0', 'V7': 'yes', 'V9': 'cellular', 'V10': '30', 'V16': 'failure', 'V4': 'secondary'}
# [Filled Missing Feature] V2 with blue-collar
# [Filled Missing Feature] V3 with single
# [Filled Missing Feature] V5 with no
# [Filled Missing Feature] V6 with 384
# [Filled Missing Feature] V15 with 0
# [Raw Output] V14 is 385, V7 is yes, V1 is 42, V11 is jul, V16 is unknown, V4 is secondary, V6 is 1213, V5 is no, V10 is 5, V9 is cellular, V1 is 37, V7 is yes, V8 is no, V12 is -1, V12 is 481, V15 is 0, Class is 1
# [Truncated at label] V14 is 385, V7 is yes, V1 is 42, V11 is jul, V16 is unknown, V4 is secondary, V6 is 1213, V5 is no, V10 is 5, V9 is cellular, V1 is 37, V7 is yes, V8 is no, V12 is -1, V12 is 481, V15 is 0
# [Parsed Features] {'V14': '385', 'V7': 'yes', 'V1': '42', 'V11': 'jul', 'V16': 'unknown', 'V4': 'secondary', 'V6': '1213', 'V5': 'no', 'V10': '5', 'V9': 'cellular', 'V8': 'no', 'V12': '-1', 'V15': '0'}
# [Filled Missing Feature] V2 with technician
# [Filled Missing Feature] V3 with single
# [Filled Missing Feature] V13 with 5
# [Raw Output] V15 is 0, V12 is 638, V9 is cellular, V4 is secondary, V1 is 49, V9 is unknown, V3 is single, V9 is cellular, V2 is management, V1 is 33, V5 is no, V15 is 0, V10 is 20, V14 is -1, V2 is management, V3 is single, Class is 1
# [Truncated at label] V15 is 0, V12 is 638, V9 is cellular, V4 is secondary, V1 is 49, V9 is unknown, V3 is single, V9 is cellular, V2 is management, V1 is 33, V5 is no, V15 is 0, V10 is 20, V14 is -1, V2 is management, V3 is single
# [Parsed Features] {'V15': '0', 'V12': '638', 'V9': 'cellular', 'V4': 'secondary', 'V1': '49', 'V3': 'single', 'V2': 'management', 'V5': 'no', 'V10': '20', 'V14': '-1'}
# [Filled Missing Feature] V6 with 121
# [Filled Missing Feature] V7 with no
# [Filled Missing Feature] V8 with yes
# [Filled Missing Feature] V11 with may
# [Filled Missing Feature] V13 with 3
# [Filled Missing Feature] V16 with unknown
# [Raw Output] V9 is unknown, V16 is unknown, V3 is single, V7 is no, V13 is 1, V1 is 42, V10 is 15, V15 is 0, V16 is unknown, V15 is 0, V7 is yes, V5 is no, V2 is technician, V2 is management, V2 is blue-collar, V1 is 49, Class is 1
# [Truncated at label] V9 is unknown, V16 is unknown, V3 is single, V7 is no, V13 is 1, V1 is 42, V10 is 15, V15 is 0, V16 is unknown, V15 is 0, V7 is yes, V5 is no, V2 is technician, V2 is management, V2 is blue-collar, V1 is 49
# [Parsed Features] {'V9': 'unknown', 'V16': 'unknown', 'V3': 'single', 'V7': 'no', 'V13': '1', 'V1': '42', 'V10': '15', 'V15': '0', 'V5': 'no', 'V2': 'technician'}
# [Filled Missing Feature] V4 with primary
# [Filled Missing Feature] V6 with 352
# [Filled Missing Feature] V8 with no
# [Filled Missing Feature] V11 with nov
# [Filled Missing Feature] V12 with 103
# [Filled Missing Feature] V14 with -1
# [Raw Output] V1 is 33, V2 is blue-collar, V3 is single, V4 is tertiary, V5 is no, V6 is 474, V7 is yes, V8 is no, V9 is unknown, V10 is 21, V11 is may, V12 is 694, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, Class is 1
# [Truncated at label] V1 is 33, V2 is blue-collar, V3 is single, V4 is tertiary, V5 is no, V6 is 474, V7 is yes, V8 is no, V9 is unknown, V10 is 21, V11 is may, V12 is 694, V13 is 1, V14 is -1, V15 is 0, V16 is unknown
# [Parsed Features] {'V1': '33', 'V2': 'blue-collar', 'V3': 'single', 'V4': 'tertiary', 'V5': 'no', 'V6': '474', 'V7': 'yes', 'V8': 'no', 'V9': 'unknown', 'V10': '21', 'V11': 'may', 'V12': '694', 'V13': '1', 'V14': '-1', 'V15': '0', 'V16': 'unknown'}
# [Raw Output] V2 is admin.employed, V3 is married, V4 is secondary, V5 is no, V6 is 543, V7 is yes, V8 is yes, V9 is cellular, V10 is 17, V11 is aug, V12 is 6, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, Class is 1
# [Truncated at label] V2 is admin.employed, V3 is married, V4 is secondary, V5 is no, V6 is 543, V7 is yes, V8 is yes, V9 is cellular, V10 is 17, V11 is aug, V12 is 6, V13 is 2, V14 is -1, V15 is 0, V16 is unknown
# [Parsed Features] {'V2': 'admin.employed', 'V3': 'married', 'V4': 'secondary', 'V5': 'no', 'V6': '543', 'V7': 'yes', 'V8': 'yes', 'V9': 'cellular', 'V10': '17', 'V11': 'aug', 'V12': '6', 'V13': '2', 'V14': '-1', 'V15': '0', 'V16': 'unknown'}
# [Filled Missing Feature] V1 with 36
# [Raw Output] V9 is cellular, V12 is 124, V7 is yes, V3 is single, V7 is yes, V2 is management, V13 is 1, V5 is no, V16 is failure, V3 is single, V4 is primary, V1 is 35, V12 is 151, V8 is no, V3 is single, V12 is 152, Class is 1
# [Truncated at label] V9 is cellular, V12 is 124, V7 is yes, V3 is single, V7 is yes, V2 is management, V13 is 1, V5 is no, V16 is failure, V3 is single, V4 is primary, V1 is 35, V12 is 151, V8 is no, V3 is single, V12 is 152
# [Parsed Features] {'V9': 'cellular', 'V12': '124', 'V7': 'yes', 'V3': 'single', 'V2': 'management', 'V13': '1', 'V5': 'no', 'V16': 'failure', 'V4': 'primary', 'V1': '35', 'V8': 'no'}
# [Filled Missing Feature] V6 with 1792
# [Filled Missing Feature] V10 with 6
# [Filled Missing Feature] V11 with feb
# [Filled Missing Feature] V14 with -1
# [Filled Missing Feature] V15 with 0
# [Raw Output] V1 is 55, V2 is management, V3 is single, V4 is tertiary, V5 is no, V6 is 2688, V7 is yes, V8 is no, V9 is unknown, V10 is 19, V11 is nov, V12 is 103, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, Class is 1
# [Truncated at label] V1 is 55, V2 is management, V3 is single, V4 is tertiary, V5 is no, V6 is 2688, V7 is yes, V8 is no, V9 is unknown, V10 is 19, V11 is nov, V12 is 103, V13 is 2, V14 is -1, V15 is 0, V16 is unknown
# [Parsed Features] {'V1': '55', 'V2': 'management', 'V3': 'single', 'V4': 'tertiary', 'V5': 'no', 'V6': '2688', 'V7': 'yes', 'V8': 'no', 'V9': 'unknown', 'V10': '19', 'V11': 'nov', 'V12': '103', 'V13': '2', 'V14': '-1', 'V15': '0', 'V16': 'unknown'}
# [Raw Output] V16 is unknown, V6 is 1679, V7 is yes, V5 is no, V10 is 14, V11 is jul, V1 is 49, V2 is management, V11 is jun, V12 is 123, V13 is 2, V14 is -1, V5 is no, V16 is unknown, V15 is 0, V16 is unknown, Class is 1
# [Truncated at label] V16 is unknown, V6 is 1679, V7 is yes, V5 is no, V10 is 14, V11 is jul, V1 is 49, V2 is management, V11 is jun, V12 is 123, V13 is 2, V14 is -1, V5 is no, V16 is unknown, V15 is 0, V16 is unknown
# [Parsed Features] {'V16': 'unknown', 'V6': '1679', 'V7': 'yes', 'V5': 'no', 'V10': '14', 'V11': 'jul', 'V1': '49', 'V2': 'management', 'V12': '123', 'V13': '2', 'V14': '-1', 'V15': '0'}
# [Filled Missing Feature] V3 with single
# [Filled Missing Feature] V4 with secondary
# [Filled Missing Feature] V8 with no
# [Filled Missing Feature] V9 with unknown
# [Raw Output] V3 is married, V2 is blue-collar, V14 is -1, V4 is secondary, V11 is jul, V4 is secondary, V5 is no, V6 is 979, V7 is yes, V8 is yes, V11 is may, V12 is 182, V13 is 1, V16 is other, V10 is 23, Class is 2
# [Truncated at label] V3 is married, V2 is blue-collar, V14 is -1, V4 is secondary, V11 is jul, V4 is secondary, V5 is no, V6 is 979, V7 is yes, V8 is yes, V11 is may, V12 is 182, V13 is 1, V16 is other, V10 is 23
# [Parsed Features] {'V3': 'married', 'V2': 'blue-collar', 'V14': '-1', 'V4': 'secondary', 'V11': 'jul', 'V5': 'no', 'V6': '979', 'V7': 'yes', 'V8': 'yes', 'V12': '182', 'V13': '1', 'V16': 'other', 'V10': '23'}
# [Filled Missing Feature] V1 with 39
# [Filled Missing Feature] V9 with cellular
# [Filled Missing Feature] V15 with 2
# [Raw Output] V16 is unknown, V2 is blue-collar, V3 is single, V4 is tertiary, V5 is no, V6 is 15, V7 is no, V8 is no, V9 is cellular, V10 is 18, V11 is jun, V12 is 112, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, Class is 1
# [Truncated at label] V16 is unknown, V2 is blue-collar, V3 is single, V4 is tertiary, V5 is no, V6 is 15, V7 is no, V8 is no, V9 is cellular, V10 is 18, V11 is jun, V12 is 112, V13 is 1, V14 is -1, V15 is 0, V16 is unknown
# [Parsed Features] {'V16': 'unknown', 'V2': 'blue-collar', 'V3': 'single', 'V4': 'tertiary', 'V5': 'no', 'V6': '15', 'V7': 'no', 'V8': 'no', 'V9': 'cellular', 'V10': '18', 'V11': 'jun', 'V12': '112', 'V13': '1', 'V14': '-1', 'V15': '0'}
# [Filled Missing Feature] V1 with 35
# [Raw Output] V12 is 116, V9 is unknown, V6 is 976, V12 is 172, V10 is 29, V9 is cellular, V15 is 0, V4 is tertiary, V16 is unknown, V13 is 3, V4 is secondary, V3 is single, V9 is cellular, V1 is 30, V4 is secondary, V12 is 158, Class is 1
# [Truncated at label] V12 is 116, V9 is unknown, V6 is 976, V12 is 172, V10 is 29, V9 is cellular, V15 is 0, V4 is tertiary, V16 is unknown, V13 is 3, V4 is secondary, V3 is single, V9 is cellular, V1 is 30, V4 is secondary, V12 is 158
# [Parsed Features] {'V12': '116', 'V9': 'unknown', 'V6': '976', 'V10': '29', 'V15': '0', 'V4': 'tertiary', 'V16': 'unknown', 'V13': '3', 'V3': 'single', 'V1': '30'}
# [Filled Missing Feature] V2 with self-employed
# [Filled Missing Feature] V5 with no
# [Filled Missing Feature] V7 with yes
# [Filled Missing Feature] V8 with yes
# [Filled Missing Feature] V11 with aug
# [Filled Missing Feature] V14 with -1
# [Raw Output] V3 is married, V8 is no, V16 is unknown, V11 is apr, V8 is no, V15 is 0, V12 is 138, V7 is yes, V14 is -1, V5 is no, V1 is 37, V8 is no, V4 is secondary, V7 is yes, V1 is 45, V11 is jun, Class is 1
# [Truncated at label] V3 is married, V8 is no, V16 is unknown, V11 is apr, V8 is no, V15 is 0, V12 is 138, V7 is yes, V14 is -1, V5 is no, V1 is 37, V8 is no, V4 is secondary, V7 is yes, V1 is 45, V11 is jun
# [Parsed Features] {'V3': 'married', 'V8': 'no', 'V16': 'unknown', 'V11': 'apr', 'V15': '0', 'V12': '138', 'V7': 'yes', 'V14': '-1', 'V5': 'no', 'V1': '37', 'V4': 'secondary'}
# [Filled Missing Feature] V2 with blue-collar
# [Filled Missing Feature] V6 with 68
# [Filled Missing Feature] V9 with unknown
# [Filled Missing Feature] V10 with 17
# [Filled Missing Feature] V13 with 7
# [Raw Output] V15 is 0, V4 is tertiary, V6 is 0, V8 is no, V5 is no, V13 is 2, V10 is 20, V13 is 1, V15 is 0, V16 is unknown, V9 is cellular, V2 is management, V16 is unknown, V9 is cellular, V3 is married, V7 is no, Class is 1
# [Truncated at label] V15 is 0, V4 is tertiary, V6 is 0, V8 is no, V5 is no, V13 is 2, V10 is 20, V13 is 1, V15 is 0, V16 is unknown, V9 is cellular, V2 is management, V16 is unknown, V9 is cellular, V3 is married, V7 is no
# [Parsed Features] {'V15': '0', 'V4': 'tertiary', 'V6': '0', 'V8': 'no', 'V5': 'no', 'V13': '2', 'V10': '20', 'V16': 'unknown', 'V9': 'cellular', 'V2': 'management', 'V3': 'married', 'V7': 'no'}
# [Filled Missing Feature] V1 with 30
# [Filled Missing Feature] V11 with may
# [Filled Missing Feature] V12 with 163
# [Filled Missing Feature] V14 with -1
# [Raw Output] V6 is 179, V2 is blue-collar, V3 is married, V4 is secondary, V5 is no, V6 is 714, V7 is yes, V8 is no, V9 is cellular, V10 is 28, V11 is jul, V12 is 562, V13 is 5, V14 is -1, V15 is 0, V16 is unknown, Class is 1
# [Truncated at label] V6 is 179, V2 is blue-collar, V3 is married, V4 is secondary, V5 is no, V6 is 714, V7 is yes, V8 is no, V9 is cellular, V10 is 28, V11 is jul, V12 is 562, V13 is 5, V14 is -1, V15 is 0, V16 is unknown
# [Parsed Features] {'V6': '179', 'V2': 'blue-collar', 'V3': 'married', 'V4': 'secondary', 'V5': 'no', 'V7': 'yes', 'V8': 'no', 'V9': 'cellular', 'V10': '28', 'V11': 'jul', 'V12': '562', 'V13': '5', 'V14': '-1', 'V15': '0', 'V16': 'unknown'}
# [Filled Missing Feature] V1 with 33
# [Raw Output] V13 is 1, V2 is management, V16 is unknown, V3 is single, V14 is -1, V5 is no, V11 is may, V2 is blue-collar, V7 is yes, V5 is no, V12 is 136, V10 is 18, V2 is blue-collar, V1 is 44, V12 is 195, Class is 1
# [Truncated at label] V13 is 1, V2 is management, V16 is unknown, V3 is single, V14 is -1, V5 is no, V11 is may, V2 is blue-collar, V7 is yes, V5 is no, V12 is 136, V10 is 18, V2 is blue-collar, V1 is 44, V12 is 195
# [Parsed Features] {'V13': '1', 'V2': 'management', 'V16': 'unknown', 'V3': 'single', 'V14': '-1', 'V5': 'no', 'V11': 'may', 'V7': 'yes', 'V12': '136', 'V10': '18', 'V1': '44'}
# [Filled Missing Feature] V4 with tertiary
# [Filled Missing Feature] V6 with 0
# [Filled Missing Feature] V8 with yes
# [Filled Missing Feature] V9 with cellular
# [Filled Missing Feature] V15 with 0
# [Raw Output] V4 is tertiary, V5 is no, V11 is jul, V12 is 195, V7 is no, V12 is 185, V13 is 1, V4 is secondary, V7 is no, V14 is -1, V15 is 0, V16 is unknown, V7 is yes, V15 is 0, V10 is 17, Class is 1
# [Truncated at label] V4 is tertiary, V5 is no, V11 is jul, V12 is 195, V7 is no, V12 is 185, V13 is 1, V4 is secondary, V7 is no, V14 is -1, V15 is 0, V16 is unknown, V7 is yes, V15 is 0, V10 is 17
# [Parsed Features] {'V4': 'tertiary', 'V5': 'no', 'V11': 'jul', 'V12': '195', 'V7': 'no', 'V13': '1', 'V14': '-1', 'V15': '0', 'V16': 'unknown', 'V10': '17'}
# [Filled Missing Feature] V1 with 56
# [Filled Missing Feature] V2 with blue-collar
# [Filled Missing Feature] V3 with married
# [Filled Missing Feature] V6 with 545
# [Filled Missing Feature] V8 with yes
# [Filled Missing Feature] V9 with unknown
# [Raw Output] V15 is 3, V8 is no, V15 is 0, V2 is admin., V16 is unknown, V5 is no, V7 is no, V4 is secondary, V2 is management, V7 is yes, V11 is jul, V14 is -1, V8 is no, V12 is 159, V3 is married, V8 is no, Class is 1
# [Truncated at label] V15 is 3, V8 is no, V15 is 0, V2 is admin., V16 is unknown, V5 is no, V7 is no, V4 is secondary, V2 is management, V7 is yes, V11 is jul, V14 is -1, V8 is no, V12 is 159, V3 is married, V8 is no
# [Parsed Features] {'V15': '3', 'V8': 'no', 'V2': 'admin.', 'V16': 'unknown', 'V5': 'no', 'V7': 'no', 'V4': 'secondary', 'V11': 'jul', 'V14': '-1', 'V12': '159', 'V3': 'married'}
# [Filled Missing Feature] V1 with 38
# [Filled Missing Feature] V6 with 3770
# [Filled Missing Feature] V9 with cellular
# [Filled Missing Feature] V10 with 1
# [Filled Missing Feature] V13 with 2
# [Raw Output] V8 is yes, V5 is no, V9 is cellular, V14 is -1, V7 is yes, V5 is no, V13 is 1, V15 is 0, V14 is -1, V7 is no, V16 is unknown, V7 is no, V8 is no, V12 is 672, V6 is 715, V1 is 37, Class is 1
# [Truncated at label] V8 is yes, V5 is no, V9 is cellular, V14 is -1, V7 is yes, V5 is no, V13 is 1, V15 is 0, V14 is -1, V7 is no, V16 is unknown, V7 is no, V8 is no, V12 is 672, V6 is 715, V1 is 37
# [Parsed Features] {'V8': 'yes', 'V5': 'no', 'V9': 'cellular', 'V14': '-1', 'V7': 'yes', 'V13': '1', 'V15': '0', 'V16': 'unknown', 'V12': '672', 'V6': '715', 'V1': '37'}
# [Filled Missing Feature] V2 with services
# [Filled Missing Feature] V3 with married
# [Filled Missing Feature] V4 with tertiary
# [Filled Missing Feature] V10 with 8
# [Filled Missing Feature] V11 with aug
# [Raw Output] V10 is 18, V1 is 36, V2 is retired, V11 is may, V8 is no, V5 is no, V16 is unknown, V4 is secondary, V12 is 179, V13 is 1, V14 is -1, V5 is no, V6 is 1415, V13 is 1, V15 is 0, V16 is unknown, Class is 1
# [Truncated at label] V10 is 18, V1 is 36, V2 is retired, V11 is may, V8 is no, V5 is no, V16 is unknown, V4 is secondary, V12 is 179, V13 is 1, V14 is -1, V5 is no, V6 is 1415, V13 is 1, V15 is 0, V16 is unknown
# [Parsed Features] {'V10': '18', 'V1': '36', 'V2': 'retired', 'V11': 'may', 'V8': 'no', 'V5': 'no', 'V16': 'unknown', 'V4': 'secondary', 'V12': '179', 'V13': '1', 'V14': '-1', 'V6': '1415', 'V15': '0'}
# [Filled Missing Feature] V3 with married
# [Filled Missing Feature] V7 with yes
# [Filled Missing Feature] V9 with cellular
# [Raw Output] V15 is 0, V3 is divorced, V11 is may, V4 is secondary, V12 is 126, V1 is 35, V15 is 0, V7 is yes, V12 is 150, V1 is 37, V12 is 163, V4 is secondary, V4 is secondary, V7 is no, V5 is no, V10 is 4, Class is 1
# [Truncated at label] V15 is 0, V3 is divorced, V11 is may, V4 is secondary, V12 is 126, V1 is 35, V15 is 0, V7 is yes, V12 is 150, V1 is 37, V12 is 163, V4 is secondary, V4 is secondary, V7 is no, V5 is no, V10 is 4
# [Parsed Features] {'V15': '0', 'V3': 'divorced', 'V11': 'may', 'V4': 'secondary', 'V12': '126', 'V1': '35', 'V7': 'yes', 'V5': 'no', 'V10': '4'}
# [Filled Missing Feature] V2 with admin.
# [Filled Missing Feature] V6 with -14
# [Filled Missing Feature] V8 with no
# [Filled Missing Feature] V9 with cellular
# [Filled Missing Feature] V13 with 2
# [Filled Missing Feature] V14 with -1
# [Filled Missing Feature] V16 with failure
# [Raw Output] V2 is services, V6 is 1313, V14 is -1, V1 is 29, V4 is tertiary, V6 is 561, V10 is 15, V15 is 0, V14 is -1, V8 is no, V15 is 0, V14 is -1, V12 is 127, V11 is jul, V7 is no, Class is 1
# [Truncated at label] V2 is services, V6 is 1313, V14 is -1, V1 is 29, V4 is tertiary, V6 is 561, V10 is 15, V15 is 0, V14 is -1, V8 is no, V15 is 0, V14 is -1, V12 is 127, V11 is jul, V7 is no
# [Parsed Features] {'V2': 'services', 'V6': '1313', 'V14': '-1', 'V1': '29', 'V4': 'tertiary', 'V10': '15', 'V15': '0', 'V8': 'no', 'V12': '127', 'V11': 'jul', 'V7': 'no'}
# [Filled Missing Feature] V3 with single
# [Filled Missing Feature] V5 with no
# [Filled Missing Feature] V9 with unknown
# [Filled Missing Feature] V13 with 7
# [Filled Missing Feature] V16 with unknown
# [Raw Output] V15 is 2, V8 is yes, V15 is 2, V3 is single, V9 is cellular, V16 is unknown, V10 is 13, V13 is 1, V3 is married, V8 is no, V15 is 0, V1 is 37, V15 is 0, V11 is apr, V3 is divorced, V14 is -1, Class is 1
# [Truncated at label] V15 is 2, V8 is yes, V15 is 2, V3 is single, V9 is cellular, V16 is unknown, V10 is 13, V13 is 1, V3 is married, V8 is no, V15 is 0, V1 is 37, V15 is 0, V11 is apr, V3 is divorced, V14 is -1
# [Parsed Features] {'V15': '2', 'V8': 'yes', 'V3': 'single', 'V9': 'cellular', 'V16': 'unknown', 'V10': '13', 'V13': '1', 'V1': '37', 'V11': 'apr', 'V14': '-1'}
# [Filled Missing Feature] V2 with services
# [Filled Missing Feature] V4 with unknown
# [Filled Missing Feature] V5 with no
# [Filled Missing Feature] V6 with 859
# [Filled Missing Feature] V7 with yes
# [Filled Missing Feature] V12 with 108
# [Raw Output] V8 is yes, V2 is blue-collar, V3 is married, V14 is -1, V5 is no, V15 is 0, V16 is unknown, V5 is no, V6 is 3302, V7 is yes, V8 is no, V9 is unknown, V10 is 12, V11 is jul, V12 is 636, Class is 1
# [Truncated at label] V8 is yes, V2 is blue-collar, V3 is married, V14 is -1, V5 is no, V15 is 0, V16 is unknown, V5 is no, V6 is 3302, V7 is yes, V8 is no, V9 is unknown, V10 is 12, V11 is jul, V12 is 636
# [Parsed Features] {'V8': 'yes', 'V2': 'blue-collar', 'V3': 'married', 'V14': '-1', 'V5': 'no', 'V15': '0', 'V16': 'unknown', 'V6': '3302', 'V7': 'yes', 'V9': 'unknown', 'V10': '12', 'V11': 'jul', 'V12': '636'}
# [Filled Missing Feature] V1 with 52
# [Filled Missing Feature] V4 with secondary
# [Filled Missing Feature] V13 with 4
# [Raw Output] V5 is no, V7 is no, V14 is -1, V3 is married, V13 is 1, V6 is 0, V4 is secondary, V8 is no, V10 is 6, V11 is apr, V5 is no, V6 is 1228, V12 is 246, V3 is married, V4 is secondary, Class is 1
# [Truncated at label] V5 is no, V7 is no, V14 is -1, V3 is married, V13 is 1, V6 is 0, V4 is secondary, V8 is no, V10 is 6, V11 is apr, V5 is no, V6 is 1228, V12 is 246, V3 is married, V4 is secondary
# [Parsed Features] {'V5': 'no', 'V7': 'no', 'V14': '-1', 'V3': 'married', 'V13': '1', 'V6': '0', 'V4': 'secondary', 'V8': 'no', 'V10': '6', 'V11': 'apr', 'V12': '246'}
# [Filled Missing Feature] V1 with 55
# [Filled Missing Feature] V2 with blue-collar
# [Filled Missing Feature] V9 with unknown
# [Filled Missing Feature] V15 with 0
# [Filled Missing Feature] V16 with unknown
# [Raw Output] V2 is technician, V3 is single, V4 is secondary, V5 is no, V6 is 1036, V7 is yes, V8 is no, V9 is cellular, V10 is 18, V11 is may, V12 is 552, V13 is 4, V14 is -1, V15 is 0, V16 is unknown, Class is 1
# [Truncated at label] V2 is technician, V3 is single, V4 is secondary, V5 is no, V6 is 1036, V7 is yes, V8 is no, V9 is cellular, V10 is 18, V11 is may, V12 is 552, V13 is 4, V14 is -1, V15 is 0, V16 is unknown
# [Parsed Features] {'V2': 'technician', 'V3': 'single', 'V4': 'secondary', 'V5': 'no', 'V6': '1036', 'V7': 'yes', 'V8': 'no', 'V9': 'cellular', 'V10': '18', 'V11': 'may', 'V12': '552', 'V13': '4', 'V14': '-1', 'V15': '0', 'V16': 'unknown'}
# [Filled Missing Feature] V1 with 60
# [Raw Output] V5 is no, V4 is secondary, V6 is -1638, V14 is -1, V7 is yes, V10 is 28, V8 is no, V13 is 2, V3 is single, V16 is unknown, V16 is unknown, V14 is -1, V10 is 16, V6 is 0, V9 is cellular, Class is 1
# [Truncated at label] V5 is no, V4 is secondary, V6 is -1638, V14 is -1, V7 is yes, V10 is 28, V8 is no, V13 is 2, V3 is single, V16 is unknown, V16 is unknown, V14 is -1, V10 is 16, V6 is 0, V9 is cellular
# [Parsed Features] {'V5': 'no', 'V4': 'secondary', 'V6': '-1638', 'V14': '-1', 'V7': 'yes', 'V10': '28', 'V8': 'no', 'V13': '2', 'V3': 'single', 'V16': 'unknown', 'V9': 'cellular'}
# [Filled Missing Feature] V1 with 34
# [Filled Missing Feature] V2 with management
# [Filled Missing Feature] V11 with jun
# [Filled Missing Feature] V12 with 279
# [Filled Missing Feature] V15 with 9
# [Raw Output] V4 is tertiary, V10 is 12, V9 is cellular, V16 is unknown, V14 is -1, V7 is yes, V3 is single, V10 is 22, V6 is -312, V6 is -378, V14 is -1, V6 is -8, V13 is 2, V1 is 53, V16 is unknown, Class is 1
# [Truncated at label] V4 is tertiary, V10 is 12, V9 is cellular, V16 is unknown, V14 is -1, V7 is yes, V3 is single, V10 is 22, V6 is -312, V6 is -378, V14 is -1, V6 is -8, V13 is 2, V1 is 53, V16 is unknown
# [Parsed Features] {'V4': 'tertiary', 'V10': '12', 'V9': 'cellular', 'V16': 'unknown', 'V14': '-1', 'V7': 'yes', 'V3': 'single', 'V6': '-312', 'V13': '2', 'V1': '53'}
# [Filled Missing Feature] V2 with housemaid
# [Filled Missing Feature] V5 with no
# [Filled Missing Feature] V8 with yes
# [Filled Missing Feature] V11 with oct
# [Filled Missing Feature] V12 with 275
# [Filled Missing Feature] V15 with 0
# [Raw Output] V4 is secondary, V13 is 1, V4 is tertiary, V1 is 34, V5 is no, V11 is jun, V15 is 0, V11 is aug, V15 is 0, V3 is single, V10 is 21, V14 is -1, V8 is no, V16 is unknown, V13 is 2, V1 is 52, Class is 1
# [Truncated at label] V4 is secondary, V13 is 1, V4 is tertiary, V1 is 34, V5 is no, V11 is jun, V15 is 0, V11 is aug, V15 is 0, V3 is single, V10 is 21, V14 is -1, V8 is no, V16 is unknown, V13 is 2, V1 is 52
# [Parsed Features] {'V4': 'secondary', 'V13': '1', 'V1': '34', 'V5': 'no', 'V11': 'jun', 'V15': '0', 'V3': 'single', 'V10': '21', 'V14': '-1', 'V8': 'no', 'V16': 'unknown'}
# [Filled Missing Feature] V2 with blue-collar
# [Filled Missing Feature] V6 with 1311
# [Filled Missing Feature] V7 with yes
# [Filled Missing Feature] V9 with cellular
# [Filled Missing Feature] V12 with 53
# [Raw Output] V3 is single, V2 is management, V11 is feb, V9 is cellular, V15 is 0, V16 is unknown, V8 is no, V3 is married, V1 is 30, V14 is -1, V3 is single, V4 is secondary, V11 is jul, V7 is no, V9 is cellular, V15 is 0, Class is 1
# [Truncated at label] V3 is single, V2 is management, V11 is feb, V9 is cellular, V15 is 0, V16 is unknown, V8 is no, V3 is married, V1 is 30, V14 is -1, V3 is single, V4 is secondary, V11 is jul, V7 is no, V9 is cellular, V15 is 0
# [Parsed Features] {'V3': 'single', 'V2': 'management', 'V11': 'feb', 'V9': 'cellular', 'V15': '0', 'V16': 'unknown', 'V8': 'no', 'V1': '30', 'V14': '-1', 'V4': 'secondary', 'V7': 'no'}
# [Filled Missing Feature] V5 with no
# [Filled Missing Feature] V6 with 0
# [Filled Missing Feature] V10 with 4
# [Filled Missing Feature] V12 with 140
# [Filled Missing Feature] V13 with 2
# [Raw Output] V13 is 1, V3 is married, V7 is no, V1 is 34, V16 is failure, V7 is no, V2 is technician, V5 is no, V8 is no, V4 is secondary, V16 is unknown, V7 is no, V4 is tertiary, V16 is unknown, V5 is no, V5 is no, V6 is -240, Class is 1
# [Truncated at label] V13 is 1, V3 is married, V7 is no, V1 is 34, V16 is failure, V7 is no, V2 is technician, V5 is no, V8 is no, V4 is secondary, V16 is unknown, V7 is no, V4 is tertiary, V16 is unknown, V5 is no, V5 is no, V6 is -240
# [Parsed Features] {'V13': '1', 'V3': 'married', 'V7': 'no', 'V1': '34', 'V16': 'failure', 'V2': 'technician', 'V5': 'no', 'V8': 'no', 'V4': 'secondary', 'V6': '-240'}
# [Filled Missing Feature] V9 with cellular
# [Filled Missing Feature] V10 with 3
# [Filled Missing Feature] V11 with jul
# [Filled Missing Feature] V12 with 54
# [Filled Missing Feature] V14 with -1
# [Filled Missing Feature] V15 with 0
# [Raw Output] V11 is apr, V8 is no, V4 is secondary, V14 is -1, V6 is 715, V5 is no, V13 is 2, V5 is no, V11 is jun, V8 is no, V4 is secondary, V6 is 2179, V2 is management, V9 is cellular, V13 is 1, Class is 1
# [Truncated at label] V11 is apr, V8 is no, V4 is secondary, V14 is -1, V6 is 715, V5 is no, V13 is 2, V5 is no, V11 is jun, V8 is no, V4 is secondary, V6 is 2179, V2 is management, V9 is cellular, V13 is 1
# [Parsed Features] {'V11': 'apr', 'V8': 'no', 'V4': 'secondary', 'V14': '-1', 'V6': '715', 'V5': 'no', 'V13': '2', 'V2': 'management', 'V9': 'cellular'}
# [Filled Missing Feature] V1 with 48
# [Filled Missing Feature] V3 with married
# [Filled Missing Feature] V7 with no
# [Filled Missing Feature] V10 with 26
# [Filled Missing Feature] V12 with 67
# [Filled Missing Feature] V15 with 0
# [Filled Missing Feature] V16 with unknown
# [Raw Output] V11 is aug, V14 is -1, V12 is 185, V5 is no, V8 is no, V5 is no, V14 is -1, V8 is no, V12 is 183, V9 is cellular, V7 is no, V12 is 182, V7 is yes, V15 is 0, V12 is 247, Class is 1
# [Truncated at label] V11 is aug, V14 is -1, V12 is 185, V5 is no, V8 is no, V5 is no, V14 is -1, V8 is no, V12 is 183, V9 is cellular, V7 is no, V12 is 182, V7 is yes, V15 is 0, V12 is 247
# [Parsed Features] {'V11': 'aug', 'V14': '-1', 'V12': '185', 'V5': 'no', 'V8': 'no', 'V9': 'cellular', 'V7': 'no', 'V15': '0'}
# [Filled Missing Feature] V1 with 48
# [Filled Missing Feature] V2 with management
# [Filled Missing Feature] V3 with married
# [Filled Missing Feature] V4 with secondary
# [Filled Missing Feature] V6 with 1603
# [Filled Missing Feature] V10 with 31
# [Filled Missing Feature] V13 with 1
# [Filled Missing Feature] V16 with unknown
# [Raw Output] V6 is 1431, V15 is 0, V10 is 16, V4 is tertiary, V9 is cellular, V6 is 0, V4 is tertiary, V2 is management, V9 is cellular, V7 is yes, V4 is secondary, V12 is 168, V15 is 0, V4 is tertiary, V5 is no, V4 is tertiary, Class is 1
# [Truncated at label] V6 is 1431, V15 is 0, V10 is 16, V4 is tertiary, V9 is cellular, V6 is 0, V4 is tertiary, V2 is management, V9 is cellular, V7 is yes, V4 is secondary, V12 is 168, V15 is 0, V4 is tertiary, V5 is no, V4 is tertiary
# [Parsed Features] {'V6': '1431', 'V15': '0', 'V10': '16', 'V4': 'tertiary', 'V9': 'cellular', 'V2': 'management', 'V7': 'yes', 'V12': '168', 'V5': 'no'}
# [Filled Missing Feature] V1 with 56
# [Filled Missing Feature] V3 with married
# [Filled Missing Feature] V8 with no
# [Filled Missing Feature] V11 with nov
# [Filled Missing Feature] V13 with 1
# [Filled Missing Feature] V14 with -1
# [Filled Missing Feature] V16 with unknown
# [Raw Output] V13 is 4, V2 is management, V5 is no, V4 is tertiary, V8 is no, V16 is unknown, V11 is may, V13 is 2, V6 is 1673, V10 is 8, V7 is yes, V1 is 40, V2 is admin., V13 is 1, V14 is -1, Class is 1
# [Truncated at label] V13 is 4, V2 is management, V5 is no, V4 is tertiary, V8 is no, V16 is unknown, V11 is may, V13 is 2, V6 is 1673, V10 is 8, V7 is yes, V1 is 40, V2 is admin., V13 is 1, V14 is -1
# [Parsed Features] {'V13': '4', 'V2': 'management', 'V5': 'no', 'V4': 'tertiary', 'V8': 'no', 'V16': 'unknown', 'V11': 'may', 'V6': '1673', 'V10': '8', 'V7': 'yes', 'V1': '40', 'V14': '-1'}
# [Filled Missing Feature] V3 with married
# [Filled Missing Feature] V9 with cellular
# [Filled Missing Feature] V12 with 372
# [Filled Missing Feature] V15 with 1
# [Raw Output] V3 is divorced, V7 is yes, V16 is unknown, V9 is unknown, V15 is 0, V14 is -1, V10 is 4, V14 is -1, V9 is cellular, V3 is divorced, V16 is unknown, V7 is yes, V8 is no, V13 is 1, V5 is no, Class is 1
# [Truncated at label] V3 is divorced, V7 is yes, V16 is unknown, V9 is unknown, V15 is 0, V14 is -1, V10 is 4, V14 is -1, V9 is cellular, V3 is divorced, V16 is unknown, V7 is yes, V8 is no, V13 is 1, V5 is no
# [Parsed Features] {'V3': 'divorced', 'V7': 'yes', 'V16': 'unknown', 'V9': 'unknown', 'V15': '0', 'V14': '-1', 'V10': '4', 'V8': 'no', 'V13': '1', 'V5': 'no'}
# [Filled Missing Feature] V1 with 30
# [Filled Missing Feature] V2 with management
# [Filled Missing Feature] V4 with secondary
# [Filled Missing Feature] V6 with 341
# [Filled Missing Feature] V11 with aug
# [Filled Missing Feature] V12 with 138
# [Raw Output] V10 is 17, V7 is no, V2 is blue-collar, V12 is 179, V15 is 0, V12 is 185, V4 is tertiary, V14 is -1, V1 is 39, V13 is 5, V4 is tertiary, V12 is 185, V7 is no, V8 is no, V16 is unknown, Class is 1
# [Truncated at label] V10 is 17, V7 is no, V2 is blue-collar, V12 is 179, V15 is 0, V12 is 185, V4 is tertiary, V14 is -1, V1 is 39, V13 is 5, V4 is tertiary, V12 is 185, V7 is no, V8 is no, V16 is unknown
# [Parsed Features] {'V10': '17', 'V7': 'no', 'V2': 'blue-collar', 'V12': '179', 'V15': '0', 'V4': 'tertiary', 'V14': '-1', 'V1': '39', 'V13': '5', 'V8': 'no', 'V16': 'unknown'}
# [Filled Missing Feature] V3 with married
# [Filled Missing Feature] V5 with no
# [Filled Missing Feature] V6 with 209
# [Filled Missing Feature] V9 with cellular
# [Filled Missing Feature] V11 with may
# [Raw Output] V5 is no, V7 is yes, V14 is -1, V2 is blue-collar, V16 is unknown, V13 is 1, V5 is no, V3 is married, V6 is 0, V4 is secondary, V10 is 9, V15 is 0, V3 is married, V10 is 18, V8 is no, Class is 1
# [Truncated at label] V5 is no, V7 is yes, V14 is -1, V2 is blue-collar, V16 is unknown, V13 is 1, V5 is no, V3 is married, V6 is 0, V4 is secondary, V10 is 9, V15 is 0, V3 is married, V10 is 18, V8 is no
# [Parsed Features] {'V5': 'no', 'V7': 'yes', 'V14': '-1', 'V2': 'blue-collar', 'V16': 'unknown', 'V13': '1', 'V3': 'married', 'V6': '0', 'V4': 'secondary', 'V10': '9', 'V15': '0', 'V8': 'no'}
# [Filled Missing Feature] V1 with 45
# [Filled Missing Feature] V9 with cellular
# [Filled Missing Feature] V11 with jul
# [Filled Missing Feature] V12 with 81
# [Raw Output] V15 is 0, V6 is 1052, V7 is yes, V9 is cellular, V3 is married, V9 is cellular, V8 is no, V10 is 5, V14 is -1, V7 is yes, V16 is unknown, V14 is -1, V4 is secondary, V14 is -1, V16 is unknown, Class is 1
# [Truncated at label] V15 is 0, V6 is 1052, V7 is yes, V9 is cellular, V3 is married, V9 is cellular, V8 is no, V10 is 5, V14 is -1, V7 is yes, V16 is unknown, V14 is -1, V4 is secondary, V14 is -1, V16 is unknown
# [Parsed Features] {'V15': '0', 'V6': '1052', 'V7': 'yes', 'V9': 'cellular', 'V3': 'married', 'V8': 'no', 'V10': '5', 'V14': '-1', 'V16': 'unknown', 'V4': 'secondary'}
# [Filled Missing Feature] V1 with 32
# [Filled Missing Feature] V2 with admin.
# [Filled Missing Feature] V5 with no
# [Filled Missing Feature] V11 with aug
# [Filled Missing Feature] V12 with 115
# [Filled Missing Feature] V13 with 4
# [Raw Output] V6 is 1564, V3 is single, V8 is no, V3 is married, V13 is 2, V16 is unknown, V4 is secondary, V12 is 184, V11 is may, V5 is no, V3 is married, V4 is secondary, V16 is failure, V6 is 686, V7 is no, V10 is 6, Class is 1
# [Truncated at label] V6 is 1564, V3 is single, V8 is no, V3 is married, V13 is 2, V16 is unknown, V4 is secondary, V12 is 184, V11 is may, V5 is no, V3 is married, V4 is secondary, V16 is failure, V6 is 686, V7 is no, V10 is 6
# [Parsed Features] {'V6': '1564', 'V3': 'single', 'V8': 'no', 'V13': '2', 'V16': 'unknown', 'V4': 'secondary', 'V12': '184', 'V11': 'may', 'V5': 'no', 'V7': 'no', 'V10': '6'}
# [Filled Missing Feature] V1 with 53
# [Filled Missing Feature] V2 with technician
# [Filled Missing Feature] V9 with unknown
# [Filled Missing Feature] V14 with -1
# [Filled Missing Feature] V15 with 0
# [Raw Output] V10 is 21, V9 is cellular, V2 is management, V11 is jun, V12 is 126, V14 is -1, V16 is unknown, V16 is unknown, V15 is 0, V15 is 0, V16 is unknown, V13 is 1, V5 is no, V4 is tertiary, V9 is cellular, V4 is tertiary, Class is 1
# [Truncated at label] V10 is 21, V9 is cellular, V2 is management, V11 is jun, V12 is 126, V14 is -1, V16 is unknown, V16 is unknown, V15 is 0, V15 is 0, V16 is unknown, V13 is 1, V5 is no, V4 is tertiary, V9 is cellular, V4 is tertiary
# [Parsed Features] {'V10': '21', 'V9': 'cellular', 'V2': 'management', 'V11': 'jun', 'V12': '126', 'V14': '-1', 'V16': 'unknown', 'V15': '0', 'V13': '1', 'V5': 'no', 'V4': 'tertiary'}
# [Filled Missing Feature] V1 with 45
# [Filled Missing Feature] V3 with single
# [Filled Missing Feature] V6 with 335
# [Filled Missing Feature] V7 with yes
# [Filled Missing Feature] V8 with no
# [Raw Output] V4 is secondary, V11 is aug, V13 is 1, V6 is -271, V5 is no, V2 is management, V8 is no, V7 is yes, V5 is no, V16 is unknown, V8 is no, V11 is apr, V16 is unknown, V4 is secondary, V13 is 1, V9 is unknown, Class is 1
# [Truncated at label] V4 is secondary, V11 is aug, V13 is 1, V6 is -271, V5 is no, V2 is management, V8 is no, V7 is yes, V5 is no, V16 is unknown, V8 is no, V11 is apr, V16 is unknown, V4 is secondary, V13 is 1, V9 is unknown
# [Parsed Features] {'V4': 'secondary', 'V11': 'aug', 'V13': '1', 'V6': '-271', 'V5': 'no', 'V2': 'management', 'V8': 'no', 'V7': 'yes', 'V16': 'unknown', 'V9': 'unknown'}
# [Filled Missing Feature] V1 with 34
# [Filled Missing Feature] V3 with married
# [Filled Missing Feature] V10 with 7
# [Filled Missing Feature] V12 with 382
# [Filled Missing Feature] V14 with -1
# [Filled Missing Feature] V15 with 0
# [Raw Output] V8 is no, V8 is no, V13 is 2, V16 is unknown, V6 is 539, V6 is 3159, V2 is management, V1 is 39, V13 is 1, V4 is tertiary, V8 is no, V16 is unknown, V10 is 28, V13 is 1, V12 is 761, Class is 1
# [Truncated at label] V8 is no, V8 is no, V13 is 2, V16 is unknown, V6 is 539, V6 is 3159, V2 is management, V1 is 39, V13 is 1, V4 is tertiary, V8 is no, V16 is unknown, V10 is 28, V13 is 1, V12 is 761
# [Parsed Features] {'V8': 'no', 'V13': '2', 'V16': 'unknown', 'V6': '539', 'V2': 'management', 'V1': '39', 'V4': 'tertiary', 'V10': '28', 'V12': '761'}
# [Filled Missing Feature] V3 with married
# [Filled Missing Feature] V5 with no
# [Filled Missing Feature] V7 with yes
# [Filled Missing Feature] V9 with cellular
# [Filled Missing Feature] V11 with jun
# [Filled Missing Feature] V14 with -1
# [Filled Missing Feature] V15 with 0
# [Raw Output] V4 is primary, V8 is no, V16 is unknown, V6 is 1487, V13 is 2, V14 is -1, V5 is no, V2 is technician, V15 is 0, V2 is technician, V11 is jun, V5 is no, V10 is 19, V4 is secondary, V2 is technician, Class is 1
# [Truncated at label] V4 is primary, V8 is no, V16 is unknown, V6 is 1487, V13 is 2, V14 is -1, V5 is no, V2 is technician, V15 is 0, V2 is technician, V11 is jun, V5 is no, V10 is 19, V4 is secondary, V2 is technician
# [Parsed Features] {'V4': 'primary', 'V8': 'no', 'V16': 'unknown', 'V6': '1487', 'V13': '2', 'V14': '-1', 'V5': 'no', 'V2': 'technician', 'V15': '0', 'V11': 'jun', 'V10': '19'}
# [Filled Missing Feature] V1 with 57
# [Filled Missing Feature] V3 with married
# [Filled Missing Feature] V7 with no
# [Filled Missing Feature] V9 with unknown
# [Filled Missing Feature] V12 with 275
# [Raw Output] V16 is unknown, V6 is 414, V8 is no, V15 is 0, V8 is no, V14 is -1, V6 is 2245, V5 is no, V8 is no, V10 is 19, V16 is unknown, V5 is no, V1 is 56, V13 is 1, V4 is secondary, V2 is management, Class is 1
# [Truncated at label] V16 is unknown, V6 is 414, V8 is no, V15 is 0, V8 is no, V14 is -1, V6 is 2245, V5 is no, V8 is no, V10 is 19, V16 is unknown, V5 is no, V1 is 56, V13 is 1, V4 is secondary, V2 is management
# [Parsed Features] {'V16': 'unknown', 'V6': '414', 'V8': 'no', 'V15': '0', 'V14': '-1', 'V5': 'no', 'V10': '19', 'V1': '56', 'V13': '1', 'V4': 'secondary', 'V2': 'management'}
# [Filled Missing Feature] V3 with single
# [Filled Missing Feature] V7 with yes
# [Filled Missing Feature] V9 with cellular
# [Filled Missing Feature] V11 with apr
# [Filled Missing Feature] V12 with 1865
# [Raw Output] V2 is unemployed, V7 is yes, V16 is unknown, V2 is admin., V12 is 103, V15 is 0, V11 is jun, V1 is 41, V4 is secondary, V3 is divorced, V16 is unknown, V2 is services, V15 is 0, V9 is cellular, V12 is 185, V13 is 1, Class is 1
# [Truncated at label] V2 is unemployed, V7 is yes, V16 is unknown, V2 is admin., V12 is 103, V15 is 0, V11 is jun, V1 is 41, V4 is secondary, V3 is divorced, V16 is unknown, V2 is services, V15 is 0, V9 is cellular, V12 is 185, V13 is 1
# [Parsed Features] {'V2': 'unemployed', 'V7': 'yes', 'V16': 'unknown', 'V12': '103', 'V15': '0', 'V11': 'jun', 'V1': '41', 'V4': 'secondary', 'V3': 'divorced', 'V9': 'cellular', 'V13': '1'}
# [Filled Missing Feature] V5 with no
# [Filled Missing Feature] V6 with 42
# [Filled Missing Feature] V8 with no
# [Filled Missing Feature] V10 with 20
# [Filled Missing Feature] V14 with -1
# [Raw Output] V11 is oct, V5 is no, V4 is tertiary, V1 is 42, V14 is -1, V6 is 0, V14 is -1, V3 is single, V2 is management, V12 is 152, V11 is nov, V13 is 1, V10 is 19, V16 is other, V7 is no, Class is 1
# [Truncated at label] V11 is oct, V5 is no, V4 is tertiary, V1 is 42, V14 is -1, V6 is 0, V14 is -1, V3 is single, V2 is management, V12 is 152, V11 is nov, V13 is 1, V10 is 19, V16 is other, V7 is no
# [Parsed Features] {'V11': 'oct', 'V5': 'no', 'V4': 'tertiary', 'V1': '42', 'V14': '-1', 'V6': '0', 'V3': 'single', 'V2': 'management', 'V12': '152', 'V13': '1', 'V10': '19', 'V16': 'other', 'V7': 'no'}
# [Filled Missing Feature] V8 with no
# [Filled Missing Feature] V9 with cellular
# [Filled Missing Feature] V15 with 0
# [Raw Output] V15 is 0, V8 is no, V7 is yes, V13 is 2, V8 is no, V7 is yes, V1 is 51, V4 is secondary, V14 is -1, V8 is no, V16 is unknown, V13 is 2, V6 is -1, V9 is cellular, V4 is tertiary, V3 is single, Class is 1
# [Truncated at label] V15 is 0, V8 is no, V7 is yes, V13 is 2, V8 is no, V7 is yes, V1 is 51, V4 is secondary, V14 is -1, V8 is no, V16 is unknown, V13 is 2, V6 is -1, V9 is cellular, V4 is tertiary, V3 is single
# [Parsed Features] {'V15': '0', 'V8': 'no', 'V7': 'yes', 'V13': '2', 'V1': '51', 'V4': 'secondary', 'V14': '-1', 'V16': 'unknown', 'V6': '-1', 'V9': 'cellular', 'V3': 'single'}
# [Filled Missing Feature] V2 with blue-collar
# [Filled Missing Feature] V5 with no
# [Filled Missing Feature] V10 with 8
# [Filled Missing Feature] V11 with may
# [Filled Missing Feature] V12 with 129
# [Raw Output] V6 is -342, V3 is single, V4 is secondary, V7 is no, V10 is 12, V11 is jul, V12 is 188, V13 is 3, V14 is -1, V15 is 0, V16 is unknown, V9 is cellular, V16 is unknown, V5 is no, V11 is aug, V12 is 152, Class is 1
# [Truncated at label] V6 is -342, V3 is single, V4 is secondary, V7 is no, V10 is 12, V11 is jul, V12 is 188, V13 is 3, V14 is -1, V15 is 0, V16 is unknown, V9 is cellular, V16 is unknown, V5 is no, V11 is aug, V12 is 152
# [Parsed Features] {'V6': '-342', 'V3': 'single', 'V4': 'secondary', 'V7': 'no', 'V10': '12', 'V11': 'jul', 'V12': '188', 'V13': '3', 'V14': '-1', 'V15': '0', 'V16': 'unknown', 'V9': 'cellular', 'V5': 'no'}
# [Filled Missing Feature] V1 with 35
# [Filled Missing Feature] V2 with unknown
# [Filled Missing Feature] V8 with no
# [Raw Output] V4 is secondary, V8 is no, V11 is jul, V12 is 111, V5 is no, V3 is married, V2 is retired, V1 is 37, V10 is 12, V11 is jun, V6 is 891, V6 is 24, V2 is admin., V13 is 1, V16 is failure, Class is 1
# [Truncated at label] V4 is secondary, V8 is no, V11 is jul, V12 is 111, V5 is no, V3 is married, V2 is retired, V1 is 37, V10 is 12, V11 is jun, V6 is 891, V6 is 24, V2 is admin., V13 is 1, V16 is failure
# [Parsed Features] {'V4': 'secondary', 'V8': 'no', 'V11': 'jul', 'V12': '111', 'V5': 'no', 'V3': 'married', 'V2': 'retired', 'V1': '37', 'V10': '12', 'V6': '891', 'V13': '1', 'V16': 'failure'}
# [Filled Missing Feature] V7 with yes
# [Filled Missing Feature] V9 with cellular
# [Filled Missing Feature] V14 with -1
# [Filled Missing Feature] V15 with 0
# [Raw Output] V11 is may, V5 is no, V16 is unknown, V2 is management, V15 is 0, V5 is no, V10 is 14, V5 is no, V3 is married, V9 is cellular, V5 is no, V2 is management, V4 is primary, V9 is unknown, V2 is management, V1 is 35, Class is 1
# [Truncated at label] V11 is may, V5 is no, V16 is unknown, V2 is management, V15 is 0, V5 is no, V10 is 14, V5 is no, V3 is married, V9 is cellular, V5 is no, V2 is management, V4 is primary, V9 is unknown, V2 is management, V1 is 35
# [Parsed Features] {'V11': 'may', 'V5': 'no', 'V16': 'unknown', 'V2': 'management', 'V15': '0', 'V10': '14', 'V3': 'married', 'V9': 'cellular', 'V4': 'primary', 'V1': '35'}
# [Filled Missing Feature] V6 with 462
# [Filled Missing Feature] V7 with yes
# [Filled Missing Feature] V8 with no
# [Filled Missing Feature] V12 with 122
# [Filled Missing Feature] V13 with 2
# [Filled Missing Feature] V14 with 182
# [Raw Output] V4 is tertiary, V15 is 0, V2 is technician, V11 is may, V14 is -1, V16 is unknown, V13 is 1, V7 is yes, V1 is 43, V4 is secondary, V5 is no, V9 is unknown, V14 is -1, V16 is unknown, V1 is 34, Class is 1
# [Truncated at label] V4 is tertiary, V15 is 0, V2 is technician, V11 is may, V14 is -1, V16 is unknown, V13 is 1, V7 is yes, V1 is 43, V4 is secondary, V5 is no, V9 is unknown, V14 is -1, V16 is unknown, V1 is 34
# [Parsed Features] {'V4': 'tertiary', 'V15': '0', 'V2': 'technician', 'V11': 'may', 'V14': '-1', 'V16': 'unknown', 'V13': '1', 'V7': 'yes', 'V1': '43', 'V5': 'no', 'V9': 'unknown'}
# [Filled Missing Feature] V3 with single
# [Filled Missing Feature] V6 with -287
# [Filled Missing Feature] V8 with no
# [Filled Missing Feature] V10 with 14
# [Filled Missing Feature] V12 with 7
# [Raw Output] V7 is yes, V10 is 13, V15 is 0, V2 is management, V1 is 43, V10 is 13, V14 is -1, V2 is management, V4 is primary, V8 is no, V10 is 16, V14 is -1, V5 is no, V16 is unknown, V1 is 56, Class is 1
# [Truncated at label] V7 is yes, V10 is 13, V15 is 0, V2 is management, V1 is 43, V10 is 13, V14 is -1, V2 is management, V4 is primary, V8 is no, V10 is 16, V14 is -1, V5 is no, V16 is unknown, V1 is 56
# [Parsed Features] {'V7': 'yes', 'V10': '13', 'V15': '0', 'V2': 'management', 'V1': '43', 'V14': '-1', 'V4': 'primary', 'V8': 'no', 'V5': 'no', 'V16': 'unknown'}
# [Filled Missing Feature] V3 with married
# [Filled Missing Feature] V6 with 4660
# [Filled Missing Feature] V9 with cellular
# [Filled Missing Feature] V11 with jul
# [Filled Missing Feature] V12 with 133
# [Filled Missing Feature] V13 with 6
# [Raw Output] V2 is technician, V3 is married, V4 is tertiary, V5 is no, V6 is 7, V7 is no, V8 is no, V9 is cellular, V10 is 11, V11 is apr, V12 is 632, V13 is 3, V14 is -1, V15 is 0, V16 is unknown, Class is 1
# [Truncated at label] V2 is technician, V3 is married, V4 is tertiary, V5 is no, V6 is 7, V7 is no, V8 is no, V9 is cellular, V10 is 11, V11 is apr, V12 is 632, V13 is 3, V14 is -1, V15 is 0, V16 is unknown
# [Parsed Features] {'V2': 'technician', 'V3': 'married', 'V4': 'tertiary', 'V5': 'no', 'V6': '7', 'V7': 'no', 'V8': 'no', 'V9': 'cellular', 'V10': '11', 'V11': 'apr', 'V12': '632', 'V13': '3', 'V14': '-1', 'V15': '0', 'V16': 'unknown'}
# [Filled Missing Feature] V1 with 26
# [Raw Output] V5 is no, V10 is 28, V8 is no, V1 is 55, V12 is 217, V16 is failure, V7 is yes, V2 is management, V14 is -1, V4 is secondary, V14 is -1, V5 is no, V9 is unknown, V5 is no, V16 is unknown, V11 is may, Class is 1
# [Truncated at label] V5 is no, V10 is 28, V8 is no, V1 is 55, V12 is 217, V16 is failure, V7 is yes, V2 is management, V14 is -1, V4 is secondary, V14 is -1, V5 is no, V9 is unknown, V5 is no, V16 is unknown, V11 is may
# [Parsed Features] {'V5': 'no', 'V10': '28', 'V8': 'no', 'V1': '55', 'V12': '217', 'V16': 'failure', 'V7': 'yes', 'V2': 'management', 'V14': '-1', 'V4': 'secondary', 'V9': 'unknown', 'V11': 'may'}
# [Filled Missing Feature] V3 with married
# [Filled Missing Feature] V6 with 339
# [Filled Missing Feature] V13 with 4
# [Filled Missing Feature] V15 with 0
# [Raw Output] V13 is 3, V14 is -1, V7 is yes, V1 is 53, V14 is -1, V14 is -1, V5 is no, V12 is 7, V6 is -312, V9 is unknown, V2 is blue-collar, V12 is 73, V6 is 0, V1 is 55, V13 is 2, Class is 1
# [Truncated at label] V13 is 3, V14 is -1, V7 is yes, V1 is 53, V14 is -1, V14 is -1, V5 is no, V12 is 7, V6 is -312, V9 is unknown, V2 is blue-collar, V12 is 73, V6 is 0, V1 is 55, V13 is 2
# [Parsed Features] {'V13': '3', 'V14': '-1', 'V7': 'yes', 'V1': '53', 'V5': 'no', 'V12': '7', 'V6': '-312', 'V9': 'unknown', 'V2': 'blue-collar'}
# [Filled Missing Feature] V3 with married
# [Filled Missing Feature] V4 with secondary
# [Filled Missing Feature] V8 with no
# [Filled Missing Feature] V10 with 18
# [Filled Missing Feature] V11 with aug
# [Filled Missing Feature] V15 with 0
# [Filled Missing Feature] V16 with unknown
# [Raw Output] V9 is cellular, V10 is 20, V1 is 40, V15 is 0, V10 is 19, V9 is cellular, V8 is no, V10 is 12, V13 is 2, V4 is secondary, V6 is -15, V10 is 20, V9 is cellular, V7 is yes, V12 is 124, V13 is 3, Class is 1
# [Truncated at label] V9 is cellular, V10 is 20, V1 is 40, V15 is 0, V10 is 19, V9 is cellular, V8 is no, V10 is 12, V13 is 2, V4 is secondary, V6 is -15, V10 is 20, V9 is cellular, V7 is yes, V12 is 124, V13 is 3
# [Parsed Features] {'V9': 'cellular', 'V10': '20', 'V1': '40', 'V15': '0', 'V8': 'no', 'V13': '2', 'V4': 'secondary', 'V6': '-15', 'V7': 'yes', 'V12': '124'}
# [Filled Missing Feature] V2 with services
# [Filled Missing Feature] V3 with married
# [Filled Missing Feature] V5 with no
# [Filled Missing Feature] V11 with aug
# [Filled Missing Feature] V14 with -1
# [Filled Missing Feature] V16 with unknown
# [Raw Output] V9 is cellular, V10 is 18, V2 is management, V11 is aug, V15 is 0, V9 is cellular, V3 is married, V16 is unknown, V12 is 196, V11 is jun, V7 is yes, V13 is 2, V7 is no, V8 is no, V12 is 486, V14 is -1, Class is 1
# [Truncated at label] V9 is cellular, V10 is 18, V2 is management, V11 is aug, V15 is 0, V9 is cellular, V3 is married, V16 is unknown, V12 is 196, V11 is jun, V7 is yes, V13 is 2, V7 is no, V8 is no, V12 is 486, V14 is -1
# [Parsed Features] {'V9': 'cellular', 'V10': '18', 'V2': 'management', 'V11': 'aug', 'V15': '0', 'V3': 'married', 'V16': 'unknown', 'V12': '196', 'V7': 'yes', 'V13': '2', 'V8': 'no', 'V14': '-1'}
# [Filled Missing Feature] V1 with 54
# [Filled Missing Feature] V4 with primary
# [Filled Missing Feature] V5 with no
# [Filled Missing Feature] V6 with 440
# [Raw Output] V14 is -1, V15 is 0, V9 is cellular, V13 is 2, V14 is -1, V7 is yes, V2 is technician, V3 is married, V2 is admin., V11 is jun, V10 is 14, V1 is 38, V12 is 110, V7 is no, V8 is no, V4 is secondary, Class is 1
# ...
# [Truncated at label] V12 is 285, V1 is 33, V2 is management, V3 is single, V4 is primary, V5 is no, V6 is -95, V7 is yes, V8 is no, V9 is cellular, V10 is 11, V11 is jul, V12 is 614, V13 is 2, V14 is -1, V15 is 0
# [Parsed Features] {'V12': '285', 'V1': '33', 'V2': 'management', 'V3': 'single', 'V4': 'primary', 'V5': 'no', 'V6': '-95', 'V7': 'yes', 'V8': 'no', 'V9': 'cellular', 'V10': '11', 'V11': 'jul', 'V13': '2', 'V14': '-1', 'V15': '0'}
# [Filled Missing Feature] V16 with unknown
# [Raw Output] V16 is unknown, V13 is 2, V9 is cellular, V2 is blue-collar, V1 is 39, V16 is failure, V7 is no, V12 is 246, V1 is 41, V5 is no, V1 is 35, V6 is 472, V5 is no, V14 is -1, V7 is yes, V12 is 223, Class is 1
# [Truncated at label] V16 is unknown, V13 is 2, V9 is cellular, V2 is blue-collar, V1 is 39, V16 is failure, V7 is no, V12 is 246, V1 is 41, V5 is no, V1 is 35, V6 is 472, V5 is no, V14 is -1, V7 is yes, V12 is 223
# [Parsed Features] {'V16': 'unknown', 'V13': '2', 'V9': 'cellular', 'V2': 'blue-collar', 'V1': '39', 'V7': 'no', 'V12': '246', 'V5': 'no', 'V6': '472', 'V14': '-1'}
# [Filled Missing Feature] V3 with married
# [Filled Missing Feature] V4 with secondary
# [Filled Missing Feature] V8 with no
# [Filled Missing Feature] V10 with 28
# [Filled Missing Feature] V11 with jul
# [Filled Missing Feature] V15 with 0
# [Raw Output] V14 is -1, V9 is cellular, V16 is unknown, V15 is 0, V4 is secondary, V8 is no, V11 is aug, V13 is 1, V15 is 0, V10 is 6, V3 is married, V9 is cellular, V4 is tertiary, V13 is 1, V4 is secondary, V5 is no, Class is 1
# [Truncated at label] V14 is -1, V9 is cellular, V16 is unknown, V15 is 0, V4 is secondary, V8 is no, V11 is aug, V13 is 1, V15 is 0, V10 is 6, V3 is married, V9 is cellular, V4 is tertiary, V13 is 1, V4 is secondary, V5 is no
# [Parsed Features] {'V14': '-1', 'V9': 'cellular', 'V16': 'unknown', 'V15': '0', 'V4': 'secondary', 'V8': 'no', 'V11': 'aug', 'V13': '1', 'V10': '6', 'V3': 'married', 'V5': 'no'}
# [Filled Missing Feature] V1 with 55
# [Filled Missing Feature] V2 with student
# [Filled Missing Feature] V6 with -27
# [Filled Missing Feature] V7 with no
# [Filled Missing Feature] V12 with 66
# [Raw Output] V12 is 255, V15 is 0, V16 is unknown, V9 is unknown, V6 is 0, V9 is cellular, V8 is no, V3 is married, V1 is 29, V7 is yes, V8 is no, V15 is 1, V11 is apr, V1 is 33, V4 is secondary, V3 is single, Class is 1
# [Truncated at label] V12 is 255, V15 is 0, V16 is unknown, V9 is unknown, V6 is 0, V9 is cellular, V8 is no, V3 is married, V1 is 29, V7 is yes, V8 is no, V15 is 1, V11 is apr, V1 is 33, V4 is secondary, V3 is single
# [Parsed Features] {'V12': '255', 'V15': '0', 'V16': 'unknown', 'V9': 'unknown', 'V6': '0', 'V8': 'no', 'V3': 'married', 'V1': '29', 'V7': 'yes', 'V11': 'apr', 'V4': 'secondary'}
# [Filled Missing Feature] V2 with technician
# [Filled Missing Feature] V5 with no
# [Filled Missing Feature] V10 with 18
# [Filled Missing Feature] V13 with 1
# [Filled Missing Feature] V14 with -1
# [Raw Output] V5 is no, V8 is no, V15 is 0, V7 is yes, V5 is no, V6 is 0, V7 is no, V13 is 1, V15 is 0, V16 is unknown, V12 is 184, V7 is yes, V8 is no, V10 is 30, V3 is single, Class is 1
# [Truncated at label] V5 is no, V8 is no, V15 is 0, V7 is yes, V5 is no, V6 is 0, V7 is no, V13 is 1, V15 is 0, V16 is unknown, V12 is 184, V7 is yes, V8 is no, V10 is 30, V3 is single
# [Parsed Features] {'V5': 'no', 'V8': 'no', 'V15': '0', 'V7': 'yes', 'V6': '0', 'V13': '1', 'V16': 'unknown', 'V12': '184', 'V10': '30', 'V3': 'single'}
# [Filled Missing Feature] V1 with 37
# [Filled Missing Feature] V2 with management
# [Filled Missing Feature] V4 with secondary
# [Filled Missing Feature] V9 with cellular
# [Filled Missing Feature] V11 with may
# [Filled Missing Feature] V14 with 183
# [Raw Output] V8 is no, V13 is 2, V3 is married, V1 is 33, V16 is unknown, V13 is 2, V10 is 25, V15 is 0, V5 is no, V8 is no, V14 is -1, V2 is management, V4 is tertiary, V1 is 51, V6 is 1384, Class is 1
# [Truncated at label] V8 is no, V13 is 2, V3 is married, V1 is 33, V16 is unknown, V13 is 2, V10 is 25, V15 is 0, V5 is no, V8 is no, V14 is -1, V2 is management, V4 is tertiary, V1 is 51, V6 is 1384
# [Parsed Features] {'V8': 'no', 'V13': '2', 'V3': 'married', 'V1': '33', 'V16': 'unknown', 'V10': '25', 'V15': '0', 'V5': 'no', 'V14': '-1', 'V2': 'management', 'V4': 'tertiary', 'V6': '1384'}
# [Filled Missing Feature] V7 with no
# [Filled Missing Feature] V9 with unknown
# [Filled Missing Feature] V11 with feb
# [Filled Missing Feature] V12 with 70
# [Raw Output] V6 is 184, V7 is yes, V8 is no, V8 is no, V9 is cellular, V10 is 9, V11 is may, V12 is 151, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, V17 is unknown, V18 is 0, V19 is unknown, Class is 1
# [Truncated at label] V6 is 184, V7 is yes, V8 is no, V8 is no, V9 is cellular, V10 is 9, V11 is may, V12 is 151, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, V17 is unknown, V18 is 0, V19 is unknown
# [Parsed Features] {'V6': '184', 'V7': 'yes', 'V8': 'no', 'V9': 'cellular', 'V10': '9', 'V11': 'may', 'V12': '151', 'V13': '1', 'V14': '-1', 'V15': '0', 'V16': 'unknown'}
# [Filled Missing Feature] V1 with 51
# [Filled Missing Feature] V2 with self-employed
# [Filled Missing Feature] V3 with married
# [Filled Missing Feature] V4 with primary
# [Filled Missing Feature] V5 with no
# [Raw Output] V13 is 5, V8 is no, V1 is 33, V14 is -1, V5 is no, V4 is secondary, V2 is blue-collar, V13 is 2, V16 is unknown, V5 is no, V4 is tertiary, V11 is jun, V13 is 3, V8 is no, V13 is 2, Class is 1
# [Truncated at label] V13 is 5, V8 is no, V1 is 33, V14 is -1, V5 is no, V4 is secondary, V2 is blue-collar, V13 is 2, V16 is unknown, V5 is no, V4 is tertiary, V11 is jun, V13 is 3, V8 is no, V13 is 2
# [Parsed Features] {'V13': '5', 'V8': 'no', 'V1': '33', 'V14': '-1', 'V5': 'no', 'V4': 'secondary', 'V2': 'blue-collar', 'V16': 'unknown', 'V11': 'jun'}
# [Filled Missing Feature] V3 with married
# [Filled Missing Feature] V6 with 2887
# [Filled Missing Feature] V7 with yes
# [Filled Missing Feature] V9 with unknown
# [Filled Missing Feature] V10 with 27
# [Filled Missing Feature] V12 with 597
# [Filled Missing Feature] V15 with 0
# [Raw Output] V7 is no, V12 is 587, V10 is 25, V8 is yes, V8 is no, V3 is divorced, V10 is 25, V15 is 0, V14 is -1, V9 is cellular, V8 is no, V12 is 182, V14 is -1, V3 is married, V10 is 17, V3 is divorced, Class is 1
# [Truncated at label] V7 is no, V12 is 587, V10 is 25, V8 is yes, V8 is no, V3 is divorced, V10 is 25, V15 is 0, V14 is -1, V9 is cellular, V8 is no, V12 is 182, V14 is -1, V3 is married, V10 is 17, V3 is divorced
# [Parsed Features] {'V7': 'no', 'V12': '587', 'V10': '25', 'V8': 'yes', 'V3': 'divorced', 'V15': '0', 'V14': '-1', 'V9': 'cellular'}
# [Filled Missing Feature] V1 with 51
# [Filled Missing Feature] V2 with admin.
# [Filled Missing Feature] V4 with tertiary
# [Filled Missing Feature] V5 with no
# [Filled Missing Feature] V6 with 43
# [Filled Missing Feature] V11 with may
# [Filled Missing Feature] V13 with 2
# [Filled Missing Feature] V16 with failure
# [Raw Output] V13 is 1, V1 is 58, V10 is 20, V9 is cellular, V2 is technician, V15 is 0, V6 is 936, V7 is yes, V15 is 0, V5 is no, V14 is -1, V9 is cellular, V3 is single, V16 is unknown, V1 is 58, V4 is tertiary, Class is 1
# [Truncated at label] V13 is 1, V1 is 58, V10 is 20, V9 is cellular, V2 is technician, V15 is 0, V6 is 936, V7 is yes, V15 is 0, V5 is no, V14 is -1, V9 is cellular, V3 is single, V16 is unknown, V1 is 58, V4 is tertiary
# [Parsed Features] {'V13': '1', 'V1': '58', 'V10': '20', 'V9': 'cellular', 'V2': 'technician', 'V15': '0', 'V6': '936', 'V7': 'yes', 'V5': 'no', 'V14': '-1', 'V3': 'single', 'V16': 'unknown', 'V4': 'tertiary'}
# [Filled Missing Feature] V8 with no
# [Filled Missing Feature] V11 with apr
# [Filled Missing Feature] V12 with 163
# [Raw Output] V3 is married, V14 is -1, V6 is 2968, V16 is unknown, V2 is management, V7 is no, V7 is no, V10 is 20, V15 is 0, V4 is secondary, V9 is cellular, V6 is -1, V12 is 974, V15 is 0, V4 is secondary, Class is 1
# [Truncated at label] V3 is married, V14 is -1, V6 is 2968, V16 is unknown, V2 is management, V7 is no, V7 is no, V10 is 20, V15 is 0, V4 is secondary, V9 is cellular, V6 is -1, V12 is 974, V15 is 0, V4 is secondary
# [Parsed Features] {'V3': 'married', 'V14': '-1', 'V6': '2968', 'V16': 'unknown', 'V2': 'management', 'V7': 'no', 'V10': '20', 'V15': '0', 'V4': 'secondary', 'V9': 'cellular', 'V12': '974'}
# [Filled Missing Feature] V1 with 33
# [Filled Missing Feature] V5 with no
# [Filled Missing Feature] V8 with no
# [Filled Missing Feature] V11 with nov
# [Filled Missing Feature] V13 with 2
# [Raw Output] V5 is no, V11 is may, V6 is 1311, V3 is single, V5 is no, V4 is tertiary, V13 is 2, V6 is 705, V12 is 467, V7 is no, V4 is tertiary, V16 is failure, V1 is 35, V12 is 104, V15 is 2, Class is 1
# [Truncated at label] V5 is no, V11 is may, V6 is 1311, V3 is single, V5 is no, V4 is tertiary, V13 is 2, V6 is 705, V12 is 467, V7 is no, V4 is tertiary, V16 is failure, V1 is 35, V12 is 104, V15 is 2
# [Parsed Features] {'V5': 'no', 'V11': 'may', 'V6': '1311', 'V3': 'single', 'V4': 'tertiary', 'V13': '2', 'V12': '467', 'V7': 'no', 'V16': 'failure', 'V1': '35', 'V15': '2'}
# [Filled Missing Feature] V2 with technician
# [Filled Missing Feature] V8 with no
# [Filled Missing Feature] V9 with cellular
# [Filled Missing Feature] V10 with 8
# [Filled Missing Feature] V14 with -1
# [Raw Output] V10 is 5, V3 is married, V16 is unknown, V1 is 53, V2 is admin., V3 is married, V10 is 11, V9 is cellular, V4 is tertiary, V12 is 196, V5 is no, V14 is -1, V5 is no, V6 is 0, V7 is no, V10 is 26, Class is 1
# [Truncated at label] V10 is 5, V3 is married, V16 is unknown, V1 is 53, V2 is admin., V3 is married, V10 is 11, V9 is cellular, V4 is tertiary, V12 is 196, V5 is no, V14 is -1, V5 is no, V6 is 0, V7 is no, V10 is 26
# [Parsed Features] {'V10': '5', 'V3': 'married', 'V16': 'unknown', 'V1': '53', 'V2': 'admin.', 'V9': 'cellular', 'V4': 'tertiary', 'V12': '196', 'V5': 'no', 'V14': '-1', 'V6': '0', 'V7': 'no'}
# [Filled Missing Feature] V8 with no
# [Filled Missing Feature] V11 with nov
# [Filled Missing Feature] V13 with 4
# [Filled Missing Feature] V15 with 1
# [Raw Output] V4 is secondary, V16 is unknown, V13 is 2, V3 is single, V1 is 33, V3 is married, V6 is 955, V2 is management, V16 is unknown, V15 is 0, V16 is unknown, V14 is -1, V7 is yes, V8 is no, V8 is no, V11 is jul, Class is 1
# [Truncated at label] V4 is secondary, V16 is unknown, V13 is 2, V3 is single, V1 is 33, V3 is married, V6 is 955, V2 is management, V16 is unknown, V15 is 0, V16 is unknown, V14 is -1, V7 is yes, V8 is no, V8 is no, V11 is jul
# [Parsed Features] {'V4': 'secondary', 'V16': 'unknown', 'V13': '2', 'V3': 'single', 'V1': '33', 'V6': '955', 'V2': 'management', 'V15': '0', 'V14': '-1', 'V7': 'yes', 'V8': 'no', 'V11': 'jul'}
# [Filled Missing Feature] V5 with no
# [Filled Missing Feature] V9 with cellular
# [Filled Missing Feature] V10 with 9
# [Filled Missing Feature] V12 with 135
# [Raw Output] V14 is -1, V2 is blue-collar, V13 is 5, V4 is secondary, V5 is no, V11 is jun, V12 is 633, V10 is 14, V13 is 5, V12 is 1, V10 is 11, V7 is yes, V12 is 588, V2 is technician, V2 is technician, Class is 1
# [Truncated at label] V14 is -1, V2 is blue-collar, V13 is 5, V4 is secondary, V5 is no, V11 is jun, V12 is 633, V10 is 14, V13 is 5, V12 is 1, V10 is 11, V7 is yes, V12 is 588, V2 is technician, V2 is technician
# [Parsed Features] {'V14': '-1', 'V2': 'blue-collar', 'V13': '5', 'V4': 'secondary', 'V5': 'no', 'V11': 'jun', 'V12': '633', 'V10': '14', 'V7': 'yes'}
# [Filled Missing Feature] V1 with 28
# [Filled Missing Feature] V3 with single
# [Filled Missing Feature] V6 with 1818
# [Filled Missing Feature] V8 with no
# [Filled Missing Feature] V9 with cellular
# [Filled Missing Feature] V15 with 0
# [Filled Missing Feature] V16 with failure
# [Raw Output] V5 is no, V11 is jul, V4 is tertiary, V10 is 13, V7 is no, V6 is -196, V11 is jul, V4 is tertiary, V8 is no, V12 is 136, V7 is no, V2 is management, V1 is 52, V8 is no, V7 is yes, Class is 1
# [Truncated at label] V5 is no, V11 is jul, V4 is tertiary, V10 is 13, V7 is no, V6 is -196, V11 is jul, V4 is tertiary, V8 is no, V12 is 136, V7 is no, V2 is management, V1 is 52, V8 is no, V7 is yes
# [Parsed Features] {'V5': 'no', 'V11': 'jul', 'V4': 'tertiary', 'V10': '13', 'V7': 'no', 'V6': '-196', 'V8': 'no', 'V12': '136', 'V2': 'management', 'V1': '52'}
# [Filled Missing Feature] V3 with married
# [Filled Missing Feature] V9 with unknown
# [Filled Missing Feature] V13 with 1
# [Filled Missing Feature] V14 with -1
# [Filled Missing Feature] V15 with 1
# [Filled Missing Feature] V16 with unknown
# [Raw Output] V7 is yes, V12 is 586, V15 is 0, V12 is 683, V2 is entrepreneur, V11 is jun, V9 is cellular, V9 is cellular, V5 is no, V3 is married, V12 is 1, V1 is 41, V7 is no, V2 is blue-collar, V10 is 20, V16 is failure, Class is 1
# [Truncated at label] V7 is yes, V12 is 586, V15 is 0, V12 is 683, V2 is entrepreneur, V11 is jun, V9 is cellular, V9 is cellular, V5 is no, V3 is married, V12 is 1, V1 is 41, V7 is no, V2 is blue-collar, V10 is 20, V16 is failure
# [Parsed Features] {'V7': 'yes', 'V12': '586', 'V15': '0', 'V2': 'entrepreneur', 'V11': 'jun', 'V9': 'cellular', 'V5': 'no', 'V3': 'married', 'V1': '41', 'V10': '20', 'V16': 'failure'}
# [Filled Missing Feature] V4 with tertiary
# [Filled Missing Feature] V6 with 230
# [Filled Missing Feature] V8 with no
# [Filled Missing Feature] V13 with 2
# [Filled Missing Feature] V14 with -1
# [Raw Output] V7 is no, V2 is admin., V16 is unknown, V8 is no, V15 is 0, V8 is no, V9 is cellular, V7 is yes, V12 is 184, V16 is unknown, V14 is -1, V3 is married, V7 is no, V1 is 43, V11 is may, V7 is no, Class is 1
# [Truncated at label] V7 is no, V2 is admin., V16 is unknown, V8 is no, V15 is 0, V8 is no, V9 is cellular, V7 is yes, V12 is 184, V16 is unknown, V14 is -1, V3 is married, V7 is no, V1 is 43, V11 is may, V7 is no
# [Parsed Features] {'V7': 'no', 'V2': 'admin.', 'V16': 'unknown', 'V8': 'no', 'V15': '0', 'V9': 'cellular', 'V12': '184', 'V14': '-1', 'V3': 'married', 'V1': '43', 'V11': 'may'}
# [Filled Missing Feature] V4 with tertiary
# [Filled Missing Feature] V5 with no
# [Filled Missing Feature] V6 with 3492
# [Filled Missing Feature] V10 with 5
# [Filled Missing Feature] V13 with 4
# [Raw Output] V4 is tertiary, V16 is unknown, V2 is services, V11 is jul, V15 is 0, V12 is 111, V4 is secondary, V2 is management, V3 is single, V12 is 144, V9 is cellular, V10 is 21, V4 is tertiary, V15 is 0, V1 is 57, Class is 1
# [Truncated at label] V4 is tertiary, V16 is unknown, V2 is services, V11 is jul, V15 is 0, V12 is 111, V4 is secondary, V2 is management, V3 is single, V12 is 144, V9 is cellular, V10 is 21, V4 is tertiary, V15 is 0, V1 is 57
# [Parsed Features] {'V4': 'tertiary', 'V16': 'unknown', 'V2': 'services', 'V11': 'jul', 'V15': '0', 'V12': '111', 'V3': 'single', 'V9': 'cellular', 'V10': '21', 'V1': '57'}
# [Filled Missing Feature] V5 with no
# [Filled Missing Feature] V6 with 324
# [Filled Missing Feature] V7 with yes
# [Filled Missing Feature] V8 with no
# [Filled Missing Feature] V13 with 1
# [Filled Missing Feature] V14 with -1
# [Raw Output] V4 is secondary, V16 is failure, V10 is 13, V7 is yes, V1 is 47, V10 is 21, V7 is yes, V6 is 2936, V11 is may, V12 is 103, V6 is 3030, V2 is blue-collar, V11 is may, V16 is failure, V14 is -1, Class is 1
# [Truncated at label] V4 is secondary, V16 is failure, V10 is 13, V7 is yes, V1 is 47, V10 is 21, V7 is yes, V6 is 2936, V11 is may, V12 is 103, V6 is 3030, V2 is blue-collar, V11 is may, V16 is failure, V14 is -1
# [Parsed Features] {'V4': 'secondary', 'V16': 'failure', 'V10': '13', 'V7': 'yes', 'V1': '47', 'V6': '2936', 'V11': 'may', 'V12': '103', 'V2': 'blue-collar', 'V14': '-1'}
# [Filled Missing Feature] V3 with married
# [Filled Missing Feature] V5 with no
# [Filled Missing Feature] V8 with no
# [Filled Missing Feature] V9 with telephone
# [Filled Missing Feature] V13 with 1
# [Filled Missing Feature] V15 with 0
# Generated 2000 synthetic feature rows.

# %%
# STEP 3
# ---------- Label-query phase: get Y (Patch 1: tighter parsing) ----------
print("\nQuerying labels (Y) …")

VALID_LABELS = {"<=50K", ">50K"}

def label_query(feat_row: dict) -> str:
  '''Serializes features in the original order,
  then lets the model continue to produce "income is <value>'''
    # Builds the prompt: 'feature is value, feature is value, ...'
  parts = [f"{c} is {feat_row[c]}" for c in FEATURES]
  prompt = ", ".join(parts) + ", "
  print(f"\n Prompt to model {prompt}")
  inputs = tok(prompt, return_tensors="pt").to(model.device)

  # Runs the model
  out = model.generate(
  **inputs,
  max_new_tokens=8,
  do_sample=False,
  temperature=0.0,
  top_p=1.0,
  pad_token_id=tok.eos_token_id,
  eos_token_id=tok.eos_token_id,
)
  text = tok.decode(out[0], skip_special_tokens=True)
  print(f"[Model Output] {text}")

  # Prefer exact known labels first
  for v in VALID_LABELS:
      if f"{LABEL} is {v}" in text:     # orders the known labels first
          print(f"Label found {v}")
          return v

  # Fallback regex (looser)
  m = re.search(rf"{LABEL}\s+is\s+([^\s,]+)", text)     # regex used to fix any formatting issues
  if m:
      cand = m.group(1).strip()
      cand = cand.replace(".", "")                  # normalization in case of punctuation
      for v in VALID_LABELS:
          if cand.lower() == v.lower():
              return v
  print("No label found - switching to random label")
  return None

synthetic_rows = []

print(f"\n Labeling {len(synthetic_X)} synthetic rows...")
for fx in synthetic_X:
    # print(f"\n Row {i+1}")
    y = label_query(fx)
    if y is None:
        print(f"Randomly selected label: {y}")
        y = random.choice(df[LABEL].tolist())
    synthetic_rows.append({**fx, LABEL: y})

syn_df = pd.DataFrame(synthetic_rows)

# Save synthetic CSV
os.makedirs("data", exist_ok=True)
syn_df.to_csv(CSV_OUT, index=False)
print(f"\nSaved synthetic dataset to: {CSV_OUT}")

print("\nSample synthetic rows:")
print(syn_df.head(10).to_string(index=False))
# Out:
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Streaming output truncated to the last 5000 lines.
#
#  Prompt to model V1 is 56, V2 is blue-collar, V3 is married, V4 is secondary, V5 is no, V6 is 464, V7 is no, V8 is no, V9 is unknown, V10 is 12, V11 is may, V12 is 113, V13 is 2, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 56, V2 is blue-collar, V3 is married, V4 is secondary, V5 is no, V6 is 464, V7 is no, V8 is no, V9 is unknown, V10 is 12, V11 is may, V12 is 113, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, ia is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 47, V2 is management, V3 is married, V4 is tertiary, V5 is no, V6 is 486, V7 is yes, V8 is yes, V9 is telephone, V10 is 14, V11 is jul, V12 is 858, V13 is 2, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 47, V2 is management, V3 is married, V4 is tertiary, V5 is no, V6 is 486, V7 is yes, V8 is yes, V9 is telephone, V10 is 14, V11 is jul, V12 is 858, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 39, V2 is management, V3 is married, V4 is secondary, V5 is no, V6 is 553, V7 is yes, V8 is no, V9 is cellular, V10 is 14, V11 is aug, V12 is 675, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 39, V2 is management, V3 is married, V4 is secondary, V5 is no, V6 is 553, V7 is yes, V8 is no, V9 is cellular, V10 is 14, V11 is aug, V12 is 675, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 44, V2 is management, V3 is married, V4 is tertiary, V5 is no, V6 is 1541, V7 is yes, V8 is no, V9 is cellular, V10 is 19, V11 is jul, V12 is 1371, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 44, V2 is management, V3 is married, V4 is tertiary, V5 is no, V6 is 1541, V7 is yes, V8 is no, V9 is cellular, V10 is 19, V11 is jul, V12 is 1371, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 38, V2 is blue-collar, V3 is single, V4 is tertiary, V5 is no, V6 is 469, V7 is yes, V8 is no, V9 is unknown, V10 is 21, V11 is aug, V12 is 126, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 38, V2 is blue-collar, V3 is single, V4 is tertiary, V5 is no, V6 is 469, V7 is yes, V8 is no, V9 is unknown, V10 is 21, V11 is aug, V12 is 126, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 35, V2 is management, V3 is married, V4 is secondary, V5 is no, V6 is 261, V7 is yes, V8 is yes, V9 is unknown, V10 is 20, V11 is jul, V12 is 190, V13 is 2, V14 is -1, V15 is 0, V16 is failure,
# [Model Output] V1 is 35, V2 is management, V3 is married, V4 is secondary, V5 is no, V6 is 261, V7 is yes, V8 is yes, V9 is unknown, V10 is 20, V11 is jul, V12 is 190, V13 is 2, V14 is -1, V15 is 0, V16 is failure, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 35, V2 is services, V3 is single, V4 is secondary, V5 is no, V6 is 0, V7 is yes, V8 is no, V9 is cellular, V10 is 24, V11 is apr, V12 is 168, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 35, V2 is services, V3 is single, V4 is secondary, V5 is no, V6 is 0, V7 is yes, V8 is no, V9 is cellular, V10 is 24, V11 is apr, V12 is 168, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 26, V2 is entrepreneur, V3 is divorced, V4 is tertiary, V5 is no, V6 is -333, V7 is no, V8 is no, V9 is cellular, V10 is 19, V11 is jun, V12 is 108, V13 is 2, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 26, V2 is entrepreneur, V3 is divorced, V4 is tertiary, V5 is no, V6 is -333, V7 is no, V8 is no, V9 is cellular, V10 is 19, V11 is jun, V12 is 108, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 34, V2 is blue-collar, V3 is married, V4 is tertiary, V5 is no, V6 is 815, V7 is yes, V8 is no, V9 is cellular, V10 is 28, V11 is jun, V12 is 239, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 34, V2 is blue-collar, V3 is married, V4 is tertiary, V5 is no, V6 is 815, V7 is yes, V8 is no, V9 is cellular, V10 is 28, V11 is jun, V12 is 239, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 49, V2 is entrepreneur, V3 is single, V4 is tertiary, V5 is no, V6 is 623, V7 is yes, V8 is no, V9 is cellular, V10 is 20, V11 is apr, V12 is 124, V13 is 2, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 49, V2 is entrepreneur, V3 is single, V4 is tertiary, V5 is no, V6 is 623, V7 is yes, V8 is no, V9 is cellular, V10 is 20, V11 is apr, V12 is 124, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 38, V2 is management, V3 is married, V4 is secondary, V5 is no, V6 is 564, V7 is yes, V8 is no, V9 is cellular, V10 is 17, V11 is may, V12 is 126, V13 is 2, V14 is -1, V15 is 0, V16 is failure,
# [Model Output] V1 is 38, V2 is management, V3 is married, V4 is secondary, V5 is no, V6 is 564, V7 is yes, V8 is no, V9 is cellular, V10 is 17, V11 is may, V12 is 126, V13 is 2, V14 is -1, V15 is 0, V16 is failure, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 35, V2 is technician, V3 is married, V4 is secondary, V5 is no, V6 is 61, V7 is yes, V8 is no, V9 is cellular, V10 is 25, V11 is apr, V12 is 167, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 35, V2 is technician, V3 is married, V4 is secondary, V5 is no, V6 is 61, V7 is yes, V8 is no, V9 is cellular, V10 is 25, V11 is apr, V12 is 167, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 33, V2 is technician, V3 is single, V4 is secondary, V5 is no, V6 is -8, V7 is yes, V8 is no, V9 is unknown, V10 is 22, V11 is jun, V12 is 682, V13 is 1, V14 is -1, V15 is 2, V16 is unknown,
# [Model Output] V1 is 33, V2 is technician, V3 is single, V4 is secondary, V5 is no, V6 is -8, V7 is yes, V8 is no, V9 is unknown, V10 is 22, V11 is jun, V12 is 682, V13 is 1, V14 is -1, V15 is 2, V16 is unknown, ia is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 25, V2 is management, V3 is married, V4 is secondary, V5 is no, V6 is 238, V7 is yes, V8 is no, V9 is cellular, V10 is 8, V11 is may, V12 is 184, V13 is 2, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 25, V2 is management, V3 is married, V4 is secondary, V5 is no, V6 is 238, V7 is yes, V8 is no, V9 is cellular, V10 is 8, V11 is may, V12 is 184, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 50, V2 is retired, V3 is married, V4 is secondary, V5 is no, V6 is 783, V7 is no, V8 is no, V9 is cellular, V10 is 25, V11 is may, V12 is 854, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 50, V2 is retired, V3 is married, V4 is secondary, V5 is no, V6 is 783, V7 is no, V8 is no, V9 is cellular, V10 is 25, V11 is may, V12 is 854, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 33, V2 is retired, V3 is divorced, V4 is tertiary, V5 is no, V6 is 0, V7 is yes, V8 is yes, V9 is cellular, V10 is 5, V11 is jul, V12 is 891, V13 is 2, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 33, V2 is retired, V3 is divorced, V4 is tertiary, V5 is no, V6 is 0, V7 is yes, V8 is yes, V9 is cellular, V10 is 5, V11 is jul, V12 is 891, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 59, V2 is management, V3 is single, V4 is secondary, V5 is no, V6 is 27, V7 is no, V8 is no, V9 is cellular, V10 is 20, V11 is apr, V12 is 101, V13 is 2, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 59, V2 is management, V3 is single, V4 is secondary, V5 is no, V6 is 27, V7 is no, V8 is no, V9 is cellular, V10 is 20, V11 is apr, V12 is 101, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 35, V2 is management, V3 is single, V4 is tertiary, V5 is no, V6 is 675, V7 is yes, V8 is no, V9 is cellular, V10 is 28, V11 is may, V12 is 173, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 35, V2 is management, V3 is single, V4 is tertiary, V5 is no, V6 is 675, V7 is yes, V8 is no, V9 is cellular, V10 is 28, V11 is may, V12 is 173, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ute is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 34, V2 is management, V3 is single, V4 is tertiary, V5 is no, V6 is -59, V7 is no, V8 is no, V9 is telephone, V10 is 8, V11 is jul, V12 is 9, V13 is 3, V14 is 374, V15 is 0, V16 is other,
# [Model Output] V1 is 34, V2 is management, V3 is single, V4 is tertiary, V5 is no, V6 is -59, V7 is no, V8 is no, V9 is telephone, V10 is 8, V11 is jul, V12 is 9, V13 is 3, V14 is 374, V15 is 0, V16 is other, iz is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 52, V2 is technician, V3 is married, V4 is secondary, V5 is no, V6 is 588, V7 is yes, V8 is no, V9 is unknown, V10 is 16, V11 is jul, V12 is 49, V13 is 3, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 52, V2 is technician, V3 is married, V4 is secondary, V5 is no, V6 is 588, V7 is yes, V8 is no, V9 is unknown, V10 is 16, V11 is jul, V12 is 49, V13 is 3, V14 is -1, V15 is 0, V16 is unknown, ute is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 53, V2 is services, V3 is single, V4 is primary, V5 is no, V6 is 0, V7 is yes, V8 is no, V9 is unknown, V10 is 17, V11 is may, V12 is 208, V13 is 1, V14 is -1, V15 is 1, V16 is unknown,
# [Model Output] V1 is 53, V2 is services, V3 is single, V4 is primary, V5 is no, V6 is 0, V7 is yes, V8 is no, V9 is unknown, V10 is 17, V11 is may, V12 is 208, V13 is 1, V14 is -1, V15 is 1, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 31, V2 is blue-collar, V3 is married, V4 is tertiary, V5 is no, V6 is 624, V7 is no, V8 is no, V9 is unknown, V10 is 10, V11 is jun, V12 is 130, V13 is 3, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 31, V2 is blue-collar, V3 is married, V4 is tertiary, V5 is no, V6 is 624, V7 is no, V8 is no, V9 is unknown, V10 is 10, V11 is jun, V12 is 130, V13 is 3, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 27, V2 is student, V3 is married, V4 is tertiary, V5 is no, V6 is 0, V7 is yes, V8 is no, V9 is cellular, V10 is 17, V11 is may, V12 is 48, V13 is 2, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 27, V2 is student, V3 is married, V4 is tertiary, V5 is no, V6 is 0, V7 is yes, V8 is no, V9 is cellular, V10 is 17, V11 is may, V12 is 48, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 37, V2 is management, V3 is single, V4 is tertiary, V5 is no, V6 is 12, V7 is yes, V8 is no, V9 is cellular, V10 is 6, V11 is may, V12 is 441, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 37, V2 is management, V3 is single, V4 is tertiary, V5 is no, V6 is 12, V7 is yes, V8 is no, V9 is cellular, V10 is 6, V11 is may, V12 is 441, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 33, V2 is blue-collar, V3 is married, V4 is primary, V5 is no, V6 is 639, V7 is no, V8 is yes, V9 is cellular, V10 is 5, V11 is jan, V12 is 122, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 33, V2 is blue-collar, V3 is married, V4 is primary, V5 is no, V6 is 639, V7 is no, V8 is yes, V9 is cellular, V10 is 5, V11 is jan, V12 is 122, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 50, V2 is technician, V3 is married, V4 is tertiary, V5 is no, V6 is 629, V7 is yes, V8 is no, V9 is unknown, V10 is 19, V11 is nov, V12 is 112, V13 is 2, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 50, V2 is technician, V3 is married, V4 is tertiary, V5 is no, V6 is 629, V7 is yes, V8 is no, V9 is unknown, V10 is 19, V11 is nov, V12 is 112, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 51, V2 is management, V3 is married, V4 is tertiary, V5 is no, V6 is 595, V7 is yes, V8 is yes, V9 is cellular, V10 is 26, V11 is may, V12 is 564, V13 is 3, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 51, V2 is management, V3 is married, V4 is tertiary, V5 is no, V6 is 595, V7 is yes, V8 is yes, V9 is cellular, V10 is 26, V11 is may, V12 is 564, V13 is 3, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 45, V2 is technician, V3 is single, V4 is primary, V5 is no, V6 is -202, V7 is no, V8 is no, V9 is cellular, V10 is 17, V11 is jun, V12 is 108, V13 is 1, V14 is -1, V15 is 0, V16 is failure,
# [Model Output] V1 is 45, V2 is technician, V3 is single, V4 is primary, V5 is no, V6 is -202, V7 is no, V8 is no, V9 is cellular, V10 is 17, V11 is jun, V12 is 108, V13 is 1, V14 is -1, V15 is 0, V16 is failure, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 45, V2 is admin., V3 is married, V4 is secondary, V5 is no, V6 is 0, V7 is no, V8 is no, V9 is unknown, V10 is 20, V11 is may, V12 is 91, V13 is 2, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 45, V2 is admin., V3 is married, V4 is secondary, V5 is no, V6 is 0, V7 is no, V8 is no, V9 is unknown, V10 is 20, V11 is may, V12 is 91, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 34, V2 is retired, V3 is divorced, V4 is tertiary, V5 is no, V6 is 259, V7 is yes, V8 is no, V9 is cellular, V10 is 6, V11 is may, V12 is 443, V13 is 3, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 34, V2 is retired, V3 is divorced, V4 is tertiary, V5 is no, V6 is 259, V7 is yes, V8 is no, V9 is cellular, V10 is 6, V11 is may, V12 is 443, V13 is 3, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 46, V2 is technician, V3 is married, V4 is secondary, V5 is no, V6 is 0, V7 is yes, V8 is no, V9 is unknown, V10 is 13, V11 is may, V12 is 185, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 46, V2 is technician, V3 is married, V4 is secondary, V5 is no, V6 is 0, V7 is yes, V8 is no, V9 is unknown, V10 is 13, V11 is may, V12 is 185, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 35, V2 is retired, V3 is married, V4 is primary, V5 is no, V6 is 13, V7 is yes, V8 is no, V9 is cellular, V10 is 20, V11 is may, V12 is 761, V13 is 3, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 35, V2 is retired, V3 is married, V4 is primary, V5 is no, V6 is 13, V7 is yes, V8 is no, V9 is cellular, V10 is 20, V11 is may, V12 is 761, V13 is 3, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 43, V2 is blue-collar, V3 is single, V4 is secondary, V5 is no, V6 is 1558, V7 is no, V8 is no, V9 is unknown, V10 is 7, V11 is jul, V12 is 108, V13 is 3, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 43, V2 is blue-collar, V3 is single, V4 is secondary, V5 is no, V6 is 1558, V7 is no, V8 is no, V9 is unknown, V10 is 7, V11 is jul, V12 is 108, V13 is 3, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 37, V2 is blue-collar, V3 is married, V4 is primary, V5 is no, V6 is -1, V7 is no, V8 is no, V9 is unknown, V10 is 26, V11 is jun, V12 is 163, V13 is 2, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 37, V2 is blue-collar, V3 is married, V4 is primary, V5 is no, V6 is -1, V7 is no, V8 is no, V9 is unknown, V10 is 26, V11 is jun, V12 is 163, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, ia is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 41, V2 is management, V3 is single, V4 is secondary, V5 is no, V6 is 3990, V7 is yes, V8 is no, V9 is cellular, V10 is 25, V11 is may, V12 is 277, V13 is 1, V14 is -1, V15 is 13, V16 is unknown,
# [Model Output] V1 is 41, V2 is management, V3 is single, V4 is secondary, V5 is no, V6 is 3990, V7 is yes, V8 is no, V9 is cellular, V10 is 25, V11 is may, V12 is 277, V13 is 1, V14 is -1, V15 is 13, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 43, V2 is management, V3 is married, V4 is secondary, V5 is no, V6 is 888, V7 is yes, V8 is no, V9 is cellular, V10 is 18, V11 is may, V12 is 614, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 43, V2 is management, V3 is married, V4 is secondary, V5 is no, V6 is 888, V7 is yes, V8 is no, V9 is cellular, V10 is 18, V11 is may, V12 is 614, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 33, V2 is services, V3 is married, V4 is secondary, V5 is no, V6 is 916, V7 is yes, V8 is no, V9 is cellular, V10 is 16, V11 is may, V12 is 127, V13 is 4, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 33, V2 is services, V3 is married, V4 is secondary, V5 is no, V6 is 916, V7 is yes, V8 is no, V9 is cellular, V10 is 16, V11 is may, V12 is 127, V13 is 4, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 37, V2 is blue-collar, V3 is married, V4 is secondary, V5 is no, V6 is 208, V7 is no, V8 is no, V9 is cellular, V10 is 28, V11 is jul, V12 is 153, V13 is 4, V14 is -1, V15 is 4, V16 is unknown,
# [Model Output] V1 is 37, V2 is blue-collar, V3 is married, V4 is secondary, V5 is no, V6 is 208, V7 is no, V8 is no, V9 is cellular, V10 is 28, V11 is jul, V12 is 153, V13 is 4, V14 is -1, V15 is 4, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 35, V2 is management, V3 is divorced, V4 is tertiary, V5 is no, V6 is 929, V7 is yes, V8 is no, V9 is cellular, V10 is 7, V11 is aug, V12 is 1193, V13 is 2, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 35, V2 is management, V3 is divorced, V4 is tertiary, V5 is no, V6 is 929, V7 is yes, V8 is no, V9 is cellular, V10 is 7, V11 is aug, V12 is 1193, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 40, V2 is admin., V3 is single, V4 is tertiary, V5 is no, V6 is 1438, V7 is yes, V8 is yes, V9 is telephone, V10 is 18, V11 is jun, V12 is 266, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 40, V2 is admin., V3 is single, V4 is tertiary, V5 is no, V6 is 1438, V7 is yes, V8 is yes, V9 is telephone, V10 is 18, V11 is jun, V12 is 266, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 28, V2 is services, V3 is married, V4 is secondary, V5 is no, V6 is 349, V7 is no, V8 is no, V9 is cellular, V10 is 2, V11 is jul, V12 is 94, V13 is 5, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 28, V2 is services, V3 is married, V4 is secondary, V5 is no, V6 is 349, V7 is no, V8 is no, V9 is cellular, V10 is 2, V11 is jul, V12 is 94, V13 is 5, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 45, V2 is technician, V3 is divorced, V4 is tertiary, V5 is no, V6 is 979, V7 is yes, V8 is no, V9 is cellular, V10 is 26, V11 is may, V12 is 637, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 45, V2 is technician, V3 is divorced, V4 is tertiary, V5 is no, V6 is 979, V7 is yes, V8 is no, V9 is cellular, V10 is 26, V11 is may, V12 is 637, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 60, V2 is entrepreneur, V3 is married, V4 is primary, V5 is no, V6 is 27, V7 is no, V8 is no, V9 is cellular, V10 is 12, V11 is jul, V12 is 127, V13 is 1, V14 is 180, V15 is 1, V16 is unknown,
# [Model Output] V1 is 60, V2 is entrepreneur, V3 is married, V4 is primary, V5 is no, V6 is 27, V7 is no, V8 is no, V9 is cellular, V10 is 12, V11 is jul, V12 is 127, V13 is 1, V14 is 180, V15 is 1, V16 is unknown, ia is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 39, V2 is management, V3 is single, V4 is primary, V5 is no, V6 is 714, V7 is yes, V8 is no, V9 is unknown, V10 is 21, V11 is aug, V12 is 150, V13 is 2, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 39, V2 is management, V3 is single, V4 is primary, V5 is no, V6 is 714, V7 is yes, V8 is no, V9 is unknown, V10 is 21, V11 is aug, V12 is 150, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 53, V2 is technician, V3 is single, V4 is secondary, V5 is no, V6 is 1355, V7 is no, V8 is no, V9 is cellular, V10 is 18, V11 is jun, V12 is 77, V13 is 2, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 53, V2 is technician, V3 is single, V4 is secondary, V5 is no, V6 is 1355, V7 is no, V8 is no, V9 is cellular, V10 is 18, V11 is jun, V12 is 77, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 45, V2 is management, V3 is married, V4 is tertiary, V5 is no, V6 is -269, V7 is no, V8 is no, V9 is unknown, V10 is 14, V11 is may, V12 is 151, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 45, V2 is management, V3 is married, V4 is tertiary, V5 is no, V6 is -269, V7 is no, V8 is no, V9 is unknown, V10 is 14, V11 is may, V12 is 151, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ia is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 58, V2 is management, V3 is married, V4 is secondary, V5 is no, V6 is 306, V7 is yes, V8 is no, V9 is cellular, V10 is 2, V11 is jul, V12 is 1206, V13 is 1, V14 is -1, V15 is 0, V16 is other,
# [Model Output] V1 is 58, V2 is management, V3 is married, V4 is secondary, V5 is no, V6 is 306, V7 is yes, V8 is no, V9 is cellular, V10 is 2, V11 is jul, V12 is 1206, V13 is 1, V14 is -1, V15 is 0, V16 is other, iz is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 29, V2 is technician, V3 is divorced, V4 is tertiary, V5 is no, V6 is 468, V7 is yes, V8 is no, V9 is cellular, V10 is 11, V11 is jun, V12 is 375, V13 is 2, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 29, V2 is technician, V3 is divorced, V4 is tertiary, V5 is no, V6 is 468, V7 is yes, V8 is no, V9 is cellular, V10 is 11, V11 is jun, V12 is 375, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 42, V2 is management, V3 is married, V4 is primary, V5 is no, V6 is 309, V7 is no, V8 is no, V9 is unknown, V10 is 21, V11 is may, V12 is 138, V13 is 4, V14 is -1, V15 is 1, V16 is unknown,
# [Model Output] V1 is 42, V2 is management, V3 is married, V4 is primary, V5 is no, V6 is 309, V7 is no, V8 is no, V9 is unknown, V10 is 21, V11 is may, V12 is 138, V13 is 4, V14 is -1, V15 is 1, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 30, V2 is technician, V3 is married, V4 is secondary, V5 is no, V6 is 479, V7 is no, V8 is yes, V9 is cellular, V10 is 3, V11 is nov, V12 is 138, V13 is 1, V14 is -1, V15 is 0, V16 is failure,
# [Model Output] V1 is 30, V2 is technician, V3 is married, V4 is secondary, V5 is no, V6 is 479, V7 is no, V8 is yes, V9 is cellular, V10 is 3, V11 is nov, V12 is 138, V13 is 1, V14 is -1, V15 is 0, V16 is failure, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 38, V2 is management, V3 is single, V4 is secondary, V5 is no, V6 is 876, V7 is no, V8 is no, V9 is cellular, V10 is 5, V11 is may, V12 is 150, V13 is 2, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 38, V2 is management, V3 is single, V4 is secondary, V5 is no, V6 is 876, V7 is no, V8 is no, V9 is cellular, V10 is 5, V11 is may, V12 is 150, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 33, V2 is technician, V3 is single, V4 is secondary, V5 is no, V6 is 126, V7 is no, V8 is no, V9 is cellular, V10 is 26, V11 is nov, V12 is 48, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 33, V2 is technician, V3 is single, V4 is secondary, V5 is no, V6 is 126, V7 is no, V8 is no, V9 is cellular, V10 is 26, V11 is nov, V12 is 48, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 39, V2 is technician, V3 is married, V4 is primary, V5 is no, V6 is -478, V7 is no, V8 is no, V9 is unknown, V10 is 20, V11 is jul, V12 is 107, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 39, V2 is technician, V3 is married, V4 is primary, V5 is no, V6 is -478, V7 is no, V8 is no, V9 is unknown, V10 is 20, V11 is jul, V12 is 107, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ia is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 44, V2 is technician, V3 is single, V4 is secondary, V5 is no, V6 is 3269, V7 is no, V8 is no, V9 is cellular, V10 is 13, V11 is aug, V12 is 541, V13 is 2, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 44, V2 is technician, V3 is single, V4 is secondary, V5 is no, V6 is 3269, V7 is no, V8 is no, V9 is cellular, V10 is 13, V11 is aug, V12 is 541, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 50, V2 is entrepreneur, V3 is married, V4 is secondary, V5 is no, V6 is -1, V7 is yes, V8 is yes, V9 is unknown, V10 is 29, V11 is jul, V12 is 179, V13 is 2, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 50, V2 is entrepreneur, V3 is married, V4 is secondary, V5 is no, V6 is -1, V7 is yes, V8 is yes, V9 is unknown, V10 is 29, V11 is jul, V12 is 179, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, ute is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 31, V2 is blue-collar, V3 is single, V4 is tertiary, V5 is no, V6 is 1867, V7 is yes, V8 is no, V9 is unknown, V10 is 28, V11 is may, V12 is 270, V13 is 4, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 31, V2 is blue-collar, V3 is single, V4 is tertiary, V5 is no, V6 is 1867, V7 is yes, V8 is no, V9 is unknown, V10 is 28, V11 is may, V12 is 270, V13 is 4, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 35, V2 is retired, V3 is married, V4 is secondary, V5 is no, V6 is -297, V7 is no, V8 is no, V9 is unknown, V10 is 2, V11 is jul, V12 is 210, V13 is 1, V14 is 344, V15 is 0, V16 is unknown,
# [Model Output] V1 is 35, V2 is retired, V3 is married, V4 is secondary, V5 is no, V6 is -297, V7 is no, V8 is no, V9 is unknown, V10 is 2, V11 is jul, V12 is 210, V13 is 1, V14 is 344, V15 is 0, V16 is unknown, ia is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 59, V2 is blue-collar, V3 is married, V4 is tertiary, V5 is no, V6 is -355, V7 is yes, V8 is no, V9 is cellular, V10 is 12, V11 is jul, V12 is 112, V13 is 1, V14 is -1, V15 is 0, V16 is other,
# [Model Output] V1 is 59, V2 is blue-collar, V3 is married, V4 is tertiary, V5 is no, V6 is -355, V7 is yes, V8 is no, V9 is cellular, V10 is 12, V11 is jul, V12 is 112, V13 is 1, V14 is -1, V15 is 0, V16 is other, iz is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 34, V2 is unemployed, V3 is single, V4 is secondary, V5 is no, V6 is 4, V7 is no, V8 is no, V9 is unknown, V10 is 27, V11 is jun, V12 is 113, V13 is 1, V14 is -1, V15 is 0, V16 is failure,
# [Model Output] V1 is 34, V2 is unemployed, V3 is single, V4 is secondary, V5 is no, V6 is 4, V7 is no, V8 is no, V9 is unknown, V10 is 27, V11 is jun, V12 is 113, V13 is 1, V14 is -1, V15 is 0, V16 is failure, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 39, V2 is blue-collar, V3 is married, V4 is tertiary, V5 is no, V6 is 155, V7 is yes, V8 is no, V9 is cellular, V10 is 15, V11 is jul, V12 is 361, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 39, V2 is blue-collar, V3 is married, V4 is tertiary, V5 is no, V6 is 155, V7 is yes, V8 is no, V9 is cellular, V10 is 15, V11 is jul, V12 is 361, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 34, V2 is management, V3 is married, V4 is secondary, V5 is no, V6 is 972, V7 is yes, V8 is no, V9 is unknown, V10 is 20, V11 is nov, V12 is 150, V13 is 3, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 34, V2 is management, V3 is married, V4 is secondary, V5 is no, V6 is 972, V7 is yes, V8 is no, V9 is unknown, V10 is 20, V11 is nov, V12 is 150, V13 is 3, V14 is -1, V15 is 0, V16 is unknown, ute is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 45, V2 is blue-collar, V3 is single, V4 is secondary, V5 is no, V6 is 1375, V7 is yes, V8 is yes, V9 is cellular, V10 is 11, V11 is jul, V12 is 173, V13 is 4, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 45, V2 is blue-collar, V3 is single, V4 is secondary, V5 is no, V6 is 1375, V7 is yes, V8 is yes, V9 is cellular, V10 is 11, V11 is jul, V12 is 173, V13 is 4, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 47, V2 is management, V3 is married, V4 is secondary, V5 is no, V6 is 596, V7 is no, V8 is no, V9 is unknown, V10 is 7, V11 is feb, V12 is 150, V13 is 1, V14 is -1, V15 is 0, V16 is failure,
# [Model Output] V1 is 47, V2 is management, V3 is married, V4 is secondary, V5 is no, V6 is 596, V7 is no, V8 is no, V9 is unknown, V10 is 7, V11 is feb, V12 is 150, V13 is 1, V14 is -1, V15 is 0, V16 is failure, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 52, V2 is management, V3 is divorced, V4 is secondary, V5 is no, V6 is 723, V7 is yes, V8 is no, V9 is cellular, V10 is 16, V11 is nov, V12 is 124, V13 is 2, V14 is -1, V15 is 6, V16 is unknown,
# [Model Output] V1 is 52, V2 is management, V3 is divorced, V4 is secondary, V5 is no, V6 is 723, V7 is yes, V8 is no, V9 is cellular, V10 is 16, V11 is nov, V12 is 124, V13 is 2, V14 is -1, V15 is 6, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 30, V2 is unemployed, V3 is single, V4 is primary, V5 is no, V6 is 463, V7 is yes, V8 is yes, V9 is unknown, V10 is 26, V11 is nov, V12 is 210, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 30, V2 is unemployed, V3 is single, V4 is primary, V5 is no, V6 is 463, V7 is yes, V8 is yes, V9 is unknown, V10 is 26, V11 is nov, V12 is 210, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ia is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 36, V2 is management, V3 is single, V4 is tertiary, V5 is no, V6 is 929, V7 is yes, V8 is no, V9 is cellular, V10 is 13, V11 is may, V12 is 199, V13 is 5, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 36, V2 is management, V3 is single, V4 is tertiary, V5 is no, V6 is 929, V7 is yes, V8 is no, V9 is cellular, V10 is 13, V11 is may, V12 is 199, V13 is 5, V14 is -1, V15 is 0, V16 is unknown, ute is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 49, V2 is retired, V3 is married, V4 is primary, V5 is no, V6 is 1502, V7 is no, V8 is no, V9 is cellular, V10 is 5, V11 is aug, V12 is 152, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 49, V2 is retired, V3 is married, V4 is primary, V5 is no, V6 is 1502, V7 is no, V8 is no, V9 is cellular, V10 is 5, V11 is aug, V12 is 152, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 58, V2 is retired, V3 is married, V4 is secondary, V5 is no, V6 is 914, V7 is no, V8 is no, V9 is cellular, V10 is 20, V11 is may, V12 is 474, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 58, V2 is retired, V3 is married, V4 is secondary, V5 is no, V6 is 914, V7 is no, V8 is no, V9 is cellular, V10 is 20, V11 is may, V12 is 474, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 60, V2 is technician, V3 is married, V4 is tertiary, V5 is no, V6 is 3052, V7 is no, V8 is no, V9 is unknown, V10 is 25, V11 is apr, V12 is 41, V13 is 5, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 60, V2 is technician, V3 is married, V4 is tertiary, V5 is no, V6 is 3052, V7 is no, V8 is no, V9 is unknown, V10 is 25, V11 is apr, V12 is 41, V13 is 5, V14 is -1, V15 is 0, V16 is unknown, ute is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 43, V2 is retired, V3 is married, V4 is secondary, V5 is no, V6 is 3131, V7 is no, V8 is no, V9 is cellular, V10 is 28, V11 is jul, V12 is 138, V13 is 1, V14 is -1, V15 is 0, V16 is failure,
# [Model Output] V1 is 43, V2 is retired, V3 is married, V4 is secondary, V5 is no, V6 is 3131, V7 is no, V8 is no, V9 is cellular, V10 is 28, V11 is jul, V12 is 138, V13 is 1, V14 is -1, V15 is 0, V16 is failure, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 42, V2 is management, V3 is single, V4 is tertiary, V5 is no, V6 is 2, V7 is yes, V8 is no, V9 is cellular, V10 is 2, V11 is jul, V12 is 470, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 42, V2 is management, V3 is single, V4 is tertiary, V5 is no, V6 is 2, V7 is yes, V8 is no, V9 is cellular, V10 is 2, V11 is jul, V12 is 470, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 32, V2 is admin., V3 is single, V4 is secondary, V5 is no, V6 is 1320, V7 is yes, V8 is no, V9 is cellular, V10 is 18, V11 is may, V12 is 108, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 32, V2 is admin., V3 is single, V4 is secondary, V5 is no, V6 is 1320, V7 is yes, V8 is no, V9 is cellular, V10 is 18, V11 is may, V12 is 108, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 44, V2 is services, V3 is single, V4 is secondary, V5 is no, V6 is 613, V7 is yes, V8 is no, V9 is cellular, V10 is 12, V11 is jul, V12 is 171, V13 is 3, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 44, V2 is services, V3 is single, V4 is secondary, V5 is no, V6 is 613, V7 is yes, V8 is no, V9 is cellular, V10 is 12, V11 is jul, V12 is 171, V13 is 3, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 40, V2 is management, V3 is single, V4 is secondary, V5 is no, V6 is 628, V7 is no, V8 is no, V9 is cellular, V10 is 7, V11 is feb, V12 is 859, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 40, V2 is management, V3 is single, V4 is secondary, V5 is no, V6 is 628, V7 is no, V8 is no, V9 is cellular, V10 is 7, V11 is feb, V12 is 859, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 55, V2 is management, V3 is married, V4 is primary, V5 is no, V6 is 15, V7 is no, V8 is no, V9 is cellular, V10 is 15, V11 is feb, V12 is 73, V13 is 2, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 55, V2 is management, V3 is married, V4 is primary, V5 is no, V6 is 15, V7 is no, V8 is no, V9 is cellular, V10 is 15, V11 is feb, V12 is 73, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 49, V2 is admin., V3 is single, V4 is secondary, V5 is no, V6 is 89, V7 is yes, V8 is no, V9 is cellular, V10 is 10, V11 is jul, V12 is 604, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 49, V2 is admin., V3 is single, V4 is secondary, V5 is no, V6 is 89, V7 is yes, V8 is no, V9 is cellular, V10 is 10, V11 is jul, V12 is 604, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 18, V2 is management, V3 is single, V4 is secondary, V5 is no, V6 is 800, V7 is no, V8 is no, V9 is cellular, V10 is 18, V11 is jul, V12 is 8, V13 is 2, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 18, V2 is management, V3 is single, V4 is secondary, V5 is no, V6 is 800, V7 is no, V8 is no, V9 is cellular, V10 is 18, V11 is jul, V12 is 8, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 39, V2 is management, V3 is single, V4 is secondary, V5 is no, V6 is 2671, V7 is yes, V8 is no, V9 is cellular, V10 is 14, V11 is nov, V12 is 815, V13 is 1, V14 is 162, V15 is 0, V16 is unknown,
# [Model Output] V1 is 39, V2 is management, V3 is single, V4 is secondary, V5 is no, V6 is 2671, V7 is yes, V8 is no, V9 is cellular, V10 is 14, V11 is nov, V12 is 815, V13 is 1, V14 is 162, V15 is 0, V16 is unknown, ia is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 42, V2 is management, V3 is married, V4 is secondary, V5 is no, V6 is 167, V7 is yes, V8 is no, V9 is unknown, V10 is 6, V11 is jul, V12 is 192, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 42, V2 is management, V3 is married, V4 is secondary, V5 is no, V6 is 167, V7 is yes, V8 is no, V9 is unknown, V10 is 6, V11 is jul, V12 is 192, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 33, V2 is management, V3 is married, V4 is tertiary, V5 is no, V6 is -386, V7 is no, V8 is yes, V9 is cellular, V10 is 31, V11 is nov, V12 is 158, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 33, V2 is management, V3 is married, V4 is tertiary, V5 is no, V6 is -386, V7 is no, V8 is yes, V9 is cellular, V10 is 31, V11 is nov, V12 is 158, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 23, V2 is management, V3 is married, V4 is secondary, V5 is no, V6 is 0, V7 is yes, V8 is yes, V9 is cellular, V10 is 5, V11 is apr, V12 is 172, V13 is 3, V14 is -1, V15 is 0, V16 is other,
# [Model Output] V1 is 23, V2 is management, V3 is married, V4 is secondary, V5 is no, V6 is 0, V7 is yes, V8 is yes, V9 is cellular, V10 is 5, V11 is apr, V12 is 172, V13 is 3, V14 is -1, V15 is 0, V16 is other, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 38, V2 is management, V3 is single, V4 is secondary, V5 is no, V6 is 5291, V7 is no, V8 is no, V9 is unknown, V10 is 6, V11 is feb, V12 is 170, V13 is 1, V14 is -1, V15 is 1, V16 is unknown,
# [Model Output] V1 is 38, V2 is management, V3 is single, V4 is secondary, V5 is no, V6 is 5291, V7 is no, V8 is no, V9 is unknown, V10 is 6, V11 is feb, V12 is 170, V13 is 1, V14 is -1, V15 is 1, V16 is unknown, ia is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 56, V2 is blue-collar, V3 is married, V4 is secondary, V5 is no, V6 is 522, V7 is yes, V8 is yes, V9 is unknown, V10 is 14, V11 is nov, V12 is 1697, V13 is 9, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 56, V2 is blue-collar, V3 is married, V4 is secondary, V5 is no, V6 is 522, V7 is yes, V8 is yes, V9 is unknown, V10 is 14, V11 is nov, V12 is 1697, V13 is 9, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 37, V2 is technician, V3 is single, V4 is secondary, V5 is no, V6 is 8950, V7 is yes, V8 is no, V9 is cellular, V10 is 16, V11 is may, V12 is 307, V13 is 1, V14 is -1, V15 is 0, V16 is failure,
# [Model Output] V1 is 37, V2 is technician, V3 is single, V4 is secondary, V5 is no, V6 is 8950, V7 is yes, V8 is no, V9 is cellular, V10 is 16, V11 is may, V12 is 307, V13 is 1, V14 is -1, V15 is 0, V16 is failure, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 51, V2 is technician, V3 is single, V4 is tertiary, V5 is no, V6 is 531, V7 is yes, V8 is no, V9 is cellular, V10 is 11, V11 is feb, V12 is 104, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 51, V2 is technician, V3 is single, V4 is tertiary, V5 is no, V6 is 531, V7 is yes, V8 is no, V9 is cellular, V10 is 11, V11 is feb, V12 is 104, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 39, V2 is management, V3 is married, V4 is tertiary, V5 is no, V6 is 0, V7 is no, V8 is no, V9 is cellular, V10 is 15, V11 is apr, V12 is 887, V13 is 2, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 39, V2 is management, V3 is married, V4 is tertiary, V5 is no, V6 is 0, V7 is no, V8 is no, V9 is cellular, V10 is 15, V11 is apr, V12 is 887, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 46, V2 is unemployed, V3 is married, V4 is tertiary, V5 is no, V6 is 394, V7 is no, V8 is no, V9 is cellular, V10 is 6, V11 is may, V12 is 94, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 46, V2 is unemployed, V3 is married, V4 is tertiary, V5 is no, V6 is 394, V7 is no, V8 is no, V9 is cellular, V10 is 6, V11 is may, V12 is 94, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 40, V2 is blue-collar, V3 is married, V4 is tertiary, V5 is no, V6 is 0, V7 is yes, V8 is no, V9 is cellular, V10 is 10, V11 is nov, V12 is 138, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 40, V2 is blue-collar, V3 is married, V4 is tertiary, V5 is no, V6 is 0, V7 is yes, V8 is no, V9 is cellular, V10 is 10, V11 is nov, V12 is 138, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 31, V2 is admin., V3 is single, V4 is tertiary, V5 is no, V6 is -342, V7 is yes, V8 is no, V9 is unknown, V10 is 9, V11 is jun, V12 is 103, V13 is 4, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 31, V2 is admin., V3 is single, V4 is tertiary, V5 is no, V6 is -342, V7 is yes, V8 is no, V9 is unknown, V10 is 9, V11 is jun, V12 is 103, V13 is 4, V14 is -1, V15 is 0, V16 is unknown, ia is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 48, V2 is blue-collar, V3 is single, V4 is tertiary, V5 is no, V6 is 422, V7 is yes, V8 is no, V9 is cellular, V10 is 18, V11 is nov, V12 is 632, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 48, V2 is blue-collar, V3 is single, V4 is tertiary, V5 is no, V6 is 422, V7 is yes, V8 is no, V9 is cellular, V10 is 18, V11 is nov, V12 is 632, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 39, V2 is technician, V3 is married, V4 is tertiary, V5 is no, V6 is 0, V7 is no, V8 is no, V9 is cellular, V10 is 15, V11 is jun, V12 is 114, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 39, V2 is technician, V3 is married, V4 is tertiary, V5 is no, V6 is 0, V7 is no, V8 is no, V9 is cellular, V10 is 15, V11 is jun, V12 is 114, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
# ...
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 59, V2 is blue-collar, V3 is single, V4 is secondary, V5 is no, V6 is 1, V7 is no, V8 is yes, V9 is unknown, V10 is 13, V11 is may, V12 is 462, V13 is 5, V14 is -1, V15 is 2, V16 is unknown,
# [Model Output] V1 is 59, V2 is blue-collar, V3 is single, V4 is secondary, V5 is no, V6 is 1, V7 is no, V8 is yes, V9 is unknown, V10 is 13, V11 is may, V12 is 462, V13 is 5, V14 is -1, V15 is 2, V16 is unknown, ia is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 32, V2 is admin., V3 is married, V4 is secondary, V5 is no, V6 is 766, V7 is yes, V8 is no, V9 is telephone, V10 is 29, V11 is aug, V12 is 256, V13 is 4, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 32, V2 is admin., V3 is married, V4 is secondary, V5 is no, V6 is 766, V7 is yes, V8 is no, V9 is telephone, V10 is 29, V11 is aug, V12 is 256, V13 is 4, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 55, V2 is blue-collar, V3 is married, V4 is secondary, V5 is no, V6 is 618, V7 is no, V8 is no, V9 is cellular, V10 is 20, V11 is nov, V12 is 11, V13 is 3, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 55, V2 is blue-collar, V3 is married, V4 is secondary, V5 is no, V6 is 618, V7 is no, V8 is no, V9 is cellular, V10 is 20, V11 is nov, V12 is 11, V13 is 3, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 33, V2 is management, V3 is single, V4 is secondary, V5 is no, V6 is 849, V7 is yes, V8 is no, V9 is cellular, V10 is 2, V11 is may, V12 is 195, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 33, V2 is management, V3 is single, V4 is secondary, V5 is no, V6 is 849, V7 is yes, V8 is no, V9 is cellular, V10 is 2, V11 is may, V12 is 195, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 53, V2 is management, V3 is married, V4 is tertiary, V5 is no, V6 is 0, V7 is no, V8 is no, V9 is cellular, V10 is 6, V11 is jul, V12 is 67, V13 is 2, V14 is -1, V15 is 0, V16 is failure,
# [Model Output] V1 is 53, V2 is management, V3 is married, V4 is tertiary, V5 is no, V6 is 0, V7 is no, V8 is no, V9 is cellular, V10 is 6, V11 is jul, V12 is 67, V13 is 2, V14 is -1, V15 is 0, V16 is failure, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 47, V2 is services, V3 is married, V4 is primary, V5 is no, V6 is 1165, V7 is yes, V8 is no, V9 is unknown, V10 is 23, V11 is jul, V12 is 551, V13 is 1, V14 is 183, V15 is 0, V16 is unknown,
# [Model Output] V1 is 47, V2 is services, V3 is married, V4 is primary, V5 is no, V6 is 1165, V7 is yes, V8 is no, V9 is unknown, V10 is 23, V11 is jul, V12 is 551, V13 is 1, V14 is 183, V15 is 0, V16 is unknown, ia is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 41, V2 is admin., V3 is married, V4 is secondary, V5 is no, V6 is 4301, V7 is yes, V8 is no, V9 is cellular, V10 is 23, V11 is may, V12 is -1, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 41, V2 is admin., V3 is married, V4 is secondary, V5 is no, V6 is 4301, V7 is yes, V8 is no, V9 is cellular, V10 is 23, V11 is may, V12 is -1, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 37, V2 is blue-collar, V3 is divorced, V4 is tertiary, V5 is no, V6 is 665, V7 is yes, V8 is no, V9 is telephone, V10 is 7, V11 is jul, V12 is 112, V13 is 2, V14 is -1, V15 is 1, V16 is unknown,
# [Model Output] V1 is 37, V2 is blue-collar, V3 is divorced, V4 is tertiary, V5 is no, V6 is 665, V7 is yes, V8 is no, V9 is telephone, V10 is 7, V11 is jul, V12 is 112, V13 is 2, V14 is -1, V15 is 1, V16 is unknown, ia is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 33, V2 is management, V3 is single, V4 is primary, V5 is no, V6 is -95, V7 is yes, V8 is no, V9 is cellular, V10 is 11, V11 is jul, V12 is 285, V13 is 2, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 33, V2 is management, V3 is single, V4 is primary, V5 is no, V6 is -95, V7 is yes, V8 is no, V9 is cellular, V10 is 11, V11 is jul, V12 is 285, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, ute is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 39, V2 is blue-collar, V3 is married, V4 is secondary, V5 is no, V6 is 472, V7 is no, V8 is no, V9 is cellular, V10 is 28, V11 is jul, V12 is 246, V13 is 2, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 39, V2 is blue-collar, V3 is married, V4 is secondary, V5 is no, V6 is 472, V7 is no, V8 is no, V9 is cellular, V10 is 28, V11 is jul, V12 is 246, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 55, V2 is student, V3 is married, V4 is secondary, V5 is no, V6 is -27, V7 is no, V8 is no, V9 is cellular, V10 is 6, V11 is aug, V12 is 66, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 55, V2 is student, V3 is married, V4 is secondary, V5 is no, V6 is -27, V7 is no, V8 is no, V9 is cellular, V10 is 6, V11 is aug, V12 is 66, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 29, V2 is technician, V3 is married, V4 is secondary, V5 is no, V6 is 0, V7 is yes, V8 is no, V9 is unknown, V10 is 18, V11 is apr, V12 is 255, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 29, V2 is technician, V3 is married, V4 is secondary, V5 is no, V6 is 0, V7 is yes, V8 is no, V9 is unknown, V10 is 18, V11 is apr, V12 is 255, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 37, V2 is management, V3 is single, V4 is secondary, V5 is no, V6 is 0, V7 is yes, V8 is no, V9 is cellular, V10 is 30, V11 is may, V12 is 184, V13 is 1, V14 is 183, V15 is 0, V16 is unknown,
# [Model Output] V1 is 37, V2 is management, V3 is single, V4 is secondary, V5 is no, V6 is 0, V7 is yes, V8 is no, V9 is cellular, V10 is 30, V11 is may, V12 is 184, V13 is 1, V14 is 183, V15 is 0, V16 is unknown, ia is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 33, V2 is management, V3 is married, V4 is tertiary, V5 is no, V6 is 1384, V7 is no, V8 is no, V9 is unknown, V10 is 25, V11 is feb, V12 is 70, V13 is 2, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 33, V2 is management, V3 is married, V4 is tertiary, V5 is no, V6 is 1384, V7 is no, V8 is no, V9 is unknown, V10 is 25, V11 is feb, V12 is 70, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 51, V2 is self-employed, V3 is married, V4 is primary, V5 is no, V6 is 184, V7 is yes, V8 is no, V9 is cellular, V10 is 9, V11 is may, V12 is 151, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 51, V2 is self-employed, V3 is married, V4 is primary, V5 is no, V6 is 184, V7 is yes, V8 is no, V9 is cellular, V10 is 9, V11 is may, V12 is 151, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 33, V2 is blue-collar, V3 is married, V4 is secondary, V5 is no, V6 is 2887, V7 is yes, V8 is no, V9 is unknown, V10 is 27, V11 is jun, V12 is 597, V13 is 5, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 33, V2 is blue-collar, V3 is married, V4 is secondary, V5 is no, V6 is 2887, V7 is yes, V8 is no, V9 is unknown, V10 is 27, V11 is jun, V12 is 597, V13 is 5, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 51, V2 is admin., V3 is divorced, V4 is tertiary, V5 is no, V6 is 43, V7 is no, V8 is yes, V9 is cellular, V10 is 25, V11 is may, V12 is 587, V13 is 2, V14 is -1, V15 is 0, V16 is failure,
# [Model Output] V1 is 51, V2 is admin., V3 is divorced, V4 is tertiary, V5 is no, V6 is 43, V7 is no, V8 is yes, V9 is cellular, V10 is 25, V11 is may, V12 is 587, V13 is 2, V14 is -1, V15 is 0, V16 is failure, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 58, V2 is technician, V3 is single, V4 is tertiary, V5 is no, V6 is 936, V7 is yes, V8 is no, V9 is cellular, V10 is 20, V11 is apr, V12 is 163, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 58, V2 is technician, V3 is single, V4 is tertiary, V5 is no, V6 is 936, V7 is yes, V8 is no, V9 is cellular, V10 is 20, V11 is apr, V12 is 163, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 33, V2 is management, V3 is married, V4 is secondary, V5 is no, V6 is 2968, V7 is no, V8 is no, V9 is cellular, V10 is 20, V11 is nov, V12 is 974, V13 is 2, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 33, V2 is management, V3 is married, V4 is secondary, V5 is no, V6 is 2968, V7 is no, V8 is no, V9 is cellular, V10 is 20, V11 is nov, V12 is 974, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 35, V2 is technician, V3 is single, V4 is tertiary, V5 is no, V6 is 1311, V7 is no, V8 is no, V9 is cellular, V10 is 8, V11 is may, V12 is 467, V13 is 2, V14 is -1, V15 is 2, V16 is failure,
# [Model Output] V1 is 35, V2 is technician, V3 is single, V4 is tertiary, V5 is no, V6 is 1311, V7 is no, V8 is no, V9 is cellular, V10 is 8, V11 is may, V12 is 467, V13 is 2, V14 is -1, V15 is 2, V16 is failure, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 53, V2 is admin., V3 is married, V4 is tertiary, V5 is no, V6 is 0, V7 is no, V8 is no, V9 is cellular, V10 is 5, V11 is nov, V12 is 196, V13 is 4, V14 is -1, V15 is 1, V16 is unknown,
# [Model Output] V1 is 53, V2 is admin., V3 is married, V4 is tertiary, V5 is no, V6 is 0, V7 is no, V8 is no, V9 is cellular, V10 is 5, V11 is nov, V12 is 196, V13 is 4, V14 is -1, V15 is 1, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 33, V2 is management, V3 is single, V4 is secondary, V5 is no, V6 is 955, V7 is yes, V8 is no, V9 is cellular, V10 is 9, V11 is jul, V12 is 135, V13 is 2, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 33, V2 is management, V3 is single, V4 is secondary, V5 is no, V6 is 955, V7 is yes, V8 is no, V9 is cellular, V10 is 9, V11 is jul, V12 is 135, V13 is 2, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 28, V2 is blue-collar, V3 is single, V4 is secondary, V5 is no, V6 is 1818, V7 is yes, V8 is no, V9 is cellular, V10 is 14, V11 is jun, V12 is 633, V13 is 5, V14 is -1, V15 is 0, V16 is failure,
# [Model Output] V1 is 28, V2 is blue-collar, V3 is single, V4 is secondary, V5 is no, V6 is 1818, V7 is yes, V8 is no, V9 is cellular, V10 is 14, V11 is jun, V12 is 633, V13 is 5, V14 is -1, V15 is 0, V16 is failure, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 52, V2 is management, V3 is married, V4 is tertiary, V5 is no, V6 is -196, V7 is no, V8 is no, V9 is unknown, V10 is 13, V11 is jul, V12 is 136, V13 is 1, V14 is -1, V15 is 1, V16 is unknown,
# [Model Output] V1 is 52, V2 is management, V3 is married, V4 is tertiary, V5 is no, V6 is -196, V7 is no, V8 is no, V9 is unknown, V10 is 13, V11 is jul, V12 is 136, V13 is 1, V14 is -1, V15 is 1, V16 is unknown, ia is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 41, V2 is entrepreneur, V3 is married, V4 is tertiary, V5 is no, V6 is 230, V7 is yes, V8 is no, V9 is cellular, V10 is 20, V11 is jun, V12 is 586, V13 is 2, V14 is -1, V15 is 0, V16 is failure,
# [Model Output] V1 is 41, V2 is entrepreneur, V3 is married, V4 is tertiary, V5 is no, V6 is 230, V7 is yes, V8 is no, V9 is cellular, V10 is 20, V11 is jun, V12 is 586, V13 is 2, V14 is -1, V15 is 0, V16 is failure, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 43, V2 is admin., V3 is married, V4 is tertiary, V5 is no, V6 is 3492, V7 is no, V8 is no, V9 is cellular, V10 is 5, V11 is may, V12 is 184, V13 is 4, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 43, V2 is admin., V3 is married, V4 is tertiary, V5 is no, V6 is 3492, V7 is no, V8 is no, V9 is cellular, V10 is 5, V11 is may, V12 is 184, V13 is 4, V14 is -1, V15 is 0, V16 is unknown, ili is unknown, Class is 1
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 57, V2 is services, V3 is single, V4 is tertiary, V5 is no, V6 is 324, V7 is yes, V8 is no, V9 is cellular, V10 is 21, V11 is jul, V12 is 111, V13 is 1, V14 is -1, V15 is 0, V16 is unknown,
# [Model Output] V1 is 57, V2 is services, V3 is single, V4 is tertiary, V5 is no, V6 is 324, V7 is yes, V8 is no, V9 is cellular, V10 is 21, V11 is jul, V12 is 111, V13 is 1, V14 is -1, V15 is 0, V16 is unknown, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
#  Prompt to model V1 is 47, V2 is blue-collar, V3 is married, V4 is secondary, V5 is no, V6 is 2936, V7 is yes, V8 is no, V9 is telephone, V10 is 13, V11 is may, V12 is 103, V13 is 1, V14 is -1, V15 is 0, V16 is failure,
# [Model Output] V1 is 47, V2 is blue-collar, V3 is married, V4 is secondary, V5 is no, V6 is 2936, V7 is yes, V8 is no, V9 is telephone, V10 is 13, V11 is may, V12 is 103, V13 is 1, V14 is -1, V15 is 0, V16 is failure, ---------------
# No label found - switching to random label
# Randomly selected label: None
#
# Saved synthetic dataset to: data/synthetic_bank_predllm_mini.csv
#
# Sample synthetic rows:
#        V4 V11 V14          V2  V8 V5 V1 V15 V13       V9       V3   V6  V7 V10 V12     V16 Class
#  tertiary may  -1  management  no no 57   2   3  unknown divorced  353  no   4 136 unknown     1
# secondary may  -1  unemployed  no no 35   0   3 cellular  married 2915 yes  17  54 unknown     1
# secondary jul  -1 blue-collar yes no 37   0   2  unknown  married 1713 yes   7 542 unknown     1
# secondary jul  -1  technician  no no 47   0   3 cellular   single -179 yes  23 107 unknown     1
# secondary aug  -1  unemployed  no no 28   0   1 cellular  married  614  no  20  53 unknown     2
# secondary may  -1 blue-collar yes no 38   0   1 cellular  married  716 yes  17 126 unknown     1
# secondary jul  -1 blue-collar yes no 61   0   3 cellular  married   29 yes  19 152 unknown     1
#  tertiary aug  -1 blue-collar  no no 50   0   2 cellular divorced  -37 yes  16 103 unknown     1
# secondary nov  -1  management  no no 34   0   2  unknown   single -312  no  13 173 unknown     1
# secondary may  -1  management  no no 48   0   1 cellular  married  794  no  22 419 failure     1

# %%
# STEP 4
# ----------  TSTR: Train on Synthetic, Test on Real ----------
print("\nRunning TSTR (Train on Synthetic → Test on Real)…")
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

real = df.copy()
real_y = real[LABEL]
real_X = real.drop(columns=[LABEL])

syn = syn_df.copy()
syn_y = syn[LABEL].fillna("<=50K")
syn_X = syn.drop(columns=[LABEL])
print(syn_y.unique())
print("Real and synthetic datasets loaded and separated into features/labels.")


# Identify categorical/numerical columns from REAL schema
cat_cols = [c for c in real_X.columns if real_X[c].dtype == 'object']
num_cols = [c for c in real_X.columns if c not in cat_cols]
print(f"Found {len(cat_cols)} categorical and {len(num_cols)} numerical columns.")

for col in num_cols:
    real_X[col] = pd.to_numeric(real_X[col], errors="coerce")
    syn_X[col]  = pd.to_numeric(syn_X[col],  errors="coerce")

print("\nFilling NaNs with real-data medians...")
real_medians = real_X[num_cols].median(numeric_only=True)
real_X[num_cols] = real_X[num_cols].fillna(real_medians)
syn_X[num_cols]  = syn_X[num_cols].fillna(real_medians)

print("Finsihed data cleaning now building the preprocessing pipeline...")
for col in cat_cols:
    real_X[col] = real_X[col].astype(str)
    syn_X[col]  = syn_X[col].astype(str)

pre = ColumnTransformer([
    ("cat", OneHotEncoder(handle_unknown="ignore"), cat_cols),
    ("num", "passthrough", num_cols),
])

# Defines the model
clf = XGBClassifier(
    n_estimators=200,
    max_depth=6,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    tree_method="hist",
    n_jobs=4
)

pipe = Pipeline([("pre", pre), ("clf", clf)])
print("Preprocessing and model processing...")
print("\n")

print("Now encodoing the synthetic labels.")
label_map = {'1': 0, '2': 1}
inv_label_map = {0: '1', 1: '2'}

syn_y_enc = syn_y.map(label_map)
if syn_y_enc.isna().any():
    # If any weird labels slipped in, snap them to the majority class
    maj = syn_y_enc.value_counts().idxmax()
    syn_y_enc = syn_y_enc.fillna(maj).astype(int)
else:
    syn_y_enc = syn_y_enc.astype(int)
print("Synthetic labels encoded...")


# Real test split
_, X_test_real, _, y_test_real = train_test_split(
    real_X, real_y, test_size=0.2, stratify=real_y, random_state=42
)
y_test_real_enc = y_test_real.map(label_map).astype(int)

print("Training of synthetic data...")
pipe.fit(syn_X, syn_y_enc)
pred_enc = pipe.predict(X_test_real).astype(int)
acc = accuracy_score(y_test_real_enc, pred_enc)
print(f"TSTR Accuracy (XGB trained on synthetic, tested on real): {acc:.3f}")

# (Optional) show predicted label distribution in natural labels
pred_labels = pd.Series(pred_enc).map(inv_label_map).value_counts(normalize=True).rename("pred_label_share")
print("\nPredicted label share on real test set:")
print(pred_labels.to_string())
print("\nDone. You now have: fine-tuned LM, synthetic CSV, and a TSTR score.")


print("Majority baseline accuracy:", (y_test_real_enc.value_counts().max() / len(y_test_real_enc)))
print("\n")
print("Successfully fine-tuned LM, synthetic CSV, and a TSTR score.")
# Out:
# Running TSTR (Train on Synthetic → Test on Real)…
# ['1' '2']
# Real and synthetic datasets loaded and separated into features/labels.
# Found 0 categorical and 16 numerical columns.
#
# Filling NaNs with real-data medians...
# Finsihed data cleaning now building the preprocessing pipeline...
# Preprocessing and model processing...
#
#
# Now encodoing the synthetic labels.
# Synthetic labels encoded...
# Training of synthetic data...
# TSTR Accuracy (XGB trained on synthetic, tested on real): 0.850
#
# Predicted label share on real test set:
# 1    0.9725
# 2    0.0275
#
# Done. You now have: fine-tuned LM, synthetic CSV, and a TSTR score.
# Majority baseline accuracy: 0.8775
#
#
# Successfully fine-tuned LM, synthetic CSV, and a TSTR score.

# %% [markdown]
# **Evaluations**

# %%
import numpy as np
import pandas as pd
from typing import Tuple, Optional


from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.linear_model import LogisticRegression
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Define real_df and synth_df for numeric alignment
real_df = real_X  # or use real if you want all columns
synth_df = syn_X  # or use syn if you want all columns

# %%
# Convert your existing DataFrames to aligned numeric matrices
import numpy as np
import pandas as pd

# Converts the existing DataFrames to aligned numeric matrices
X_real = real_df.select_dtypes(include=[np.number]).copy()
X_synth = synth_df.select_dtypes(include=[np.number]).copy()

# Ensure same columns and order
common_cols = [c for c in X_real.columns if c in X_synth.columns]
X_real = X_real[common_cols].to_numpy()
X_synth = X_synth[common_cols].to_numpy()

print("X_real and X_synth ready:", X_real.shape, X_synth.shape)
# Out:
# X_real and X_synth ready: (2000, 16) (2000, 16)

# %%
# -- Setu Up --
try:
    from xgboost import XGBClassifier
    _HAS_XGB = True
except Exception:
    _HAS_XGB = False
from sklearn.linear_model import LogisticRegression

def _as_array(X) -> np.ndarray:
    if isinstance(X, pd.DataFrame):
        return X.values
    X = np.asarray(X)
    if X.ndim != 2:
        raise ValueError("Expected 2D array for features.")
    return X

def _ensure_numeric_2d(X_real, X_synth) -> Tuple[np.ndarray, np.ndarray]:
    Xr = _as_array(X_real)
    Xs = _as_array(X_synth)

    # basic shape checks
    if Xr.shape[1] != Xs.shape[1]:
        raise ValueError(f"Column mismatch: X_real has {Xr.shape[1]} cols, X_synth has {Xs.shape[1]}.")

    # impute NaN/inf
    Xr = np.where(np.isfinite(Xr), Xr, np.nan)
    Xs = np.where(np.isfinite(Xs), Xs, np.nan)

    imputer = SimpleImputer(strategy="most_frequent")
    Xr = imputer.fit_transform(Xr)
    Xs = imputer.transform(Xs)

    Xr = Xr.astype(float)
    Xs = Xs.astype(float)

    print("Preprocessing complete for numeric 2D arrays.")
    return Xr, Xs

def _safe_k(n: int, k: int) -> int:
    '''Ensure kNN uses k <= n-1 and k>=1.'''
    if n <= 1:
        raise ValueError("Not enough rows for kNN metrics.")
    return max(1, min(k, max(1, n-1)))

def _kth_nn_radius(X: np.ndarray, k: int = 5) -> np.ndarray:
    '''Computes the k-th nearest neighbor radius for each row'''
    k_adj = _safe_k(len(X), k)
    nn = NearestNeighbors(n_neighbors=k_adj+1).fit(X)
    dists, _ = nn.kneighbors(X)
    # Exclude self; pick k-th neighbor (index -1 because we asked for k+1)
    return dists[:, -1]

# For Inverse-KL with numeric or categorical columns:
def _safe_probs(counts: np.ndarray) -> np.ndarray:
    '''Normalizses the count arrays '''
    counts = np.asarray(counts, dtype=float)
    s = counts.sum()
    if s <= 0:
        # avoid division by zero; return uniform
        return np.ones_like(counts) / len(counts)
    return counts / s

def _inv_kl_1d(real_col, synth_col, max_bins: int = 30) -> float:
    eps = 1e-8
    # detect numeric by attempting float conversion
    try:
        real_num = pd.to_numeric(pd.Series(real_col), errors="raise")
        synth_num = pd.to_numeric(pd.Series(synth_col), errors="raise")
        is_numeric = True
    except Exception:
        is_numeric = False

    if is_numeric:
        real = real_num.astype(float).values
        synth = pd.Series(synth_num).astype(float).values

        q25, q75 = np.nanpercentile(real, [25, 75])
        iqr = max(q75 - q25, eps)
        bin_width = 2 * iqr * (len(real) ** (-1/3))
        if not np.isfinite(bin_width) or bin_width <= 0:
            bins = min(max_bins, max(5, int(np.sqrt(max(len(real), 5)))))
        else:
            rng = np.nanmax(real) - np.nanmin(real)
            bins = int(np.clip(rng / max(bin_width, eps), 5, max_bins))

        hist_r, edges = np.histogram(real, bins=bins)
        hist_s, _ = np.histogram(synth, bins=edges)

        p = _safe_probs(hist_r + 1)
        q = _safe_probs(hist_s + 1)
    else:
        r_counts = pd.Series(real_col).astype("object").value_counts()
        s_counts = pd.Series(synth_col).astype("object").value_counts()
        cats = pd.Index(sorted(set(r_counts.index).union(set(s_counts.index))))
        r = (r_counts.reindex(cats).fillna(0).values + 1)
        s = (s_counts.reindex(cats).fillna(0).values + 1)
        p = r / r.sum()
        q = s / s.sum()

    kl = float(np.sum(p * np.log((p + eps) / (q + eps))))
    inv_kl = 1.0 / (1.0 + max(kl, 0.0))  # higher is better
    return inv_kl

def inverse_kl_dataframe(real_df: pd.DataFrame, synth_df: pd.DataFrame):
    '''Inverse-KL on an entire dataframe'''
    if list(real_df.columns) != list(synth_df.columns):
        raise ValueError("Inverse-KL: dataframes must have the same columns in the same order.")
    print("Computing inverse-KL for each column...")
    vals = []
    for c in real_df.columns:
        vals.append(_inv_kl_1d(real_df[c].values, synth_df[c].values))
    return float(np.mean(vals)), pd.Series(vals, index=real_df.columns).sort_values(ascending=True)

print("Helpers loaded. Expecting variables X_real and X_synth to be defined (numeric, 2D).")
# Out:
# Helpers loaded. Expecting variables X_real and X_synth to be defined (numeric, 2D).

# %%
# DISCRIMINATOR SCORE (real vs synthetic) —
print("\n--- DISCRIMINATOR SCORE (Real vs Synthetic Classifier) ---")

Xr, Xs = _ensure_numeric_2d(X_real, X_synth)
X_disc = np.vstack([Xr, Xs])
y_disc = np.concatenate([np.ones(len(Xr), dtype=int), np.zeros(len(Xs), dtype=int)])

test_size = 0.3 if len(X_disc) >= 20 else 0.5
print(f" Splitting data into train/test with test_size={test_size:.2f}")

X_tr, X_te, y_tr, y_te = train_test_split(X_disc, y_disc, test_size=test_size, stratify=y_disc, random_state=42)

print(f" Train size: {X_tr.shape[0]} | Test size: {X_te.shape[0]}")

if _HAS_XGB:
    clf = XGBClassifier(
        n_estimators=300, max_depth=6, subsample=0.8, colsample_bytree=0.8,
        learning_rate=0.05, reg_lambda=1.0, n_jobs=-1, random_state=42
    )
else:
    clf = LogisticRegression(max_iter=2000, n_jobs=-1, solver="lbfgs")

clf.fit(X_tr, y_tr)
print("\nModel training complete.")

print("Predicting labels on test set...")
y_pred = clf.predict(X_te)

# AUC may fail for degenerate probs; handle gracefully
try:
    if hasattr(clf, "predict_proba"):
        y_prob = clf.predict_proba(X_te)[:, 1]
    elif hasattr(clf, "decision_function"):
        from sklearn.metrics import roc_curve
        scores = clf.decision_function(X_te)
        # map decision scores to [0,1] via rank (fallback)
        ranks = pd.Series(scores).rank(method="average").values
        y_prob = (ranks - ranks.min()) / (ranks.max() - ranks.min() + 1e-8)
    else:
        print("No probability scores available from this classifier.")
        y_prob = None
except Exception:
    print(f"Error computing probabilities: {e}")
    y_prob = None

acc = accuracy_score(y_te, y_pred)
if y_prob is not None:
    auc = roc_auc_score(y_te, y_prob)
    print(f"Discriminator score — Accuracy: {acc:.3f}   AUC: {auc:.3f}   (≈0.50 acc is better)")
else:
    print(f"Discriminator score — Accuracy: {acc:.3f}   (≈0.50 is better; AUC not available)")
# Out:
# --- DISCRIMINATOR SCORE (Real vs Synthetic Classifier) ---
# Preprocessing complete for numeric 2D arrays.
#  Splitting data into train/test with test_size=0.30
#  Train size: 2800 | Test size: 1200
# /usr/local/lib/python3.12/dist-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: [ 1  2  3  4  6  7  8 10 15]. At least one non-missing value is needed for imputation with strategy='most_frequent'.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: [ 1  2  3  4  6  7  8 10 15]. At least one non-missing value is needed for imputation with strategy='most_frequent'.
#   warnings.warn(
# Model training complete.
# Predicting labels on test set...
# Discriminator score — Accuracy: 0.735   AUC: 0.823   (≈0.50 acc is better)

# %%
# DENSITY (kNN; higher is better if synth lies in real neighborhoods)
print("\n--- DENSITY (kNN ) ---")
Xr, Xs = _ensure_numeric_2d(X_real, X_synth)

k = 5
k_real = _safe_k(len(Xr), k)

scaler = StandardScaler().fit(Xr)  # scale by real distribution
R = scaler.transform(Xr)
S = scaler.transform(Xs)

r_real = _kth_nn_radius(R, k=k_real)

nn_real = NearestNeighbors(n_neighbors=1).fit(R)
d_sr, idx_sr = nn_real.kneighbors(S, return_distance=True)
d_sr = d_sr.ravel()
idx_sr = idx_sr.ravel()

hits = (d_sr <= r_real[idx_sr]).astype(float)
density_score = float(hits.mean())
print(f"Density (k={k_real}) = {density_score:.3f}   # higher = synthetic near real localities")
# Out:
# --- DENSITY (kNN ) ---
# Preprocessing complete for numeric 2D arrays.
# Density (k=5) = 0.861   # higher = synthetic near real localities
# /usr/local/lib/python3.12/dist-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: [ 1  2  3  4  6  7  8 10 15]. At least one non-missing value is needed for imputation with strategy='most_frequent'.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: [ 1  2  3  4  6  7  8 10 15]. At least one non-missing value is needed for imputation with strategy='most_frequent'.
#   warnings.warn(

# %%
# COVERAGE (kNN; higher is better if synthetic spans real space)
print("\n--- CONVERGE (kNN ) ---")

Xr, Xs = _ensure_numeric_2d(X_real, X_synth)

k = 5
k_synth = _safe_k(len(Xs), k)

scaler = StandardScaler().fit(Xr)  # measure in real-scaled space
R = scaler.transform(Xr)
S = scaler.transform(Xs)

r_synth = _kth_nn_radius(S, k=k_synth)

nn_synth = NearestNeighbors(n_neighbors=1).fit(S)
d_rs, idx_rs = nn_synth.kneighbors(R, return_distance=True)
d_rs = d_rs.ravel()
idx_rs = idx_rs.ravel()

covered = (d_rs <= r_synth[idx_rs]).astype(float)
coverage_score = float(covered.mean())
print(f"Coverage (k={k_synth}) = {coverage_score:.3f}   # higher = synthetic covers real modes")
# Out:
# --- CONVERGE (kNN ) ---
# Preprocessing complete for numeric 2D arrays.
# /usr/local/lib/python3.12/dist-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: [ 1  2  3  4  6  7  8 10 15]. At least one non-missing value is needed for imputation with strategy='most_frequent'.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: [ 1  2  3  4  6  7  8 10 15]. At least one non-missing value is needed for imputation with strategy='most_frequent'.
#   warnings.warn(
# Coverage (k=5) = 0.802   # higher = synthetic covers real modes

# %%
# INVERSE KL DIVERGENCE (per-feature, averaged). Higher is better.

print("\n--- INVERSE KL DIVERGENCE ---")
def _to_aligned_dataframes(X_real, X_synth) -> Tuple[pd.DataFrame, pd.DataFrame]:
  ''' Ensures X_real and X_synth are in the same format and aligned column-wise.
  If already DataFrames, checks column order. If arrays, creates default column names.'''

  if isinstance(X_real, pd.DataFrame) and isinstance(X_synth, pd.DataFrame):
      if list(X_real.columns) != list(X_synth.columns):
          raise ValueError("Inverse-KL: DataFrames must share identical columns in order.")
      return X_real.reset_index(drop=True), X_synth.reset_index(drop=True)

  print("Converting arrays to DataFrames...")
  Xr, Xs = _ensure_numeric_2d(X_real, X_synth)
  cols = [f"f{i}" for i in range(Xr.shape[1])]
  return pd.DataFrame(Xr, columns=cols), pd.DataFrame(Xs, columns=cols)

print("Aligning columns across real and synthetic data...")
real_df, synth_df = _to_aligned_dataframes(X_real, X_synth)

print("Calculating per-feature inverse KL divergence scores...")
inv_kl_mean, inv_kl_per_col = inverse_kl_dataframe(real_df, synth_df)

print(f"Inverse KL (mean across features) = {inv_kl_mean:.3f}   # higher = closer per-feature distributions")
# Out:
# --- INVERSE KL DIVERGENCE ---
# Aligning columns across real and synthetic data...
# Converting arrays to DataFrames...
# Preprocessing complete for numeric 2D arrays.
# Calculating per-feature inverse KL divergence scores...
# Computing inverse-KL for each column...
# Inverse KL (mean across features) = 0.941   # higher = closer per-feature distributions
# /usr/local/lib/python3.12/dist-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: [ 1  2  3  4  6  7  8 10 15]. At least one non-missing value is needed for imputation with strategy='most_frequent'.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: [ 1  2  3  4  6  7  8 10 15]. At least one non-missing value is needed for imputation with strategy='most_frequent'.
#   warnings.warn(

# %%
import pandas as pd
from IPython.display import display

# Collect metric values from previous cells (make sure these variables exist)

results = {
    'Discriminator score': acc if 'acc' in locals() else None,
    'Inverse KL': inv_kl_mean if 'inv_kl_mean' in locals() else None,
    'Density': density_score if 'density_score' in locals() else None,
    'Coverage': coverage_score if 'coverage_score' in locals() else None
}

for metric, value in results.items():
    df = pd.DataFrame({'Pred-LLM': [value]})
    print(f"\n{metric}")
    display(df)
# Out:
# Discriminator score
#    Pred-LLM
# 0     0.735
# Inverse KL
#   Pred-LLM
# 0     None
# Density
#    Pred-LLM
# 0    0.8605
# Coverage
#    Pred-LLM
# 0     0.802

# %%
# Prepare data for plotting
df_results = pd.DataFrame(list(results.items()), columns=["Metric", "Pred-LLM"])

plt.figure(figsize=(7, 4))
sns.barplot(data=df_results, x="Metric", y="Pred-LLM", color="blue")
plt.title("Pred-LLM Evaluation Metrics")
plt.ylim(0, 1)
plt.ylabel("Score")
plt.xlabel("")
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()
